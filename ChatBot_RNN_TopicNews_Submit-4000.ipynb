# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function
from __future__ import unicode_literals

import torch
from torch.jit import script, trace
import torch.nn as nn
from torch import optim
import torch.nn.functional as F
import csv
import random
import re
import os
import unicodedata
import codecs
from io import open
import itertools
import math

# %%
corpus_name = "cornell movie-dialogs corpus"
corpus = os.path.join(r"C:\Users\indra\OneDrive\Documents\Indrani\UCB\w266\chatbot\data", corpus_name)

def printLines(file, n=10):
    with open(file, 'rb') as datafile:
        lines = datafile.readlines()
    for line in lines[:n]:
        print(line)

printLines(os.path.join(corpus, "movie_lines.txt"))

# Define path to new file
datafile = os.path.join(corpus, "formatted_movie_lines.txt")
# Out:
# b'L1045 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ They do not!\n'
# b'L1044 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ They do to!\n'
# b'L985 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ I hope so.\n'
# b'L984 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ She okay?\n'
# b"L925 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Let's go.\n"
# b'L924 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ Wow\n'
# b"L872 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Okay -- you're gonna need to learn how to lie.\n"
# b'L871 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ No\n'
# b'L870 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ I\'m kidding.  You know how sometimes you just become this "persona"?  And you don\'t know how to quit?\n'
# b'L869 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Like my fear of wearing pastels?\n'

# %%
# Default word tokens
PAD_token = 0  # Used for padding short sentences
SOS_token = 1  # Start-of-sentence token
EOS_token = 2  # End-of-sentence token

# %%
class Voc:
    def __init__(self, name):
        self.name = name
        self.trimmed = False
        self.word2index = {}
        self.word2count = {}
        self.index2word = {PAD_token: "PAD", SOS_token: "SOS", EOS_token: "EOS"}
        self.num_words = 3  # Count SOS, EOS, PAD

    def addSentence(self, sentence):
        for word in sentence.split(' '):
            self.addWord(word)

    def addWord(self, word):
        if word not in self.word2index:
            self.word2index[word] = self.num_words
            self.word2count[word] = 1
            self.index2word[self.num_words] = word
            self.num_words += 1
        else:
            self.word2count[word] += 1

    # Remove words below a certain count threshold
    def trim(self, min_count):
        if self.trimmed:
            return
        self.trimmed = True

        keep_words = []

        for k, v in self.word2count.items():
            if v >= min_count:
                keep_words.append(k)

        print('keep_words {} / {} = {:.4f}'.format(
            len(keep_words), len(self.word2index), len(keep_words) / len(self.word2index)
        ))

        # Reinitialize dictionaries
        self.word2index = {}
        self.word2count = {}
        self.index2word = {PAD_token: "PAD", SOS_token: "SOS", EOS_token: "EOS"}
        self.num_words = 3 # Count default tokens

        for word in keep_words:
            self.addWord(word)

# %%
MAX_LENGTH = 10  # Maximum sentence length to consider

# Turn a Unicode string to plain ASCII, thanks to
# https://stackoverflow.com/a/518232/2809427
def unicodeToAscii(s):
    return ''.join(
        c for c in unicodedata.normalize('NFD', s)
        if unicodedata.category(c) != 'Mn'
    )

# Lowercase, trim, and remove non-letter characters
def normalizeString(s):
    s = unicodeToAscii(s.lower().strip())
    s = re.sub(r"([.!?])", r" \1", s)
    s = re.sub(r"[^a-zA-Z.!?]+", r" ", s)
    s = re.sub(r"\s+", r" ", s).strip()
    return s

# Read query/response pairs and return a voc object
def readVocs(datafile, corpus_name):
    print("Reading lines...")
    # Read the file and split into lines
    lines = open(datafile, encoding='utf-8').\
        read().strip().split('\n')
    # Split every line into pairs and normalize
    pairs = [[normalizeString(s) for s in l.split('\t')] for l in lines]
    voc = Voc(corpus_name)
    return voc, pairs

# Returns True iff both sentences in a pair 'p' are under the MAX_LENGTH threshold
def filterPair(p):
    # Input sequences need to preserve the last word for EOS token
    return len(p[0].split(' ')) < MAX_LENGTH and len(p[1].split(' ')) < MAX_LENGTH

# Filter pairs using filterPair condition
def filterPairs(pairs):
    return [pair for pair in pairs if filterPair(pair)]

# Using the functions defined above, return a populated voc object and pairs list
def loadPrepareData(corpus, corpus_name, datafile, save_dir):
    print("Start preparing training data ...")
    voc, pairs = readVocs(datafile, corpus_name)
    print("Read {!s} sentence pairs".format(len(pairs)))
    pairs = filterPairs(pairs)
    print("Trimmed to {!s} sentence pairs".format(len(pairs)))
    print("Counting words...")
    for pair in pairs:
        voc.addSentence(pair[0])
        voc.addSentence(pair[1])
    print("Counted words:", voc.num_words)
    return voc, pairs

# %%
datafile_validation = os.path.join(corpus, "formatted_movie_lines_valid.txt")

# %%
# Load/Assemble voc and pairs
save_dir = os.path.join("data", "save")
voc, pairs = loadPrepareData(corpus, corpus_name, datafile, save_dir)
# Out:
# Start preparing training data ...
# Reading lines...
# Read 171282 sentence pairs
# Trimmed to 49566 sentence pairs
# Counting words...
# Counted words: 15583

# %%
voc_validation, pairs_validation = loadPrepareData(corpus, corpus_name, datafile_validation, save_dir)
# Out:
# Start preparing training data ...
# Reading lines...
# Read 53424 sentence pairs
# Trimmed to 15653 sentence pairs
# Counting words...
# Counted words: 7808

# %%
def indexesFromSentence(voc, sentence):
    return [voc.word2index[word] for word in sentence.split(' ')] + [EOS_token]


def zeroPadding(l, fillvalue=PAD_token):
    return list(itertools.zip_longest(*l, fillvalue=fillvalue))

def binaryMatrix(l, value=PAD_token):
    m = []
    for i, seq in enumerate(l):
        m.append([])
        for token in seq:
            if token == PAD_token:
                m[i].append(0)
            else:
                m[i].append(1)
    return m

# Returns padded input sequence tensor and lengths
def inputVar(l, voc):
    indexes_batch = [indexesFromSentence(voc, sentence) for sentence in l]
    lengths = torch.tensor([len(indexes) for indexes in indexes_batch])
    padList = zeroPadding(indexes_batch)
    padVar = torch.LongTensor(padList)
    return padVar, lengths

# Returns padded target sequence tensor, padding mask, and max target length
def outputVar(l, voc):
    indexes_batch = [indexesFromSentence(voc, sentence) for sentence in l]
    max_target_len = max([len(indexes) for indexes in indexes_batch])
    padList = zeroPadding(indexes_batch)
    mask = binaryMatrix(padList)
    mask = torch.BoolTensor(mask)
    padVar = torch.LongTensor(padList)
    return padVar, mask, max_target_len

# Returns all items for a given batch of pairs
def batch2TrainData(voc, pair_batch):
    pair_batch.sort(key=lambda x: len(x[0].split(" ")), reverse=True)
    input_batch, output_batch = [], []
    for pair in pair_batch:
        input_batch.append(pair[0])
        output_batch.append(pair[1])
    inp, lengths = inputVar(input_batch, voc)
    output, mask, max_target_len = outputVar(output_batch, voc)
    return inp, lengths, output, mask, max_target_len

# %%
def printLines(file, n=10):
    with open(file, 'rb') as datafile:
        lines = datafile.readlines()
    for line in lines[:n]:
        print(line)

# %%
# Splits each line of the file into a dictionary of fields
def loadLines(fileName, fields):
    lines = {}
    with open(fileName, 'r', encoding='iso-8859-1') as f:
        for line in f:
            values = line.split(" +++$+++ ")
            # Extract fields
            lineObj = {}
            for i, field in enumerate(fields):
                lineObj[field] = values[i]
            lines[lineObj['lineID']] = lineObj
    return lines

# %%
# Groups fields of lines from `loadLines` into conversations based on *movie_conversations.txt*
def loadConversations(fileName, lines, fields):
    conversations = []
    with open(fileName, 'r', encoding='iso-8859-1') as f:
        for line in f:
            values = line.split(" +++$+++ ")
            # Extract fields
            convObj = {}
            for i, field in enumerate(fields):
                convObj[field] = values[i]
            # Convert string to list (convObj["utteranceIDs"] == "['L598485', 'L598486', ...]")
            utterance_id_pattern = re.compile('L[0-9]+')
            lineIds = utterance_id_pattern.findall(convObj["utteranceIDs"])
            # Reassemble lines
            convObj["lines"] = []
            for lineId in lineIds:
                convObj["lines"].append(lines[lineId])
            conversations.append(convObj)
    return conversations

# %%
# Extracts pairs of sentences from conversations
def extractSentencePairs(conversations):
    qa_pairs = []
    for conversation in conversations:
        # Iterate over all the lines of the conversation
        for i in range(len(conversation["lines"]) - 1):  # We ignore the last line (no answer for it)
            inputLine = conversation["lines"][i]["text"].strip()
            targetLine = conversation["lines"][i+1]["text"].strip()
            # Filter wrong samples (if one of the lists is empty)
            if inputLine and targetLine:
                qa_pairs.append([inputLine, targetLine])
    return qa_pairs

# %%
# Define path to new file
datafile = r"C:\Users\indra\OneDrive\Documents\Indrani\UCB\w266\chatbot\data\cornell movie-dialogs corpus\formatted_movie_lines.txt"
datafile_validation = r"C:\Users\indra\OneDrive\Documents\Indrani\UCB\w266\chatbot\data\cornell movie-dialogs corpus\formatted_movie_lines_validation.txt"

# %%
delimiter = '\t'
# Unescape the delimiter
delimiter = str(codecs.decode(delimiter, "unicode_escape"))

# Initialize lines dict, conversations list, and field ids
lines = {}
conversations = []
MOVIE_LINES_FIELDS = ["lineID", "characterID", "movieID", "character", "text"]
MOVIE_CONVERSATIONS_FIELDS = ["character1ID", "character2ID", "movieID", "utteranceIDs"]

# %%
 # Load lines and process conversations
print("\nProcessing corpus...")
lines = loadLines(r"C:\Users\indra\OneDrive\Documents\Indrani\UCB\w266\chatbot\data\cornell movie-dialogs corpus\movie_lines.txt", MOVIE_LINES_FIELDS)
print("\nLoading conversations...")
conversations = loadConversations(r"C:\Users\indra\OneDrive\Documents\Indrani\UCB\w266\chatbot\data\cornell movie-dialogs corpus\movie_conversations.txt",
                              lines, MOVIE_CONVERSATIONS_FIELDS)

# conversations=conversations[0:50000]
# Write new csv file
number = 1
print("\nWriting Validation formatted file...")
with open(datafile_validation, 'w', encoding='utf-8') as outputfile:
    writer = csv.writer(outputfile, delimiter=delimiter, lineterminator='\n')

    for pair in extractSentencePairs(conversations):
        if number <= 50000:
            writer.writerow(pair)
        number += 1

number = 1
print("\nWriting Training  formatted file...")
with open(datafile, 'w', encoding='utf-8') as outputfile:
    writer = csv.writer(outputfile, delimiter=delimiter, lineterminator='\n')
    for pair in extractSentencePairs(conversations):
        if number > 50000:
            writer.writerow(pair)
        number += 1
# Out:
# Processing corpus...
#
# Loading conversations...
#
# Writing Validation formatted file...
#
# Writing Training  formatted file...

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import NMF ,LatentDirichletAllocation
from sklearn.pipeline import Pipeline
from sklearn.datasets import fetch_20newsgroups
import numpy as np

# %%
def save_model(dictionary, feature_names, filename):
    with open(filename, "wb") as f:
        np.savez(f, dictionary=dictionary, feature_names=feature_names)
        
def load_model(filename):
    """load model saved with save_model. Returns a tupe of dictionary, feature_names"""
    with open(filename, "rb") as f:
        arrs = np.load(f)
        return arrs["dictionary"], arrs["feature_names"]
    

def print_top_words(dictionary, feature_names, n_top_words):
    """print the top n_top_words from each topic in the dictionary matrix
    of dictionary. Feature names is a list of words with indices corresponding
    to the columns of the dictionary"""
    for topic_idx, topic in enumerate(dictionary):
        message = "Topic #%d: " % topic_idx
        message += " ".join([feature_names[i]
                             for i in topic.argsort()[:-n_top_words - 1:-1]])
        print(message)
    print()

# %%
def train_model(data, n_features, n_components):
    model = Pipeline(steps=[("tfidf", TfidfVectorizer(max_df=0.95, min_df=2,
                                                      max_features=n_features, stop_words='english')),
                            ("lda", LatentDirichletAllocation(n_components=n_components, random_state=1))])
    model.fit(data)
    features = model["tfidf"].get_feature_names()
    dictionary = model["lda"].components_
    return dictionary, features

def train_save_model(data, n_features, n_components, filename):
    dictionary, features = train_model(data, n_features, n_components)
    save_model(dictionary, features, filename)
    return dictionary, features        

def load_news():
    dataset = fetch_20newsgroups(shuffle=True, random_state=1,
                                 remove=('headers', 'footers', 'quotes'))
    data_samples = dataset.data
    return data_samples

# %%
# number of top words to use in tfidf representation of data
n_features = 1000
# number of topics in LDA
n_components = 10

# train model and save it
print("Loading, training, and saving 20 news groups model")
news_data = load_news()
news_dict, news_feats = train_save_model(news_data, n_features, n_components, "data/topic/news-lda.npz")
print_top_words(news_dict, news_feats, 10)
# Out:
# Loading, training, and saving 20 news groups model
# Topic #0: 00 10 11 1993 15 12 23 13 apr 17
# Topic #1: god people think jesus don say believe just does know
# Topic #2: windows window file program use files using edu server motif
# Topic #3: government people key israel gun law don state encryption public
# Topic #4: drive card mac software video monitor use windows pc scsi
# Topic #5: space nasa new orbit earth air years launch research water
# Topic #6: game team year games season players play hockey league win
# Topic #7: mail phone address thanks sale edu email interested 00 price
# Topic #8: just like car don bike good know think ve time
# Topic #9: thanks know mail looking post hi info faq help appreciated

# %%
USE_CUDA = torch.cuda.is_available()
print("USE_CUDA", USE_CUDA)
if USE_CUDA:
    device = torch.device("cuda")
# Out:
# USE_CUDA True

# %%
def calculate_codes(topic_for_code, input_seq_for_code, voc, feature_path, batch_size):
    # batch_size = 64 for training, 1 for chatting
    ldadict = np.load(feature_path)["feature_names"]
    new_input_seq = torch.zeros(batch_size, len(ldadict))

    for i in range(batch_size):
        for j in range(len(input_seq_for_code[i])):
            input_seq_words = voc.index2word[input_seq_for_code[i][j].item()]
            for check_index in range(len(ldadict)):
                if ldadict[check_index] == input_seq_words:
                    new_input_seq[i][check_index] = 1

    three_d_topic = topic_for_code.repeat(batch_size, 1, 1).to(device)
    three_d_q = new_input_seq.repeat(1, 1, 1).permute(1, 2, 0).to(device)

    return torch.bmm(three_d_topic, three_d_q)

# %%
class EncoderRNN(nn.Module):
    def __init__(self,
                 hidden_size,
                 embedding,
                 topics,
                 n_layers=1,
                 dropout=0,
                 batch_size=64):
        super(EncoderRNN, self).__init__()
        self.n_layers = n_layers
        self.hidden_size = hidden_size
        self.embedding = embedding
        self.topics = topics
        self.batch_size = batch_size
        # self.voc = voc
        # Initialize GRU; the input_size and hidden_size params are both set to 'hidden_size'
        self.gru = nn.GRU(hidden_size,
                          hidden_size,
                          n_layers,
                          dropout=(0 if n_layers == 1 else dropout), bidirectional=True)

    def forward(self, input_seq, input_lengths, hidden=None):
        #print(input_seq)
        batch_size = 1
        #get the codes first
        input_seq_for_code = input_seq.transpose(0,1)
        topic_for_code = self.topics
        feature_path = r"data/topic/news-lda.npz"
        codes = calculate_codes(topic_for_code, input_seq_for_code, voc, feature_path, self.batch_size)
        #print(codes.size())
        # Convert word indexes to embeddings
        embedded = self.embedding(input_seq)
        # Pack padded batch of sequences for RNN module
        packed = nn.utils.rnn.pack_padded_sequence(embedded, input_lengths)
        # Forward pass through GRU
        outputs, hidden = self.gru(packed, hidden)
        # Unpack padding
        outputs, _ = nn.utils.rnn.pad_packed_sequence(outputs)
        # Sum bidirectional GRU outputs
        outputs = outputs[:, :, :self.hidden_size] + outputs[:, : ,self.hidden_size:]
        # Return output and final hidden state
        return outputs, hidden, codes

# %%
class Attn(nn.Module):
    def __init__(self, method, hidden_size):
        super(Attn, self).__init__()
        self.method = method
        if self.method not in ['dot', 'general', 'concat']:
            raise ValueError(self.method, "is not an appropriate attention method.")
        self.hidden_size = hidden_size
        if self.method == 'general':
            self.attn = nn.Linear(self.hidden_size, hidden_size)
        elif self.method == 'concat':
            self.attn = nn.Linear(self.hidden_size * 2, hidden_size)
            self.v = nn.Parameter(torch.FloatTensor(hidden_size))

    def dot_score(self, hidden, encoder_output):
        return torch.sum(hidden * encoder_output, dim=2)

    def general_score(self, hidden, encoder_output):
        energy = self.attn(encoder_output)
        return torch.sum(hidden * energy, dim=2)

    def concat_score(self, hidden, encoder_output):
        energy = self.attn(torch.cat((hidden.expand(encoder_output.size(0), -1, -1), encoder_output), 2)).tanh()
        return torch.sum(self.v * energy, dim=2)

    def forward(self, hidden, encoder_outputs):
        # Calculate the attention weights (energies) based on the given method
        if self.method == 'general':
            attn_energies = self.general_score(hidden, encoder_outputs)
        elif self.method == 'concat':
            attn_energies = self.concat_score(hidden, encoder_outputs)
        elif self.method == 'dot':
            attn_energies = self.dot_score(hidden, encoder_outputs)

        # Transpose max_length and batch_size dimensions
        attn_energies = attn_energies.t()

        # Return the softmax normalized probability scores (with added dimension)
        return F.softmax(attn_energies, dim=1).unsqueeze(1)

# %%
def maskNLLLoss(inp, target, mask):
    nTotal = mask.sum()
    crossEntropy = -torch.log(torch.gather(inp, 1, target.view(-1, 1)).squeeze(1))
    loss = crossEntropy.masked_select(mask).mean()
    loss = loss.to(device)
    return loss, nTotal.item()

# %%
def validation(input_variable, lengths, target_variable, mask, max_target_len, encoder, decoder, embedding,
          encoder_optimizer, decoder_optimizer, batch_size, clip, max_length=MAX_LENGTH):
    # Set device options
    input_variable = input_variable.to(device)
    lengths = lengths.to(device)
    target_variable = target_variable.to(device)
    mask = mask.to(device)

    # Initialize variables
    loss = 0
    print_losses = []
    n_totals = 0

    # Forward pass through encoder
    encoder_outputs, encoder_hidden, codes = encoder(input_variable, lengths)

    # Create initial decoder input (start with SOS tokens for each sentence)
    decoder_input = torch.LongTensor([[SOS_token for _ in range(batch_size)]])
    decoder_input = decoder_input.to(device)

    # Set initial decoder hidden state to the encoder's final hidden state
    decoder_hidden = encoder_hidden[:decoder.n_layers]

    # Determine if we are using teacher forcing this iteration
    teacher_forcing_ratio = 1.0
    use_teacher_forcing = True if random.random() < teacher_forcing_ratio else False

    # Forward batch of sequences through decoder one time step at a time
    if use_teacher_forcing:
        for t in range(max_target_len):
            decoder_output, decoder_hidden = decoder(
                decoder_input, decoder_hidden, encoder_outputs, codes, batch_size
            )
            # Teacher forcing: next input is current target
            decoder_input = target_variable[t].view(1, -1)
            # Calculate and accumulate loss
            mask_loss, nTotal = maskNLLLoss(decoder_output, target_variable[t], mask[t])
            loss += mask_loss
            print_losses.append(mask_loss.item() * nTotal)
            n_totals += nTotal
    else:
        for t in range(max_target_len):
            decoder_output, decoder_hidden = decoder(
                decoder_input, decoder_hidden, encoder_outputs, codes, batch_size
            )
            # No teacher forcing: next input is decoder's own current output
            _, topi = decoder_output.topk(1)
            decoder_input = torch.LongTensor([[topi[i][0] for i in range(batch_size)]])
            decoder_input = decoder_input.to(device)
            # Calculate and accumulate loss
            mask_loss, nTotal = maskNLLLoss(decoder_output, target_variable[t], mask[t])
            loss += mask_loss
            print_losses.append(mask_loss.item() * nTotal)
            n_totals += nTotal

    return sum(print_losses) / n_totals

# %%
def train(input_variable,
          lengths,
          target_variable,
          mask,
          max_target_len,
          encoder,
          decoder,
          embedding,
          encoder_optimizer,
          decoder_optimizer,
          batch_size,
          clip,
          max_length=MAX_LENGTH):

    # Zero gradients
    encoder_optimizer.zero_grad()
    decoder_optimizer.zero_grad()

    # Set device options
    input_variable = input_variable.to(device)
    lengths = lengths.to(device)
    target_variable = target_variable.to(device)
    mask = mask.to(device)

    # Initialize variables
    loss = 0
    print_losses = []
    n_totals = 0

    # Forward pass through encoder
    encoder_outputs, encoder_hidden, codes = encoder(input_variable, lengths)

    # Create initial decoder input (start with SOS tokens for each sentence)
    decoder_input = torch.LongTensor([[SOS_token for _ in range(batch_size)]])
    decoder_input = decoder_input.to(device)

    # Set initial decoder hidden state to the encoder's final hidden state
    #decoder_hidden = encoder_hidden[:decoder.n_layers]
    decoder_hidden = encoder_hidden[:decoder.n_layers]

    # Determine if we are using teacher forcing this iteration
    teacher_forcing_ratio = 1.0
    use_teacher_forcing = True if random.random() < teacher_forcing_ratio else False

    # Forward batch of sequences through decoder one time step at a time
    if use_teacher_forcing:
        for t in range(max_target_len):

            decoder_output, decoder_hidden = decoder(
                decoder_input, decoder_hidden, encoder_outputs, codes, batch_size
            )
            # Teacher forcing: next input is current target
            decoder_input = target_variable[t].view(1, -1)
            # Calculate and accumulate loss
            mask_loss, nTotal = maskNLLLoss(decoder_output, target_variable[t], mask[t])
            loss += mask_loss
            print_losses.append(mask_loss.item() * nTotal)
            n_totals += nTotal
    else:
        for t in range(max_target_len):
            decoder_output, decoder_hidden = decoder(
                decoder_input, decoder_hidden, encoder_outputs, codes, batch_size
            )
            # No teacher forcing: next input is decoder's own current output
            _, topi = decoder_output.topk(1)
            decoder_input = torch.LongTensor([[topi[i][0] for i in range(batch_size)]])
            decoder_input = decoder_input.to(device)
            # Calculate and accumulate loss
            mask_loss, nTotal = maskNLLLoss(decoder_output, target_variable[t], mask[t])
            loss += mask_loss
            print_losses.append(mask_loss.item() * nTotal)
            n_totals += nTotal

    # Perform backpropatation
    loss.backward()

    # Clip gradients: gradients are modified in place
    _ = nn.utils.clip_grad_norm_(encoder.parameters(), clip)
    _ = nn.utils.clip_grad_norm_(decoder.parameters(), clip)

    # Adjust model weights
    encoder_optimizer.step()
    decoder_optimizer.step()

    return sum(print_losses) / n_totals

# %%
def trainIters(model_name,
               voc,
               voc_validation,
               pairs,
               pairs_validation,
               encoder,
               decoder,
               encoder_optimizer,
               decoder_optimizer,
               embedding,
               encoder_n_layers,
               decoder_n_layers,
               save_dir,
               n_iteration,
               batch_size,
               print_every,
               save_every,
               clip,
               corpus_name,
               loadFilename,
               DICT_NAME,
               checkpoint):

    #history record file
    history_file = open(r'history_delta.txt', 'w')

    # Load batches for each iteration
    training_batches = [batch2TrainData(voc, [random.choice(pairs) for _ in range(batch_size)])
                      for _ in range(n_iteration)]
    training_batches_validation = [batch2TrainData(voc_validation, [random.choice(pairs_validation) for _ in range(batch_size)])
                        for _ in range(n_iteration)]

    # Initializations
    print('Initializing ...')
    start_iteration = 1
    print_loss = 0
    print_loss_validation = 0
    if loadFilename:
        start_iteration = checkpoint['iteration'] + 1

    # Training loop
    print("Training...")
    for iteration in range(start_iteration, n_iteration + 1):
        training_batch = training_batches[iteration - 1]
        training_batch_validation = training_batches_validation[iteration - 1]

        # Extract fields from batch
        input_variable, lengths, target_variable, mask, max_target_len = training_batch
        input_variable_validation, lengths_validation, target_variable_validation, mask_validation, max_target_len_validation = training_batch_validation

        # Run a training iteration with batch
        loss = train(input_variable, lengths, target_variable, mask, max_target_len, encoder,
                     decoder, embedding, encoder_optimizer, decoder_optimizer, batch_size, clip)
        print_loss += loss
        loss_validation = validation(input_variable_validation, lengths_validation, target_variable_validation, mask_validation, max_target_len_validation, encoder,
                     decoder, embedding, encoder_optimizer, decoder_optimizer, batch_size, clip)
        print_loss_validation += loss_validation

        # Print progress
        if iteration % print_every == 0:
            print_loss_avg = print_loss / print_every
            print_loss_avg_validation = print_loss_validation / print_every
            print("Iteration: {}; Percent complete: {:.1f}%; Training loss: {:.4f}; Validation loss: {:.4f}".format(iteration, iteration / n_iteration * 100, print_loss_avg, print_loss_avg_validation))
            history_file.write('{}'.format(print_loss_avg))
            history_file.write(' ')
            history_file.write('{}'.format(print_loss_avg_validation))
            history_file.write("\n")

            print_loss = 0
            print_loss_validation = 0

# %%
def evaluate(encoder, decoder, searcher, voc, sentence, max_length=MAX_LENGTH):
    ### Format input sentence as a batch
    # words -> indexes
    indexes_batch = [indexesFromSentence(voc, sentence)]
    # Create lengths tensor
    lengths = torch.tensor([len(indexes) for indexes in indexes_batch])
    # Transpose dimensions of batch to match models' expectations
    input_batch = torch.LongTensor(indexes_batch).transpose(0, 1)
    # Use appropriate device
    input_batch = input_batch.to(device)
    lengths = lengths.to(device)
    # Decode sentence with searcher
    tokens, scores = searcher(input_batch, lengths, max_length)
    # indexes -> words
    decoded_words = [voc.index2word[token.item()] for token in tokens]
    return decoded_words


def evaluateInput(encoder, decoder, searcher, voc):
    input_sentence = ''
    while(1):
        try:
            # Get input sentence
            input_sentence = input('> ')
            # Check if it is quit case
            if input_sentence == 'q' or input_sentence == 'quit': break
            # Normalize sentence
            input_sentence = normalizeString(input_sentence)
            # Evaluate sentence
            start_time = time.time()
            output_words = evaluate(encoder, decoder, searcher, voc, input_sentence)
            # Format and print response sentence
            output_words[:] = [x for x in output_words if not (x == 'EOS' or x == 'PAD')]
            print('Bot:', ' '.join(output_words))
            end_time = time.time()
            print('Responding time:', end_time - start_time)
        except KeyError:
            print("Error: Encountered unknown word.")

# %%
def rand_pick(probabilities):
    x=random.uniform(0,1)
    #print(probabilities[0][20])
    cumulative_probability = 0.0
    #list = [n for n in range(len(probabilities))]
    for item in range(len(probabilities[0])):
        cumulative_probability += probabilities[0][item]
        if x < cumulative_probability:
            break
    item_list = torch.zeros([1], device=device, dtype=torch.long)
    item_list[0] = item
    score = torch.zeros([1],device=device)
    score[0]=probabilities[0][item]
    
    return item_list, score

class SearchDecoder(nn.Module):
    def __init__(self, encoder, decoder, batch_size=1):
        super(SearchDecoder, self).__init__()
        self.encoder = encoder
        self.decoder = decoder
        self.batch_size = batch_size

    def forward(self, input_seq, input_length, max_length):
        # Forward input through encoder model
        encoder_outputs, encoder_hidden, codes = self.encoder(input_seq, input_length)
        # Prepare encoder's final hidden layer to be first hidden input to the decoder
        decoder_hidden = encoder_hidden[:self.decoder.n_layers]
        # Initialize decoder input with SOS_token
        decoder_input = torch.ones(1, 1, device=device, dtype=torch.long) * SOS_token
        # Initialize tensors to append decoded words to
        all_tokens = torch.zeros([0], device=device, dtype=torch.long)
        all_scores = torch.zeros([0], device=device)
        # Iteratively decode one word token at a time
        for _ in range(max_length):
            # Forward pass through decoder
            decoder_output, decoder_hidden = self.decoder(decoder_input,
                                                          decoder_hidden,
                                                          encoder_outputs,
                                                          codes,
                                                          self.batch_size)
            # Obtain word based on probability distribution token and its softmax score
            decoder_input, decoder_scores = my_random_pick(decoder_output)
            # Record token and score
            all_tokens = torch.cat((all_tokens, decoder_input), dim=0)
            all_scores = torch.cat((all_scores, decoder_scores), dim=0)
            # Prepare current token to be next decoder input (add a dimension)
            decoder_input = torch.unsqueeze(decoder_input, 0)
        # Return collections of word tokens and scores
        return all_tokens, all_scores

# %%
class TopicAttention(nn.Module):
    def __init__(self, topic_vocab_size, enc_hid_dim, dec_hid_dim):
        super(TopicAttention, self).__init__()
        self.enc_hid_dim = enc_hid_dim
        self.dec_hid_dim = dec_hid_dim

        self.attn = nn.Linear(topic_vocab_size + dec_hid_dim + enc_hid_dim, dec_hid_dim)
        self.v = nn.Parameter(torch.rand(dec_hid_dim))

    def forward(self, hidden, topic_dict, enc_hidden):
        batch_size = enc_hidden.shape[0]
        num_topics = topic_dict.shape[0]

        hidden = hidden.repeat(num_topics, 1, 1).permute(1, 0, 2)
        enc_hidden = enc_hidden.repeat(num_topics, 1, 1).permute(1, 0, 2)
        topic_dict = topic_dict.repeat(batch_size, 1, 1)

        
        energy = torch.tanh(self.attn(torch.cat((hidden, topic_dict, enc_hidden), dim=2)))

        # energy = [batch_size, dec_hid_dim]
        energy = energy.permute(0, 2, 1)

        v = self.v.repeat(batch_size, 1).unsqueeze(1)

        # v = [batch_size, 1, dec_hid_dim]
        attention = torch.bmm(v, energy).squeeze(1)

        return F.softmax(attention, dim=1).unsqueeze(1)

# %%
class TopicDecoder(nn.Module):
    def __init__(self,
                 attn_model,
                 embedding,
                 hidden_size,
                 output_size,
                 enc_hid_dim,
                 dec_hid_dim,
                 topics,
                 topic_vocab_size,
                 n_layers=1,
                 dropout=0.1,
                 batch_size=1):
        super(TopicDecoder, self).__init__()

        # Keep for reference
        self.attn_model = attn_model
        self.hidden_size = hidden_size
        self.output_size = output_size
        self.n_layers = n_layers
        self.dropout = dropout
        self.enc_hid_dim = enc_hid_dim
        self.dec_hid_dim = dec_hid_dim
        self.topics = topics
        self.topic_vocab_size = topic_vocab_size
        self.batch_size = batch_size

        # Define layers
        self.embedding = embedding
        self.embedding_dropout = nn.Dropout(dropout)
        self.gru = nn.GRU(hidden_size, hidden_size, n_layers, dropout=(0 if n_layers == 1 else dropout))
        self.concat = nn.Linear(hidden_size * 2 + topic_vocab_size + 1000, hidden_size) #1000 is len of topic dictionary
        self.out = nn.Linear(hidden_size, output_size)

        self.attn = Attn(attn_model, hidden_size)
        self.topic_attn = TopicAttention(topic_vocab_size, enc_hid_dim, dec_hid_dim)

    def forward(self,
                input_step,
                last_hidden,
                encoder_outputs,
                codes,
                batch_size=1):
        # Note: we run this one step (word) at a time
        # Get embedding of current input word
        embedded = self.embedding(input_step)
        embedded = self.embedding_dropout(embedded)
        # Forward through unidirectional GRU
        rnn_output, hidden = self.gru(embedded, last_hidden)

        # Calculate attention weights from the current GRU output
        attn_weights = self.attn(rnn_output, encoder_outputs)
        topic_attn_weights = self.topic_attn(last_hidden, self.topics, encoder_outputs[-1])

        # Multiply attention weights to encoder outputs to get new "weighted sum" context vector
        encoder_outputs = encoder_outputs.permute(1,0,2)
      
        context = torch.bmm(attn_weights, encoder_outputs)
     
        topic_context = torch.bmm(topic_attn_weights, self.topics.repeat(batch_size, 1, 1))
       
        topic_for_Pk = self.topics.repeat(batch_size,1,1).permute(0,2,1)
        # print('topic_for_Pk',topic_for_Pk.size())
        Pk_context = torch.bmm(topic_for_Pk, codes)
        # print('Pk_context',Pk_context.size())

        # Concatenate weighted context vector and GRU output using Luong eq. 5
       
        rnn_output = rnn_output.squeeze(0)
        context = context.squeeze(1)
        topic_context = topic_context.squeeze(1)
      
        Pk_context = Pk_context.squeeze(2)
        concat_input = torch.cat((rnn_output, context, topic_context, Pk_context), 1)
        # print('concat_input', concat_input.size())
        concat_output = torch.tanh(self.concat(concat_input))

        # Predict next word using Luong eq. 6
        output = self.out(concat_output)
        output = F.softmax(output, dim=1)
        # Return output and final hidden state
        return output, hidden

# %%
# Configure models
model_name = 'topic_model'
attn_model = 'dot'
hidden_size = 500
encoder_n_layers = 1
decoder_n_layers = 1
dropout = 0.1
batch_size = 64 # 64 for training, 1 for chatting

# %%
DICT_NAME = 'data/topic/news'
DICT_PATH = DICT_NAME + '-lda.npz'
print("DICT_PATH",DICT_PATH)
topic_dict = torch.tensor(np.load(DICT_PATH)["dictionary"], dtype=torch.float).to(device)
# Out:
# DICT_PATH data/topic/news-lda.npz

# %%
# Set checkpoint to load from
loadFilename = None
checkpoint_iter = 64000

# %%
print('Building encoder and decoder ...')
# Initialize word embeddings
embedding = nn.Embedding(voc.num_words, hidden_size)
if loadFilename:
    embedding.load_state_dict(embedding_sd)

# Initialize encoder & decoder models
encoder = EncoderRNN(hidden_size=hidden_size,
                             embedding=embedding,
                             topics=topic_dict,
                             n_layers=encoder_n_layers,
                             dropout=dropout,
                             batch_size=batch_size)

enc_hid_dim, dec_hid_dim, emb_dim = hidden_size, hidden_size, hidden_size

decoder = TopicDecoder(attn_model,
                                  embedding,
                                  hidden_size,
                                  voc.num_words,
                                  enc_hid_dim,
                                  dec_hid_dim,
                                  topic_dict,
                                  topic_dict.shape[1],
                                  decoder_n_layers,
                                  dropout)
if loadFilename:
    encoder.load_state_dict(encoder_sd)
    decoder.load_state_dict(decoder_sd)

# Use appropriate device
encoder = encoder.to(device)
decoder = decoder.to(device)
print('Models built and ready to go!')
# Out:
# Building encoder and decoder ...
# Models built and ready to go!

# %%
#start training
# Configure training/optimization
clip = 50.0
teacher_forcing_ratio = 1.0
learning_rate = 0.0001
decoder_learning_ratio = 5.0
n_iteration = 4000
print_every = 1
save_every = 100

# Ensure dropout layers are in train mode
encoder.train()
decoder.train()

# Initialize optimizers
print('Building optimizers ...')
encoder_optimizer = optim.Adam(encoder.parameters(), lr=learning_rate)
decoder_optimizer = optim.Adam(decoder.parameters(), lr=learning_rate * decoder_learning_ratio)
if loadFilename:
    encoder_optimizer.load_state_dict(encoder_optimizer_sd)
    decoder_optimizer.load_state_dict(decoder_optimizer_sd)

# If you have cuda, configure cuda to call
for state in encoder_optimizer.state.values():
    for k, v in state.items():
        if isinstance(v, torch.Tensor):
            state[k] = v.cuda()

for state in decoder_optimizer.state.values():
    for k, v in state.items():
        if isinstance(v, torch.Tensor):
            state[k] = v.cuda()

# Run training iterations
print("Starting Training!")
trainIters(model_name=model_name,
                   voc=voc,
                   voc_validation=voc_validation,
                   pairs=pairs,
                   pairs_validation=pairs_validation,
                   encoder=encoder,
                   decoder=decoder,
                   encoder_optimizer=encoder_optimizer,
                   decoder_optimizer=decoder_optimizer,
                   embedding=embedding,
                   encoder_n_layers=encoder_n_layers,
                   decoder_n_layers=decoder_n_layers,
                   save_dir=save_dir,
                   n_iteration=n_iteration,
                   batch_size=batch_size,
                   print_every=print_every,
                   save_every=save_every,
                   clip=clip,
                   corpus_name=corpus_name,
                   loadFilename=loadFilename,
                   DICT_NAME=DICT_NAME,
                   checkpoint=None)
# Out:
# Building optimizers ...
# Starting Training!
# Initializing ...
# Training...
# Iteration: 1; Percent complete: 0.0%; Training loss: 9.6927; Validation loss: 8.8661
# Iteration: 2; Percent complete: 0.1%; Training loss: 8.6254; Validation loss: 8.6060
# Iteration: 3; Percent complete: 0.1%; Training loss: 8.3154; Validation loss: 8.4682
# Iteration: 4; Percent complete: 0.1%; Training loss: 8.0159; Validation loss: 8.1137
# Iteration: 5; Percent complete: 0.1%; Training loss: 7.8199; Validation loss: 8.1513
# Iteration: 6; Percent complete: 0.1%; Training loss: 7.4927; Validation loss: 7.9734
# Iteration: 7; Percent complete: 0.2%; Training loss: 7.3132; Validation loss: 7.7576
# Iteration: 8; Percent complete: 0.2%; Training loss: 6.8961; Validation loss: 7.9036
# Iteration: 9; Percent complete: 0.2%; Training loss: 6.9288; Validation loss: 7.8743
# Iteration: 10; Percent complete: 0.2%; Training loss: 6.9273; Validation loss: 7.6272
# Iteration: 11; Percent complete: 0.3%; Training loss: 6.6716; Validation loss: 7.5621
# Iteration: 12; Percent complete: 0.3%; Training loss: 6.6955; Validation loss: 7.4552
# Iteration: 13; Percent complete: 0.3%; Training loss: 6.4567; Validation loss: 7.4527
# Iteration: 14; Percent complete: 0.4%; Training loss: 6.2115; Validation loss: 7.3603
# Iteration: 15; Percent complete: 0.4%; Training loss: 5.9835; Validation loss: 7.3473
# Iteration: 16; Percent complete: 0.4%; Training loss: 6.0447; Validation loss: 7.2955
# Iteration: 17; Percent complete: 0.4%; Training loss: 5.8422; Validation loss: 7.1863
# Iteration: 18; Percent complete: 0.4%; Training loss: 5.6696; Validation loss: 7.1407
# Iteration: 19; Percent complete: 0.5%; Training loss: 5.6298; Validation loss: 7.4854
# Iteration: 20; Percent complete: 0.5%; Training loss: 5.8902; Validation loss: 7.4649
# Iteration: 21; Percent complete: 0.5%; Training loss: 5.7000; Validation loss: 7.4038
# Iteration: 22; Percent complete: 0.5%; Training loss: 5.6812; Validation loss: 7.3763
# Iteration: 23; Percent complete: 0.6%; Training loss: 5.6601; Validation loss: 7.6292
# Iteration: 24; Percent complete: 0.6%; Training loss: 5.4371; Validation loss: 7.1842
# Iteration: 25; Percent complete: 0.6%; Training loss: 5.4419; Validation loss: 7.5407
# Iteration: 26; Percent complete: 0.7%; Training loss: 5.4154; Validation loss: 7.5232
# Iteration: 27; Percent complete: 0.7%; Training loss: 5.7111; Validation loss: 7.0739
# Iteration: 28; Percent complete: 0.7%; Training loss: 5.2742; Validation loss: 7.3841
# Iteration: 29; Percent complete: 0.7%; Training loss: 5.2813; Validation loss: 7.2645
# Iteration: 30; Percent complete: 0.8%; Training loss: 5.0146; Validation loss: 7.3554
# Iteration: 31; Percent complete: 0.8%; Training loss: 5.4633; Validation loss: 7.5967
# Iteration: 32; Percent complete: 0.8%; Training loss: 5.4218; Validation loss: 7.7620
# Iteration: 33; Percent complete: 0.8%; Training loss: 5.4217; Validation loss: 7.1430
# Iteration: 34; Percent complete: 0.9%; Training loss: 5.4739; Validation loss: 7.5296
# Iteration: 35; Percent complete: 0.9%; Training loss: 5.3430; Validation loss: 7.5698
# Iteration: 36; Percent complete: 0.9%; Training loss: 5.1718; Validation loss: 7.0110
# Iteration: 37; Percent complete: 0.9%; Training loss: 4.9332; Validation loss: 7.4054
# Iteration: 38; Percent complete: 0.9%; Training loss: 5.3408; Validation loss: 7.5248
# Iteration: 39; Percent complete: 1.0%; Training loss: 5.5898; Validation loss: 7.3038
# Iteration: 40; Percent complete: 1.0%; Training loss: 5.6355; Validation loss: 7.2481
# Iteration: 41; Percent complete: 1.0%; Training loss: 5.5526; Validation loss: 7.4025
# Iteration: 42; Percent complete: 1.1%; Training loss: 5.2223; Validation loss: 7.5550
# Iteration: 43; Percent complete: 1.1%; Training loss: 5.3142; Validation loss: 7.7330
# Iteration: 44; Percent complete: 1.1%; Training loss: 5.2598; Validation loss: 7.3122
# Iteration: 45; Percent complete: 1.1%; Training loss: 5.4795; Validation loss: 7.2638
# Iteration: 46; Percent complete: 1.1%; Training loss: 5.3989; Validation loss: 7.5222
# Iteration: 47; Percent complete: 1.2%; Training loss: 5.3579; Validation loss: 7.5850
# Iteration: 48; Percent complete: 1.2%; Training loss: 5.5126; Validation loss: 7.4725
# Iteration: 49; Percent complete: 1.2%; Training loss: 5.5331; Validation loss: 7.5297
# Iteration: 50; Percent complete: 1.2%; Training loss: 5.4145; Validation loss: 7.3589
# Iteration: 51; Percent complete: 1.3%; Training loss: 5.2440; Validation loss: 7.4868
# Iteration: 52; Percent complete: 1.3%; Training loss: 5.6066; Validation loss: 7.4810
# Iteration: 53; Percent complete: 1.3%; Training loss: 5.1230; Validation loss: 7.3106
# Iteration: 54; Percent complete: 1.4%; Training loss: 5.3462; Validation loss: 7.4533
# Iteration: 55; Percent complete: 1.4%; Training loss: 5.5209; Validation loss: 7.5079
# Iteration: 56; Percent complete: 1.4%; Training loss: 5.2199; Validation loss: 7.4712
# Iteration: 57; Percent complete: 1.4%; Training loss: 5.4559; Validation loss: 7.3804
# Iteration: 58; Percent complete: 1.5%; Training loss: 5.2838; Validation loss: 7.6078
# Iteration: 59; Percent complete: 1.5%; Training loss: 5.4271; Validation loss: 7.6053
# Iteration: 60; Percent complete: 1.5%; Training loss: 4.9525; Validation loss: 7.4459
# Iteration: 61; Percent complete: 1.5%; Training loss: 5.2364; Validation loss: 7.5981
# Iteration: 62; Percent complete: 1.6%; Training loss: 5.4947; Validation loss: 7.7420
# Iteration: 63; Percent complete: 1.6%; Training loss: 5.3364; Validation loss: 7.4096
# Iteration: 64; Percent complete: 1.6%; Training loss: 5.4313; Validation loss: 7.4175
# Iteration: 65; Percent complete: 1.6%; Training loss: 5.3566; Validation loss: 7.2119
# Iteration: 66; Percent complete: 1.7%; Training loss: 5.1164; Validation loss: 7.5130
# Iteration: 67; Percent complete: 1.7%; Training loss: 5.3243; Validation loss: 7.3967
# Iteration: 68; Percent complete: 1.7%; Training loss: 5.3413; Validation loss: 7.1452
# Iteration: 69; Percent complete: 1.7%; Training loss: 5.2754; Validation loss: 7.8731
# Iteration: 70; Percent complete: 1.8%; Training loss: 5.1481; Validation loss: 7.1798
# Iteration: 71; Percent complete: 1.8%; Training loss: 5.3425; Validation loss: 7.3826
# Iteration: 72; Percent complete: 1.8%; Training loss: 4.9854; Validation loss: 7.3975
# Iteration: 73; Percent complete: 1.8%; Training loss: 5.2394; Validation loss: 7.6274
# Iteration: 74; Percent complete: 1.8%; Training loss: 5.2915; Validation loss: 7.6377
# Iteration: 75; Percent complete: 1.9%; Training loss: 5.3703; Validation loss: 7.6247
# Iteration: 76; Percent complete: 1.9%; Training loss: 5.5777; Validation loss: 7.0173
# Iteration: 77; Percent complete: 1.9%; Training loss: 5.2244; Validation loss: 7.4780
# Iteration: 78; Percent complete: 1.9%; Training loss: 5.2923; Validation loss: 7.3981
# Iteration: 79; Percent complete: 2.0%; Training loss: 5.3220; Validation loss: 7.4426
# Iteration: 80; Percent complete: 2.0%; Training loss: 5.3326; Validation loss: 7.5676
# Iteration: 81; Percent complete: 2.0%; Training loss: 5.3134; Validation loss: 7.8617
# Iteration: 82; Percent complete: 2.1%; Training loss: 5.2585; Validation loss: 7.6348
# Iteration: 83; Percent complete: 2.1%; Training loss: 5.5139; Validation loss: 7.3306
# Iteration: 84; Percent complete: 2.1%; Training loss: 5.4413; Validation loss: 7.5454
# Iteration: 85; Percent complete: 2.1%; Training loss: 5.4688; Validation loss: 7.4200
# Iteration: 86; Percent complete: 2.1%; Training loss: 5.0828; Validation loss: 7.5003
# Iteration: 87; Percent complete: 2.2%; Training loss: 5.3815; Validation loss: 7.3805
# Iteration: 88; Percent complete: 2.2%; Training loss: 5.1081; Validation loss: 7.2973
# Iteration: 89; Percent complete: 2.2%; Training loss: 5.3655; Validation loss: 7.4021
# Iteration: 90; Percent complete: 2.2%; Training loss: 5.4622; Validation loss: 7.1969
# Iteration: 91; Percent complete: 2.3%; Training loss: 5.3036; Validation loss: 7.6646
# Iteration: 92; Percent complete: 2.3%; Training loss: 5.3604; Validation loss: 7.5562
# Iteration: 93; Percent complete: 2.3%; Training loss: 5.2684; Validation loss: 7.4918
# Iteration: 94; Percent complete: 2.4%; Training loss: 5.3281; Validation loss: 7.4468
# Iteration: 95; Percent complete: 2.4%; Training loss: 5.2364; Validation loss: 7.4250
# Iteration: 96; Percent complete: 2.4%; Training loss: 5.2090; Validation loss: 7.5012
# Iteration: 97; Percent complete: 2.4%; Training loss: 5.1696; Validation loss: 7.4091
# Iteration: 98; Percent complete: 2.5%; Training loss: 5.2261; Validation loss: 7.4273
# Iteration: 99; Percent complete: 2.5%; Training loss: 5.3782; Validation loss: 7.4700
# Iteration: 100; Percent complete: 2.5%; Training loss: 5.1777; Validation loss: 7.3874
# Iteration: 101; Percent complete: 2.5%; Training loss: 5.2980; Validation loss: 7.3899
# Iteration: 102; Percent complete: 2.5%; Training loss: 5.3402; Validation loss: 7.3254
# Iteration: 103; Percent complete: 2.6%; Training loss: 5.2163; Validation loss: 7.7297
# Iteration: 104; Percent complete: 2.6%; Training loss: 5.2175; Validation loss: 7.5023
# Iteration: 105; Percent complete: 2.6%; Training loss: 5.3244; Validation loss: 7.5709
# Iteration: 106; Percent complete: 2.6%; Training loss: 5.2211; Validation loss: 7.4021
# Iteration: 107; Percent complete: 2.7%; Training loss: 5.2975; Validation loss: 7.3726
# Iteration: 108; Percent complete: 2.7%; Training loss: 5.1374; Validation loss: 7.3379
# Iteration: 109; Percent complete: 2.7%; Training loss: 5.0035; Validation loss: 7.2615
# Iteration: 110; Percent complete: 2.8%; Training loss: 5.0186; Validation loss: 7.2132
# Iteration: 111; Percent complete: 2.8%; Training loss: 5.3284; Validation loss: 7.4408
# Iteration: 112; Percent complete: 2.8%; Training loss: 5.2015; Validation loss: 7.3699
# Iteration: 113; Percent complete: 2.8%; Training loss: 5.2797; Validation loss: 7.2800
# Iteration: 114; Percent complete: 2.9%; Training loss: 5.4039; Validation loss: 7.0960
# Iteration: 115; Percent complete: 2.9%; Training loss: 5.3302; Validation loss: 7.9476
# Iteration: 116; Percent complete: 2.9%; Training loss: 5.2885; Validation loss: 7.1656
# Iteration: 117; Percent complete: 2.9%; Training loss: 5.3347; Validation loss: 7.3743
# Iteration: 118; Percent complete: 2.9%; Training loss: 5.1500; Validation loss: 7.4230
# Iteration: 119; Percent complete: 3.0%; Training loss: 5.2018; Validation loss: 7.6840
# Iteration: 120; Percent complete: 3.0%; Training loss: 5.1538; Validation loss: 7.2451
# Iteration: 121; Percent complete: 3.0%; Training loss: 5.4085; Validation loss: 7.7151
# Iteration: 122; Percent complete: 3.0%; Training loss: 5.3023; Validation loss: 7.3196
# Iteration: 123; Percent complete: 3.1%; Training loss: 5.2956; Validation loss: 7.1854
# Iteration: 124; Percent complete: 3.1%; Training loss: 5.1357; Validation loss: 7.2192
# Iteration: 125; Percent complete: 3.1%; Training loss: 5.4048; Validation loss: 7.6912
# Iteration: 126; Percent complete: 3.1%; Training loss: 5.1855; Validation loss: 7.4821
# Iteration: 127; Percent complete: 3.2%; Training loss: 5.1713; Validation loss: 7.2748
# Iteration: 128; Percent complete: 3.2%; Training loss: 5.1938; Validation loss: 7.4854
# Iteration: 129; Percent complete: 3.2%; Training loss: 5.3770; Validation loss: 7.4134
# Iteration: 130; Percent complete: 3.2%; Training loss: 4.8518; Validation loss: 7.0894
# Iteration: 131; Percent complete: 3.3%; Training loss: 5.3307; Validation loss: 7.5415
# Iteration: 132; Percent complete: 3.3%; Training loss: 5.0655; Validation loss: 7.4466
# Iteration: 133; Percent complete: 3.3%; Training loss: 5.0354; Validation loss: 7.2362
# Iteration: 134; Percent complete: 3.4%; Training loss: 5.2910; Validation loss: 6.8200
# Iteration: 135; Percent complete: 3.4%; Training loss: 5.2542; Validation loss: 7.1486
# Iteration: 136; Percent complete: 3.4%; Training loss: 5.3162; Validation loss: 7.1705
# Iteration: 137; Percent complete: 3.4%; Training loss: 5.1762; Validation loss: 7.1922
# Iteration: 138; Percent complete: 3.5%; Training loss: 5.1465; Validation loss: 7.5068
# Iteration: 139; Percent complete: 3.5%; Training loss: 5.0830; Validation loss: 7.5958
# Iteration: 140; Percent complete: 3.5%; Training loss: 5.3818; Validation loss: 7.2482
# Iteration: 141; Percent complete: 3.5%; Training loss: 5.5303; Validation loss: 7.5812
# Iteration: 142; Percent complete: 3.5%; Training loss: 5.4409; Validation loss: 7.1376
# Iteration: 143; Percent complete: 3.6%; Training loss: 5.3723; Validation loss: 7.4097
# Iteration: 144; Percent complete: 3.6%; Training loss: 5.1046; Validation loss: 7.5350
# Iteration: 145; Percent complete: 3.6%; Training loss: 5.0731; Validation loss: 7.5803
# Iteration: 146; Percent complete: 3.6%; Training loss: 4.9891; Validation loss: 7.1292
# Iteration: 147; Percent complete: 3.7%; Training loss: 5.3217; Validation loss: 7.4479
# Iteration: 148; Percent complete: 3.7%; Training loss: 5.2087; Validation loss: 7.5560
# Iteration: 149; Percent complete: 3.7%; Training loss: 5.0368; Validation loss: 7.2055
# Iteration: 150; Percent complete: 3.8%; Training loss: 5.0271; Validation loss: 7.2448
# Iteration: 151; Percent complete: 3.8%; Training loss: 5.1915; Validation loss: 7.1143
# Iteration: 152; Percent complete: 3.8%; Training loss: 5.0861; Validation loss: 7.5378
# Iteration: 153; Percent complete: 3.8%; Training loss: 5.3687; Validation loss: 7.5109
# Iteration: 154; Percent complete: 3.9%; Training loss: 5.0788; Validation loss: 7.4646
# Iteration: 155; Percent complete: 3.9%; Training loss: 5.2648; Validation loss: 7.3783
# Iteration: 156; Percent complete: 3.9%; Training loss: 4.8522; Validation loss: 7.3731
# Iteration: 157; Percent complete: 3.9%; Training loss: 5.1369; Validation loss: 7.5588
# Iteration: 158; Percent complete: 4.0%; Training loss: 5.1685; Validation loss: 7.2856
# Iteration: 159; Percent complete: 4.0%; Training loss: 5.4393; Validation loss: 7.3603
# Iteration: 160; Percent complete: 4.0%; Training loss: 5.0572; Validation loss: 7.3751
# Iteration: 161; Percent complete: 4.0%; Training loss: 5.3655; Validation loss: 7.4824
# Iteration: 162; Percent complete: 4.0%; Training loss: 5.5543; Validation loss: 7.5514
# Iteration: 163; Percent complete: 4.1%; Training loss: 5.2903; Validation loss: 7.1658
# Iteration: 164; Percent complete: 4.1%; Training loss: 5.2952; Validation loss: 7.6748
# Iteration: 165; Percent complete: 4.1%; Training loss: 4.9162; Validation loss: 7.4699
# Iteration: 166; Percent complete: 4.2%; Training loss: 5.1125; Validation loss: 7.4244
# Iteration: 167; Percent complete: 4.2%; Training loss: 5.2816; Validation loss: 7.6675
# Iteration: 168; Percent complete: 4.2%; Training loss: 5.1539; Validation loss: 7.5572
# Iteration: 169; Percent complete: 4.2%; Training loss: 5.4450; Validation loss: 7.3485
# Iteration: 170; Percent complete: 4.2%; Training loss: 5.0716; Validation loss: 7.3923
# Iteration: 171; Percent complete: 4.3%; Training loss: 5.2966; Validation loss: 6.9473
# Iteration: 172; Percent complete: 4.3%; Training loss: 4.9395; Validation loss: 7.5143
# Iteration: 173; Percent complete: 4.3%; Training loss: 5.1241; Validation loss: 7.3463
# Iteration: 174; Percent complete: 4.3%; Training loss: 5.4290; Validation loss: 7.4946
# Iteration: 175; Percent complete: 4.4%; Training loss: 5.3021; Validation loss: 7.3721
# Iteration: 176; Percent complete: 4.4%; Training loss: 5.2812; Validation loss: 7.7727
# Iteration: 177; Percent complete: 4.4%; Training loss: 5.3262; Validation loss: 7.5088
# Iteration: 178; Percent complete: 4.5%; Training loss: 5.2142; Validation loss: 7.5257
# Iteration: 179; Percent complete: 4.5%; Training loss: 5.1277; Validation loss: 7.4185
# Iteration: 180; Percent complete: 4.5%; Training loss: 5.3068; Validation loss: 7.3485
# Iteration: 181; Percent complete: 4.5%; Training loss: 4.9078; Validation loss: 7.5961
# Iteration: 182; Percent complete: 4.5%; Training loss: 4.9917; Validation loss: 7.1392
# Iteration: 183; Percent complete: 4.6%; Training loss: 5.1844; Validation loss: 7.3171
# Iteration: 184; Percent complete: 4.6%; Training loss: 4.9874; Validation loss: 7.3120
# Iteration: 185; Percent complete: 4.6%; Training loss: 5.3169; Validation loss: 7.2397
# Iteration: 186; Percent complete: 4.7%; Training loss: 5.0219; Validation loss: 7.1518
# Iteration: 187; Percent complete: 4.7%; Training loss: 5.2047; Validation loss: 7.3412
# Iteration: 188; Percent complete: 4.7%; Training loss: 5.2835; Validation loss: 7.3891
# Iteration: 189; Percent complete: 4.7%; Training loss: 5.1367; Validation loss: 7.3354
# Iteration: 190; Percent complete: 4.8%; Training loss: 5.2707; Validation loss: 7.6007
# Iteration: 191; Percent complete: 4.8%; Training loss: 5.2445; Validation loss: 7.5980
# Iteration: 192; Percent complete: 4.8%; Training loss: 5.2056; Validation loss: 7.6021
# Iteration: 193; Percent complete: 4.8%; Training loss: 5.1456; Validation loss: 7.1169
# Iteration: 194; Percent complete: 4.9%; Training loss: 5.2405; Validation loss: 7.4026
# Iteration: 195; Percent complete: 4.9%; Training loss: 5.2292; Validation loss: 7.6006
# Iteration: 196; Percent complete: 4.9%; Training loss: 5.0408; Validation loss: 7.4731
# Iteration: 197; Percent complete: 4.9%; Training loss: 5.1386; Validation loss: 7.5594
# Iteration: 198; Percent complete: 5.0%; Training loss: 5.3031; Validation loss: 7.6250
# Iteration: 199; Percent complete: 5.0%; Training loss: 5.1498; Validation loss: 7.5452
# Iteration: 200; Percent complete: 5.0%; Training loss: 5.1174; Validation loss: 7.1607
# Iteration: 201; Percent complete: 5.0%; Training loss: 5.2292; Validation loss: 7.4229
# Iteration: 202; Percent complete: 5.1%; Training loss: 5.2319; Validation loss: 7.5263
# Iteration: 203; Percent complete: 5.1%; Training loss: 5.0927; Validation loss: 7.5490
# Iteration: 204; Percent complete: 5.1%; Training loss: 5.0567; Validation loss: 7.2845
# Iteration: 205; Percent complete: 5.1%; Training loss: 5.2522; Validation loss: 7.4525
# Iteration: 206; Percent complete: 5.1%; Training loss: 5.1511; Validation loss: 7.4539
# Iteration: 207; Percent complete: 5.2%; Training loss: 5.2415; Validation loss: 7.2290
# Iteration: 208; Percent complete: 5.2%; Training loss: 4.9560; Validation loss: 7.5874
# Iteration: 209; Percent complete: 5.2%; Training loss: 5.4602; Validation loss: 7.2364
# Iteration: 210; Percent complete: 5.2%; Training loss: 5.2453; Validation loss: 7.4006
# Iteration: 211; Percent complete: 5.3%; Training loss: 4.9182; Validation loss: 7.5114
# Iteration: 212; Percent complete: 5.3%; Training loss: 5.4885; Validation loss: 7.6819
# Iteration: 213; Percent complete: 5.3%; Training loss: 5.2093; Validation loss: 7.5261
# Iteration: 214; Percent complete: 5.3%; Training loss: 4.8670; Validation loss: 7.3358
# Iteration: 215; Percent complete: 5.4%; Training loss: 5.2437; Validation loss: 7.3817
# Iteration: 216; Percent complete: 5.4%; Training loss: 4.9657; Validation loss: 7.5014
# Iteration: 217; Percent complete: 5.4%; Training loss: 5.0581; Validation loss: 7.4188
# Iteration: 218; Percent complete: 5.5%; Training loss: 5.3024; Validation loss: 7.1917
# Iteration: 219; Percent complete: 5.5%; Training loss: 5.2503; Validation loss: 7.3469
# Iteration: 220; Percent complete: 5.5%; Training loss: 5.2571; Validation loss: 7.2172
# Iteration: 221; Percent complete: 5.5%; Training loss: 4.9811; Validation loss: 7.5470
# Iteration: 222; Percent complete: 5.5%; Training loss: 5.0882; Validation loss: 7.4690
# Iteration: 223; Percent complete: 5.6%; Training loss: 5.1489; Validation loss: 7.5880
# Iteration: 224; Percent complete: 5.6%; Training loss: 5.2246; Validation loss: 7.1734
# Iteration: 225; Percent complete: 5.6%; Training loss: 5.1460; Validation loss: 7.6539
# Iteration: 226; Percent complete: 5.7%; Training loss: 4.9926; Validation loss: 7.2069
# Iteration: 227; Percent complete: 5.7%; Training loss: 5.1319; Validation loss: 7.6920
# Iteration: 228; Percent complete: 5.7%; Training loss: 5.1280; Validation loss: 7.3898
# Iteration: 229; Percent complete: 5.7%; Training loss: 5.4347; Validation loss: 7.1501
# Iteration: 230; Percent complete: 5.8%; Training loss: 5.4958; Validation loss: 7.2786
# Iteration: 231; Percent complete: 5.8%; Training loss: 5.2042; Validation loss: 7.2392
# Iteration: 232; Percent complete: 5.8%; Training loss: 5.4046; Validation loss: 7.5866
# Iteration: 233; Percent complete: 5.8%; Training loss: 5.0710; Validation loss: 7.2605
# Iteration: 234; Percent complete: 5.9%; Training loss: 5.2332; Validation loss: 7.3943
# Iteration: 235; Percent complete: 5.9%; Training loss: 5.1590; Validation loss: 7.2000
# Iteration: 236; Percent complete: 5.9%; Training loss: 5.1799; Validation loss: 7.3412
# Iteration: 237; Percent complete: 5.9%; Training loss: 4.9893; Validation loss: 7.5155
# Iteration: 238; Percent complete: 5.9%; Training loss: 5.3643; Validation loss: 7.7374
# Iteration: 239; Percent complete: 6.0%; Training loss: 5.1664; Validation loss: 7.2111
# Iteration: 240; Percent complete: 6.0%; Training loss: 5.0082; Validation loss: 7.4056
# Iteration: 241; Percent complete: 6.0%; Training loss: 5.0514; Validation loss: 7.5044
# Iteration: 242; Percent complete: 6.0%; Training loss: 4.8499; Validation loss: 7.5097
# Iteration: 243; Percent complete: 6.1%; Training loss: 4.9191; Validation loss: 7.1924
# Iteration: 244; Percent complete: 6.1%; Training loss: 5.2704; Validation loss: 7.4023
# Iteration: 245; Percent complete: 6.1%; Training loss: 5.3124; Validation loss: 7.2101
# Iteration: 246; Percent complete: 6.2%; Training loss: 4.9947; Validation loss: 7.6026
# Iteration: 247; Percent complete: 6.2%; Training loss: 5.0737; Validation loss: 7.2826
# Iteration: 248; Percent complete: 6.2%; Training loss: 5.3206; Validation loss: 7.2461
# Iteration: 249; Percent complete: 6.2%; Training loss: 4.9873; Validation loss: 7.4963
# Iteration: 250; Percent complete: 6.2%; Training loss: 5.0110; Validation loss: 7.4388
# Iteration: 251; Percent complete: 6.3%; Training loss: 5.1878; Validation loss: 7.5698
# Iteration: 252; Percent complete: 6.3%; Training loss: 5.2329; Validation loss: 7.3134
# Iteration: 253; Percent complete: 6.3%; Training loss: 4.8570; Validation loss: 7.2054
# Iteration: 254; Percent complete: 6.3%; Training loss: 5.3367; Validation loss: 7.5547
# Iteration: 255; Percent complete: 6.4%; Training loss: 5.1825; Validation loss: 7.3373
# Iteration: 256; Percent complete: 6.4%; Training loss: 5.2248; Validation loss: 7.7240
# Iteration: 257; Percent complete: 6.4%; Training loss: 5.2055; Validation loss: 7.4236
# Iteration: 258; Percent complete: 6.5%; Training loss: 5.3456; Validation loss: 7.3127
# Iteration: 259; Percent complete: 6.5%; Training loss: 5.3510; Validation loss: 7.5666
# Iteration: 260; Percent complete: 6.5%; Training loss: 5.4010; Validation loss: 7.5221
# Iteration: 261; Percent complete: 6.5%; Training loss: 5.0721; Validation loss: 7.2950
# Iteration: 262; Percent complete: 6.6%; Training loss: 5.1832; Validation loss: 7.4790
# Iteration: 263; Percent complete: 6.6%; Training loss: 5.2427; Validation loss: 7.1436
# Iteration: 264; Percent complete: 6.6%; Training loss: 5.4250; Validation loss: 7.4798
# Iteration: 265; Percent complete: 6.6%; Training loss: 5.1086; Validation loss: 7.3256
# Iteration: 266; Percent complete: 6.7%; Training loss: 5.2825; Validation loss: 7.6647
# Iteration: 267; Percent complete: 6.7%; Training loss: 5.0479; Validation loss: 7.3748
# Iteration: 268; Percent complete: 6.7%; Training loss: 5.1769; Validation loss: 7.2743
# Iteration: 269; Percent complete: 6.7%; Training loss: 5.1077; Validation loss: 7.6196
# Iteration: 270; Percent complete: 6.8%; Training loss: 5.0513; Validation loss: 7.3616
# Iteration: 271; Percent complete: 6.8%; Training loss: 5.0575; Validation loss: 7.2485
# Iteration: 272; Percent complete: 6.8%; Training loss: 5.1673; Validation loss: 7.4935
# Iteration: 273; Percent complete: 6.8%; Training loss: 5.4642; Validation loss: 7.8338
# Iteration: 274; Percent complete: 6.9%; Training loss: 4.9260; Validation loss: 7.5228
# Iteration: 275; Percent complete: 6.9%; Training loss: 5.2244; Validation loss: 7.5915
# Iteration: 276; Percent complete: 6.9%; Training loss: 5.2129; Validation loss: 7.7214
# Iteration: 277; Percent complete: 6.9%; Training loss: 5.2962; Validation loss: 7.3201
# Iteration: 278; Percent complete: 7.0%; Training loss: 5.2122; Validation loss: 7.4145
# Iteration: 279; Percent complete: 7.0%; Training loss: 5.1686; Validation loss: 7.1868
# Iteration: 280; Percent complete: 7.0%; Training loss: 5.2127; Validation loss: 7.6896
# Iteration: 281; Percent complete: 7.0%; Training loss: 5.1181; Validation loss: 7.4108
# Iteration: 282; Percent complete: 7.0%; Training loss: 5.0120; Validation loss: 7.3757
# Iteration: 283; Percent complete: 7.1%; Training loss: 5.2175; Validation loss: 7.1665
# Iteration: 284; Percent complete: 7.1%; Training loss: 5.3610; Validation loss: 7.6339
# Iteration: 285; Percent complete: 7.1%; Training loss: 5.1982; Validation loss: 7.1342
# Iteration: 286; Percent complete: 7.1%; Training loss: 5.0943; Validation loss: 7.5156
# Iteration: 287; Percent complete: 7.2%; Training loss: 5.3101; Validation loss: 7.3877
# Iteration: 288; Percent complete: 7.2%; Training loss: 5.4109; Validation loss: 7.5594
# Iteration: 289; Percent complete: 7.2%; Training loss: 5.3191; Validation loss: 7.4714
# Iteration: 290; Percent complete: 7.2%; Training loss: 5.2106; Validation loss: 7.4162
# Iteration: 291; Percent complete: 7.3%; Training loss: 5.0473; Validation loss: 7.3196
# Iteration: 292; Percent complete: 7.3%; Training loss: 5.1000; Validation loss: 7.5980
# Iteration: 293; Percent complete: 7.3%; Training loss: 5.2228; Validation loss: 7.4368
# Iteration: 294; Percent complete: 7.3%; Training loss: 5.1325; Validation loss: 7.3275
# Iteration: 295; Percent complete: 7.4%; Training loss: 5.1854; Validation loss: 7.6276
# Iteration: 296; Percent complete: 7.4%; Training loss: 5.2726; Validation loss: 7.4364
# Iteration: 297; Percent complete: 7.4%; Training loss: 5.1884; Validation loss: 7.5543
# Iteration: 298; Percent complete: 7.4%; Training loss: 5.3024; Validation loss: 7.4093
# Iteration: 299; Percent complete: 7.5%; Training loss: 5.0095; Validation loss: 7.3410
# Iteration: 300; Percent complete: 7.5%; Training loss: 5.1985; Validation loss: 7.3185
# Iteration: 301; Percent complete: 7.5%; Training loss: 5.0495; Validation loss: 7.2341
# Iteration: 302; Percent complete: 7.5%; Training loss: 5.1508; Validation loss: 7.4225
# Iteration: 303; Percent complete: 7.6%; Training loss: 5.2429; Validation loss: 7.4390
# Iteration: 304; Percent complete: 7.6%; Training loss: 5.0015; Validation loss: 7.7567
# Iteration: 305; Percent complete: 7.6%; Training loss: 4.9756; Validation loss: 7.5764
# Iteration: 306; Percent complete: 7.6%; Training loss: 5.1013; Validation loss: 7.4645
# Iteration: 307; Percent complete: 7.7%; Training loss: 4.5093; Validation loss: 7.3037
# Iteration: 308; Percent complete: 7.7%; Training loss: 5.2564; Validation loss: 7.3670
# Iteration: 309; Percent complete: 7.7%; Training loss: 5.0075; Validation loss: 7.6987
# Iteration: 310; Percent complete: 7.8%; Training loss: 5.1029; Validation loss: 7.2512
# Iteration: 311; Percent complete: 7.8%; Training loss: 5.1288; Validation loss: 7.3931
# Iteration: 312; Percent complete: 7.8%; Training loss: 5.0823; Validation loss: 7.3879
# Iteration: 313; Percent complete: 7.8%; Training loss: 5.1290; Validation loss: 7.3150
# Iteration: 314; Percent complete: 7.8%; Training loss: 4.9607; Validation loss: 7.6700
# Iteration: 315; Percent complete: 7.9%; Training loss: 5.3119; Validation loss: 7.1825
# Iteration: 316; Percent complete: 7.9%; Training loss: 4.7757; Validation loss: 7.0143
# Iteration: 317; Percent complete: 7.9%; Training loss: 5.0798; Validation loss: 7.1800
# Iteration: 318; Percent complete: 8.0%; Training loss: 5.2616; Validation loss: 7.4222
# Iteration: 319; Percent complete: 8.0%; Training loss: 5.1871; Validation loss: 7.4795
# Iteration: 320; Percent complete: 8.0%; Training loss: 5.3165; Validation loss: 7.4970
# Iteration: 321; Percent complete: 8.0%; Training loss: 5.1165; Validation loss: 6.9738
# Iteration: 322; Percent complete: 8.1%; Training loss: 5.3579; Validation loss: 7.5307
# Iteration: 323; Percent complete: 8.1%; Training loss: 5.1647; Validation loss: 7.2722
# Iteration: 324; Percent complete: 8.1%; Training loss: 5.2850; Validation loss: 6.9546
# Iteration: 325; Percent complete: 8.1%; Training loss: 5.2534; Validation loss: 7.2428
# Iteration: 326; Percent complete: 8.2%; Training loss: 5.0286; Validation loss: 7.5667
# Iteration: 327; Percent complete: 8.2%; Training loss: 5.4751; Validation loss: 7.6065
# Iteration: 328; Percent complete: 8.2%; Training loss: 5.2957; Validation loss: 6.9730
# Iteration: 329; Percent complete: 8.2%; Training loss: 4.7701; Validation loss: 7.3699
# Iteration: 330; Percent complete: 8.2%; Training loss: 4.9502; Validation loss: 7.2663
# Iteration: 331; Percent complete: 8.3%; Training loss: 5.1359; Validation loss: 7.2182
# Iteration: 332; Percent complete: 8.3%; Training loss: 5.0670; Validation loss: 7.0579
# Iteration: 333; Percent complete: 8.3%; Training loss: 5.1811; Validation loss: 7.2530
# Iteration: 334; Percent complete: 8.3%; Training loss: 5.3080; Validation loss: 7.2573
# Iteration: 335; Percent complete: 8.4%; Training loss: 5.1140; Validation loss: 7.0875
# Iteration: 336; Percent complete: 8.4%; Training loss: 5.1539; Validation loss: 7.6751
# Iteration: 337; Percent complete: 8.4%; Training loss: 5.1665; Validation loss: 7.1651
# Iteration: 338; Percent complete: 8.5%; Training loss: 4.8757; Validation loss: 7.0942
# Iteration: 339; Percent complete: 8.5%; Training loss: 5.0118; Validation loss: 7.5381
# Iteration: 340; Percent complete: 8.5%; Training loss: 5.1900; Validation loss: 7.3642
# Iteration: 341; Percent complete: 8.5%; Training loss: 5.1312; Validation loss: 7.3018
# Iteration: 342; Percent complete: 8.6%; Training loss: 5.1267; Validation loss: 7.6585
# Iteration: 343; Percent complete: 8.6%; Training loss: 5.2488; Validation loss: 7.1348
# Iteration: 344; Percent complete: 8.6%; Training loss: 5.1447; Validation loss: 7.5339
# Iteration: 345; Percent complete: 8.6%; Training loss: 5.0650; Validation loss: 7.4715
# Iteration: 346; Percent complete: 8.6%; Training loss: 4.9429; Validation loss: 7.1464
# Iteration: 347; Percent complete: 8.7%; Training loss: 5.1982; Validation loss: 7.5875
# Iteration: 348; Percent complete: 8.7%; Training loss: 5.1924; Validation loss: 7.1771
# Iteration: 349; Percent complete: 8.7%; Training loss: 5.0775; Validation loss: 7.4877
# Iteration: 350; Percent complete: 8.8%; Training loss: 5.1567; Validation loss: 7.6623
# Iteration: 351; Percent complete: 8.8%; Training loss: 5.2732; Validation loss: 7.8968
# Iteration: 352; Percent complete: 8.8%; Training loss: 4.9373; Validation loss: 7.2216
# Iteration: 353; Percent complete: 8.8%; Training loss: 4.9716; Validation loss: 7.4343
# Iteration: 354; Percent complete: 8.8%; Training loss: 5.2728; Validation loss: 7.7559
# Iteration: 355; Percent complete: 8.9%; Training loss: 5.0775; Validation loss: 7.2294
# Iteration: 356; Percent complete: 8.9%; Training loss: 4.9490; Validation loss: 7.4027
# Iteration: 357; Percent complete: 8.9%; Training loss: 5.4314; Validation loss: 7.3412
# Iteration: 358; Percent complete: 8.9%; Training loss: 4.9269; Validation loss: 7.2491
# Iteration: 359; Percent complete: 9.0%; Training loss: 5.1108; Validation loss: 7.4457
# Iteration: 360; Percent complete: 9.0%; Training loss: 5.0449; Validation loss: 7.4777
# Iteration: 361; Percent complete: 9.0%; Training loss: 5.2973; Validation loss: 7.3901
# Iteration: 362; Percent complete: 9.0%; Training loss: 5.2637; Validation loss: 7.1440
# Iteration: 363; Percent complete: 9.1%; Training loss: 5.0876; Validation loss: 7.3977
# Iteration: 364; Percent complete: 9.1%; Training loss: 5.2122; Validation loss: 7.0734
# Iteration: 365; Percent complete: 9.1%; Training loss: 5.1648; Validation loss: 7.4672
# Iteration: 366; Percent complete: 9.2%; Training loss: 5.2459; Validation loss: 7.4489
# Iteration: 367; Percent complete: 9.2%; Training loss: 4.9000; Validation loss: 7.4806
# Iteration: 368; Percent complete: 9.2%; Training loss: 5.2298; Validation loss: 7.2610
# Iteration: 369; Percent complete: 9.2%; Training loss: 5.2701; Validation loss: 7.5215
# Iteration: 370; Percent complete: 9.2%; Training loss: 5.2507; Validation loss: 7.6258
# Iteration: 371; Percent complete: 9.3%; Training loss: 5.2359; Validation loss: 7.4651
# Iteration: 372; Percent complete: 9.3%; Training loss: 5.2018; Validation loss: 7.4760
# Iteration: 373; Percent complete: 9.3%; Training loss: 5.1110; Validation loss: 7.5260
# Iteration: 374; Percent complete: 9.3%; Training loss: 5.0796; Validation loss: 7.3892
# Iteration: 375; Percent complete: 9.4%; Training loss: 5.2421; Validation loss: 7.0365
# Iteration: 376; Percent complete: 9.4%; Training loss: 4.6870; Validation loss: 7.3627
# Iteration: 377; Percent complete: 9.4%; Training loss: 5.0798; Validation loss: 8.0044
# Iteration: 378; Percent complete: 9.4%; Training loss: 5.0848; Validation loss: 7.4018
# Iteration: 379; Percent complete: 9.5%; Training loss: 4.9132; Validation loss: 7.3522
# Iteration: 380; Percent complete: 9.5%; Training loss: 5.0442; Validation loss: 7.3090
# Iteration: 381; Percent complete: 9.5%; Training loss: 4.9532; Validation loss: 7.5244
# Iteration: 382; Percent complete: 9.6%; Training loss: 5.3752; Validation loss: 7.2984
# Iteration: 383; Percent complete: 9.6%; Training loss: 5.4404; Validation loss: 7.5133
# Iteration: 384; Percent complete: 9.6%; Training loss: 4.9760; Validation loss: 7.3942
# Iteration: 385; Percent complete: 9.6%; Training loss: 5.0143; Validation loss: 7.5660
# Iteration: 386; Percent complete: 9.7%; Training loss: 5.1966; Validation loss: 7.3180
# Iteration: 387; Percent complete: 9.7%; Training loss: 5.2436; Validation loss: 7.4537
# Iteration: 388; Percent complete: 9.7%; Training loss: 5.0836; Validation loss: 7.4817
# Iteration: 389; Percent complete: 9.7%; Training loss: 5.0483; Validation loss: 7.6227
# Iteration: 390; Percent complete: 9.8%; Training loss: 5.3567; Validation loss: 7.3444
# Iteration: 391; Percent complete: 9.8%; Training loss: 5.2641; Validation loss: 7.2347
# Iteration: 392; Percent complete: 9.8%; Training loss: 5.3257; Validation loss: 7.9964
# Iteration: 393; Percent complete: 9.8%; Training loss: 4.9640; Validation loss: 7.4755
# Iteration: 394; Percent complete: 9.8%; Training loss: 5.5587; Validation loss: 7.3222
# Iteration: 395; Percent complete: 9.9%; Training loss: 5.1860; Validation loss: 7.1273
# Iteration: 396; Percent complete: 9.9%; Training loss: 5.1957; Validation loss: 7.3190
# Iteration: 397; Percent complete: 9.9%; Training loss: 5.3902; Validation loss: 7.5652
# Iteration: 398; Percent complete: 10.0%; Training loss: 5.1704; Validation loss: 7.4012
# Iteration: 399; Percent complete: 10.0%; Training loss: 4.9420; Validation loss: 7.3491
# Iteration: 400; Percent complete: 10.0%; Training loss: 5.1766; Validation loss: 7.2890
# Iteration: 401; Percent complete: 10.0%; Training loss: 5.1821; Validation loss: 7.0900
# Iteration: 402; Percent complete: 10.1%; Training loss: 4.9996; Validation loss: 7.2721
# Iteration: 403; Percent complete: 10.1%; Training loss: 5.0460; Validation loss: 7.3483
# Iteration: 404; Percent complete: 10.1%; Training loss: 5.0244; Validation loss: 7.6457
# Iteration: 405; Percent complete: 10.1%; Training loss: 4.9104; Validation loss: 7.0302
# Iteration: 406; Percent complete: 10.2%; Training loss: 5.3479; Validation loss: 7.2588
# Iteration: 407; Percent complete: 10.2%; Training loss: 5.3097; Validation loss: 7.6114
# Iteration: 408; Percent complete: 10.2%; Training loss: 5.3531; Validation loss: 7.4593
# Iteration: 409; Percent complete: 10.2%; Training loss: 5.2286; Validation loss: 7.4605
# Iteration: 410; Percent complete: 10.2%; Training loss: 5.0661; Validation loss: 7.3512
# Iteration: 411; Percent complete: 10.3%; Training loss: 5.0686; Validation loss: 7.7980
# Iteration: 412; Percent complete: 10.3%; Training loss: 5.2563; Validation loss: 7.3904
# Iteration: 413; Percent complete: 10.3%; Training loss: 5.1174; Validation loss: 7.3335
# Iteration: 414; Percent complete: 10.3%; Training loss: 5.1189; Validation loss: 7.6699
# Iteration: 415; Percent complete: 10.4%; Training loss: 4.8287; Validation loss: 7.5770
# Iteration: 416; Percent complete: 10.4%; Training loss: 5.2786; Validation loss: 7.5668
# Iteration: 417; Percent complete: 10.4%; Training loss: 5.1532; Validation loss: 7.4075
# Iteration: 418; Percent complete: 10.4%; Training loss: 5.0739; Validation loss: 7.0488
# Iteration: 419; Percent complete: 10.5%; Training loss: 5.1492; Validation loss: 7.7212
# Iteration: 420; Percent complete: 10.5%; Training loss: 5.0641; Validation loss: 7.6482
# Iteration: 421; Percent complete: 10.5%; Training loss: 5.2125; Validation loss: 7.3013
# Iteration: 422; Percent complete: 10.5%; Training loss: 5.1261; Validation loss: 7.6552
# Iteration: 423; Percent complete: 10.6%; Training loss: 5.3583; Validation loss: 7.3806
# Iteration: 424; Percent complete: 10.6%; Training loss: 5.0095; Validation loss: 7.4719
# Iteration: 425; Percent complete: 10.6%; Training loss: 5.2040; Validation loss: 7.3731
# Iteration: 426; Percent complete: 10.7%; Training loss: 5.0378; Validation loss: 7.5529
# Iteration: 427; Percent complete: 10.7%; Training loss: 5.1423; Validation loss: 7.2202
# Iteration: 428; Percent complete: 10.7%; Training loss: 5.0758; Validation loss: 7.1288
# Iteration: 429; Percent complete: 10.7%; Training loss: 5.3200; Validation loss: 7.4885
# Iteration: 430; Percent complete: 10.8%; Training loss: 5.2349; Validation loss: 7.6118
# Iteration: 431; Percent complete: 10.8%; Training loss: 5.0827; Validation loss: 7.8894
# Iteration: 432; Percent complete: 10.8%; Training loss: 5.1387; Validation loss: 7.4747
# Iteration: 433; Percent complete: 10.8%; Training loss: 5.0538; Validation loss: 7.4676
# Iteration: 434; Percent complete: 10.8%; Training loss: 5.2537; Validation loss: 7.3395
# Iteration: 435; Percent complete: 10.9%; Training loss: 4.9148; Validation loss: 7.4780
# Iteration: 436; Percent complete: 10.9%; Training loss: 5.2808; Validation loss: 7.1909
# Iteration: 437; Percent complete: 10.9%; Training loss: 4.9473; Validation loss: 7.3023
# Iteration: 438; Percent complete: 10.9%; Training loss: 5.1058; Validation loss: 7.2666
# Iteration: 439; Percent complete: 11.0%; Training loss: 5.2272; Validation loss: 7.5301
# Iteration: 440; Percent complete: 11.0%; Training loss: 5.1795; Validation loss: 7.2343
# Iteration: 441; Percent complete: 11.0%; Training loss: 5.1458; Validation loss: 7.4549
# Iteration: 442; Percent complete: 11.1%; Training loss: 5.2599; Validation loss: 7.3287
# Iteration: 443; Percent complete: 11.1%; Training loss: 5.3069; Validation loss: 7.4884
# Iteration: 444; Percent complete: 11.1%; Training loss: 5.0930; Validation loss: 7.2351
# Iteration: 445; Percent complete: 11.1%; Training loss: 5.0152; Validation loss: 7.1279
# Iteration: 446; Percent complete: 11.2%; Training loss: 4.9617; Validation loss: 7.1401
# Iteration: 447; Percent complete: 11.2%; Training loss: 5.1438; Validation loss: 7.5813
# Iteration: 448; Percent complete: 11.2%; Training loss: 4.9867; Validation loss: 7.4429
# Iteration: 449; Percent complete: 11.2%; Training loss: 5.2290; Validation loss: 7.5953
# Iteration: 450; Percent complete: 11.2%; Training loss: 5.2210; Validation loss: 7.6592
# Iteration: 451; Percent complete: 11.3%; Training loss: 5.0392; Validation loss: 7.3189
# Iteration: 452; Percent complete: 11.3%; Training loss: 5.1430; Validation loss: 7.7659
# Iteration: 453; Percent complete: 11.3%; Training loss: 5.1932; Validation loss: 7.4675
# Iteration: 454; Percent complete: 11.3%; Training loss: 5.2550; Validation loss: 7.3701
# Iteration: 455; Percent complete: 11.4%; Training loss: 5.0134; Validation loss: 7.2677
# Iteration: 456; Percent complete: 11.4%; Training loss: 5.0737; Validation loss: 7.5760
# Iteration: 457; Percent complete: 11.4%; Training loss: 5.1002; Validation loss: 7.3835
# Iteration: 458; Percent complete: 11.5%; Training loss: 5.1094; Validation loss: 7.3492
# Iteration: 459; Percent complete: 11.5%; Training loss: 5.0674; Validation loss: 8.0540
# Iteration: 460; Percent complete: 11.5%; Training loss: 5.3283; Validation loss: 7.3163
# Iteration: 461; Percent complete: 11.5%; Training loss: 5.2378; Validation loss: 7.6663
# Iteration: 462; Percent complete: 11.6%; Training loss: 5.0544; Validation loss: 7.3755
# Iteration: 463; Percent complete: 11.6%; Training loss: 5.0631; Validation loss: 7.7122
# Iteration: 464; Percent complete: 11.6%; Training loss: 5.1268; Validation loss: 7.3461
# Iteration: 465; Percent complete: 11.6%; Training loss: 5.3350; Validation loss: 7.5625
# Iteration: 466; Percent complete: 11.7%; Training loss: 4.9884; Validation loss: 7.4883
# Iteration: 467; Percent complete: 11.7%; Training loss: 5.0551; Validation loss: 7.6287
# Iteration: 468; Percent complete: 11.7%; Training loss: 5.1994; Validation loss: 7.4186
# Iteration: 469; Percent complete: 11.7%; Training loss: 5.3584; Validation loss: 7.6437
# Iteration: 470; Percent complete: 11.8%; Training loss: 5.0929; Validation loss: 7.3424
# Iteration: 471; Percent complete: 11.8%; Training loss: 5.2298; Validation loss: 7.3946
# Iteration: 472; Percent complete: 11.8%; Training loss: 5.2437; Validation loss: 7.4610
# Iteration: 473; Percent complete: 11.8%; Training loss: 5.1072; Validation loss: 7.5410
# Iteration: 474; Percent complete: 11.8%; Training loss: 5.1291; Validation loss: 7.3893
# Iteration: 475; Percent complete: 11.9%; Training loss: 5.2868; Validation loss: 7.2834
# Iteration: 476; Percent complete: 11.9%; Training loss: 5.2893; Validation loss: 7.4271
# Iteration: 477; Percent complete: 11.9%; Training loss: 5.0142; Validation loss: 7.3244
# Iteration: 478; Percent complete: 11.9%; Training loss: 5.1621; Validation loss: 7.5597
# Iteration: 479; Percent complete: 12.0%; Training loss: 5.1121; Validation loss: 7.1480
# Iteration: 480; Percent complete: 12.0%; Training loss: 5.0893; Validation loss: 7.3249
# Iteration: 481; Percent complete: 12.0%; Training loss: 5.2408; Validation loss: 7.4402
# Iteration: 482; Percent complete: 12.0%; Training loss: 4.9457; Validation loss: 7.2752
# Iteration: 483; Percent complete: 12.1%; Training loss: 5.2220; Validation loss: 7.5828
# Iteration: 484; Percent complete: 12.1%; Training loss: 5.2305; Validation loss: 7.4100
# Iteration: 485; Percent complete: 12.1%; Training loss: 5.3501; Validation loss: 7.4408
# Iteration: 486; Percent complete: 12.2%; Training loss: 5.2813; Validation loss: 7.5012
# Iteration: 487; Percent complete: 12.2%; Training loss: 5.0520; Validation loss: 7.3559
# Iteration: 488; Percent complete: 12.2%; Training loss: 5.1043; Validation loss: 7.3946
# Iteration: 489; Percent complete: 12.2%; Training loss: 4.9987; Validation loss: 7.3310
# Iteration: 490; Percent complete: 12.2%; Training loss: 5.0853; Validation loss: 7.2918
# Iteration: 491; Percent complete: 12.3%; Training loss: 5.0092; Validation loss: 7.4512
# Iteration: 492; Percent complete: 12.3%; Training loss: 5.0867; Validation loss: 7.3804
# Iteration: 493; Percent complete: 12.3%; Training loss: 5.2097; Validation loss: 7.4463
# Iteration: 494; Percent complete: 12.3%; Training loss: 4.9449; Validation loss: 7.3641
# Iteration: 495; Percent complete: 12.4%; Training loss: 5.2050; Validation loss: 7.4524
# Iteration: 496; Percent complete: 12.4%; Training loss: 5.3496; Validation loss: 7.5156
# Iteration: 497; Percent complete: 12.4%; Training loss: 5.2607; Validation loss: 7.3580
# Iteration: 498; Percent complete: 12.4%; Training loss: 5.1425; Validation loss: 6.9815
# Iteration: 499; Percent complete: 12.5%; Training loss: 5.2457; Validation loss: 7.3503
# Iteration: 500; Percent complete: 12.5%; Training loss: 5.1780; Validation loss: 7.2872
# Iteration: 501; Percent complete: 12.5%; Training loss: 5.4297; Validation loss: 7.7023
# Iteration: 502; Percent complete: 12.6%; Training loss: 5.1472; Validation loss: 7.3219
# Iteration: 503; Percent complete: 12.6%; Training loss: 5.1608; Validation loss: 7.4331
# Iteration: 504; Percent complete: 12.6%; Training loss: 4.9115; Validation loss: 7.6282
# Iteration: 505; Percent complete: 12.6%; Training loss: 5.0850; Validation loss: 7.5808
# Iteration: 506; Percent complete: 12.7%; Training loss: 4.9794; Validation loss: 7.6558
# Iteration: 507; Percent complete: 12.7%; Training loss: 5.2045; Validation loss: 7.2657
# Iteration: 508; Percent complete: 12.7%; Training loss: 5.1178; Validation loss: 7.2851
# Iteration: 509; Percent complete: 12.7%; Training loss: 5.1636; Validation loss: 7.3891
# Iteration: 510; Percent complete: 12.8%; Training loss: 5.5503; Validation loss: 7.1456
# Iteration: 511; Percent complete: 12.8%; Training loss: 5.1532; Validation loss: 7.3796
# Iteration: 512; Percent complete: 12.8%; Training loss: 5.2082; Validation loss: 7.1976
# Iteration: 513; Percent complete: 12.8%; Training loss: 5.0678; Validation loss: 7.6007
# Iteration: 514; Percent complete: 12.8%; Training loss: 5.1029; Validation loss: 7.3702
# Iteration: 515; Percent complete: 12.9%; Training loss: 4.8961; Validation loss: 7.7536
# Iteration: 516; Percent complete: 12.9%; Training loss: 5.2435; Validation loss: 7.7139
# Iteration: 517; Percent complete: 12.9%; Training loss: 5.0706; Validation loss: 7.5890
# Iteration: 518; Percent complete: 13.0%; Training loss: 5.0159; Validation loss: 7.5272
# Iteration: 519; Percent complete: 13.0%; Training loss: 5.0228; Validation loss: 7.4628
# Iteration: 520; Percent complete: 13.0%; Training loss: 5.1207; Validation loss: 7.5631
# Iteration: 521; Percent complete: 13.0%; Training loss: 5.2312; Validation loss: 7.2870
# Iteration: 522; Percent complete: 13.1%; Training loss: 5.2636; Validation loss: 7.5879
# Iteration: 523; Percent complete: 13.1%; Training loss: 5.4650; Validation loss: 7.4841
# Iteration: 524; Percent complete: 13.1%; Training loss: 5.3368; Validation loss: 6.9537
# Iteration: 525; Percent complete: 13.1%; Training loss: 5.2114; Validation loss: 7.2823
# Iteration: 526; Percent complete: 13.2%; Training loss: 5.0246; Validation loss: 7.3764
# Iteration: 527; Percent complete: 13.2%; Training loss: 5.2007; Validation loss: 7.1421
# Iteration: 528; Percent complete: 13.2%; Training loss: 5.2236; Validation loss: 7.6058
# Iteration: 529; Percent complete: 13.2%; Training loss: 5.3653; Validation loss: 7.2389
# Iteration: 530; Percent complete: 13.2%; Training loss: 5.0348; Validation loss: 7.1032
# Iteration: 531; Percent complete: 13.3%; Training loss: 4.9416; Validation loss: 7.4231
# Iteration: 532; Percent complete: 13.3%; Training loss: 5.0395; Validation loss: 7.2406
# Iteration: 533; Percent complete: 13.3%; Training loss: 5.0111; Validation loss: 7.5192
# Iteration: 534; Percent complete: 13.4%; Training loss: 5.4482; Validation loss: 7.4800
# Iteration: 535; Percent complete: 13.4%; Training loss: 5.1652; Validation loss: 7.5965
# Iteration: 536; Percent complete: 13.4%; Training loss: 5.1739; Validation loss: 7.3778
# Iteration: 537; Percent complete: 13.4%; Training loss: 4.9411; Validation loss: 7.5208
# Iteration: 538; Percent complete: 13.5%; Training loss: 5.3391; Validation loss: 7.1929
# Iteration: 539; Percent complete: 13.5%; Training loss: 4.9484; Validation loss: 7.3901
# Iteration: 540; Percent complete: 13.5%; Training loss: 5.1632; Validation loss: 7.7592
# Iteration: 541; Percent complete: 13.5%; Training loss: 5.1629; Validation loss: 7.2762
# Iteration: 542; Percent complete: 13.6%; Training loss: 5.2544; Validation loss: 7.6379
# Iteration: 543; Percent complete: 13.6%; Training loss: 5.1567; Validation loss: 7.8317
# Iteration: 544; Percent complete: 13.6%; Training loss: 5.1411; Validation loss: 7.3413
# Iteration: 545; Percent complete: 13.6%; Training loss: 5.3371; Validation loss: 7.4731
# Iteration: 546; Percent complete: 13.7%; Training loss: 5.1397; Validation loss: 7.7551
# Iteration: 547; Percent complete: 13.7%; Training loss: 5.0453; Validation loss: 7.3459
# Iteration: 548; Percent complete: 13.7%; Training loss: 4.9223; Validation loss: 7.6807
# Iteration: 549; Percent complete: 13.7%; Training loss: 5.2096; Validation loss: 7.1878
# Iteration: 550; Percent complete: 13.8%; Training loss: 4.9212; Validation loss: 7.4879
# ...
# Iteration: 3822; Percent complete: 95.5%; Training loss: 5.1959; Validation loss: 7.6313
# Iteration: 3823; Percent complete: 95.6%; Training loss: 5.0386; Validation loss: 7.6310
# Iteration: 3824; Percent complete: 95.6%; Training loss: 5.4408; Validation loss: 7.4876
# Iteration: 3825; Percent complete: 95.6%; Training loss: 5.0410; Validation loss: 7.5010
# Iteration: 3826; Percent complete: 95.7%; Training loss: 4.9105; Validation loss: 6.9619
# Iteration: 3827; Percent complete: 95.7%; Training loss: 4.8945; Validation loss: 7.4421
# Iteration: 3828; Percent complete: 95.7%; Training loss: 5.2583; Validation loss: 7.5036
# Iteration: 3829; Percent complete: 95.7%; Training loss: 5.0310; Validation loss: 7.4193
# Iteration: 3830; Percent complete: 95.8%; Training loss: 5.1333; Validation loss: 7.6142
# Iteration: 3831; Percent complete: 95.8%; Training loss: 5.1254; Validation loss: 7.7445
# Iteration: 3832; Percent complete: 95.8%; Training loss: 5.2173; Validation loss: 7.4572
# Iteration: 3833; Percent complete: 95.8%; Training loss: 5.2195; Validation loss: 7.5020
# Iteration: 3834; Percent complete: 95.9%; Training loss: 5.3115; Validation loss: 7.3750
# Iteration: 3835; Percent complete: 95.9%; Training loss: 4.9079; Validation loss: 7.5583
# Iteration: 3836; Percent complete: 95.9%; Training loss: 5.1973; Validation loss: 7.6615
# Iteration: 3837; Percent complete: 95.9%; Training loss: 5.0961; Validation loss: 7.2981
# Iteration: 3838; Percent complete: 96.0%; Training loss: 5.0405; Validation loss: 7.3874
# Iteration: 3839; Percent complete: 96.0%; Training loss: 5.1654; Validation loss: 7.5922
# Iteration: 3840; Percent complete: 96.0%; Training loss: 5.1363; Validation loss: 7.6134
# Iteration: 3841; Percent complete: 96.0%; Training loss: 4.8215; Validation loss: 7.4915
# Iteration: 3842; Percent complete: 96.0%; Training loss: 5.1909; Validation loss: 7.7018
# Iteration: 3843; Percent complete: 96.1%; Training loss: 5.2268; Validation loss: 7.4898
# Iteration: 3844; Percent complete: 96.1%; Training loss: 4.9811; Validation loss: 7.1378
# Iteration: 3845; Percent complete: 96.1%; Training loss: 5.1765; Validation loss: 7.7900
# Iteration: 3846; Percent complete: 96.2%; Training loss: 5.0510; Validation loss: 7.1401
# Iteration: 3847; Percent complete: 96.2%; Training loss: 4.9877; Validation loss: 7.4557
# Iteration: 3848; Percent complete: 96.2%; Training loss: 5.0690; Validation loss: 7.6299
# Iteration: 3849; Percent complete: 96.2%; Training loss: 4.8825; Validation loss: 7.7029
# Iteration: 3850; Percent complete: 96.2%; Training loss: 4.8199; Validation loss: 7.2659
# Iteration: 3851; Percent complete: 96.3%; Training loss: 5.1380; Validation loss: 7.4704
# Iteration: 3852; Percent complete: 96.3%; Training loss: 5.0728; Validation loss: 7.3379
# Iteration: 3853; Percent complete: 96.3%; Training loss: 5.1324; Validation loss: 7.3395
# Iteration: 3854; Percent complete: 96.4%; Training loss: 4.9693; Validation loss: 7.5788
# Iteration: 3855; Percent complete: 96.4%; Training loss: 5.2353; Validation loss: 7.5027
# Iteration: 3856; Percent complete: 96.4%; Training loss: 5.3109; Validation loss: 7.4502
# Iteration: 3857; Percent complete: 96.4%; Training loss: 4.8375; Validation loss: 7.1971
# Iteration: 3858; Percent complete: 96.5%; Training loss: 5.0634; Validation loss: 7.2988
# Iteration: 3859; Percent complete: 96.5%; Training loss: 5.2161; Validation loss: 7.4428
# Iteration: 3860; Percent complete: 96.5%; Training loss: 5.0361; Validation loss: 7.2148
# Iteration: 3861; Percent complete: 96.5%; Training loss: 4.9731; Validation loss: 7.3012
# Iteration: 3862; Percent complete: 96.5%; Training loss: 5.1378; Validation loss: 7.4963
# Iteration: 3863; Percent complete: 96.6%; Training loss: 5.2014; Validation loss: 7.3174
# Iteration: 3864; Percent complete: 96.6%; Training loss: 5.1738; Validation loss: 7.3003
# Iteration: 3865; Percent complete: 96.6%; Training loss: 5.0249; Validation loss: 7.2531
# Iteration: 3866; Percent complete: 96.7%; Training loss: 5.1571; Validation loss: 7.3425
# Iteration: 3867; Percent complete: 96.7%; Training loss: 5.1071; Validation loss: 7.5658
# Iteration: 3868; Percent complete: 96.7%; Training loss: 4.8965; Validation loss: 7.4963
# Iteration: 3869; Percent complete: 96.7%; Training loss: 4.9157; Validation loss: 7.5175
# Iteration: 3870; Percent complete: 96.8%; Training loss: 5.0127; Validation loss: 7.7430
# Iteration: 3871; Percent complete: 96.8%; Training loss: 4.8924; Validation loss: 7.4925
# Iteration: 3872; Percent complete: 96.8%; Training loss: 5.0212; Validation loss: 7.4058
# Iteration: 3873; Percent complete: 96.8%; Training loss: 5.0052; Validation loss: 7.6260
# Iteration: 3874; Percent complete: 96.9%; Training loss: 5.0658; Validation loss: 7.1444
# Iteration: 3875; Percent complete: 96.9%; Training loss: 5.4419; Validation loss: 7.5726
# Iteration: 3876; Percent complete: 96.9%; Training loss: 4.8973; Validation loss: 7.4124
# Iteration: 3877; Percent complete: 96.9%; Training loss: 5.0641; Validation loss: 7.3866
# Iteration: 3878; Percent complete: 97.0%; Training loss: 5.0117; Validation loss: 7.4453
# Iteration: 3879; Percent complete: 97.0%; Training loss: 5.2011; Validation loss: 7.1074
# Iteration: 3880; Percent complete: 97.0%; Training loss: 4.9895; Validation loss: 7.1646
# Iteration: 3881; Percent complete: 97.0%; Training loss: 5.0436; Validation loss: 7.3006
# Iteration: 3882; Percent complete: 97.0%; Training loss: 5.0677; Validation loss: 7.7503
# Iteration: 3883; Percent complete: 97.1%; Training loss: 5.0012; Validation loss: 7.5956
# Iteration: 3884; Percent complete: 97.1%; Training loss: 4.8861; Validation loss: 7.5812
# Iteration: 3885; Percent complete: 97.1%; Training loss: 5.1617; Validation loss: 7.5696
# Iteration: 3886; Percent complete: 97.2%; Training loss: 5.0053; Validation loss: 7.3237
# Iteration: 3887; Percent complete: 97.2%; Training loss: 5.3600; Validation loss: 7.2538
# Iteration: 3888; Percent complete: 97.2%; Training loss: 5.0709; Validation loss: 7.1305
# Iteration: 3889; Percent complete: 97.2%; Training loss: 5.0450; Validation loss: 7.4258
# Iteration: 3890; Percent complete: 97.2%; Training loss: 4.9570; Validation loss: 7.3545
# Iteration: 3891; Percent complete: 97.3%; Training loss: 4.8121; Validation loss: 7.5774
# Iteration: 3892; Percent complete: 97.3%; Training loss: 5.0354; Validation loss: 7.5118
# Iteration: 3893; Percent complete: 97.3%; Training loss: 4.9656; Validation loss: 7.3677
# Iteration: 3894; Percent complete: 97.4%; Training loss: 5.1020; Validation loss: 7.3718
# Iteration: 3895; Percent complete: 97.4%; Training loss: 5.1999; Validation loss: 7.4971
# Iteration: 3896; Percent complete: 97.4%; Training loss: 5.0860; Validation loss: 7.0231
# Iteration: 3897; Percent complete: 97.4%; Training loss: 5.3042; Validation loss: 7.5849
# Iteration: 3898; Percent complete: 97.5%; Training loss: 5.2091; Validation loss: 7.6381
# Iteration: 3899; Percent complete: 97.5%; Training loss: 5.0565; Validation loss: 7.3359
# Iteration: 3900; Percent complete: 97.5%; Training loss: 5.1109; Validation loss: 7.5015
# Iteration: 3901; Percent complete: 97.5%; Training loss: 5.0643; Validation loss: 7.5063
# Iteration: 3902; Percent complete: 97.5%; Training loss: 5.0461; Validation loss: 7.5132
# Iteration: 3903; Percent complete: 97.6%; Training loss: 4.9959; Validation loss: 7.7761
# Iteration: 3904; Percent complete: 97.6%; Training loss: 5.2318; Validation loss: 7.6519
# Iteration: 3905; Percent complete: 97.6%; Training loss: 4.9733; Validation loss: 7.4549
# Iteration: 3906; Percent complete: 97.7%; Training loss: 5.0823; Validation loss: 7.6668
# Iteration: 3907; Percent complete: 97.7%; Training loss: 5.0071; Validation loss: 7.4247
# Iteration: 3908; Percent complete: 97.7%; Training loss: 5.1171; Validation loss: 7.6983
# Iteration: 3909; Percent complete: 97.7%; Training loss: 5.3653; Validation loss: 7.4795
# Iteration: 3910; Percent complete: 97.8%; Training loss: 4.8520; Validation loss: 7.6311
# Iteration: 3911; Percent complete: 97.8%; Training loss: 5.0918; Validation loss: 7.4655
# Iteration: 3912; Percent complete: 97.8%; Training loss: 5.0962; Validation loss: 7.5670
# Iteration: 3913; Percent complete: 97.8%; Training loss: 5.1080; Validation loss: 7.2891
# Iteration: 3914; Percent complete: 97.9%; Training loss: 5.2083; Validation loss: 7.4932
# Iteration: 3915; Percent complete: 97.9%; Training loss: 5.1137; Validation loss: 7.6484
# Iteration: 3916; Percent complete: 97.9%; Training loss: 4.8836; Validation loss: 7.5042
# Iteration: 3917; Percent complete: 97.9%; Training loss: 5.1023; Validation loss: 7.6897
# Iteration: 3918; Percent complete: 98.0%; Training loss: 5.0647; Validation loss: 7.0938
# Iteration: 3919; Percent complete: 98.0%; Training loss: 5.0414; Validation loss: 7.4348
# Iteration: 3920; Percent complete: 98.0%; Training loss: 5.0250; Validation loss: 7.4861
# Iteration: 3921; Percent complete: 98.0%; Training loss: 5.2929; Validation loss: 7.7666
# Iteration: 3922; Percent complete: 98.0%; Training loss: 5.1495; Validation loss: 7.7524
# Iteration: 3923; Percent complete: 98.1%; Training loss: 5.1337; Validation loss: 7.2241
# Iteration: 3924; Percent complete: 98.1%; Training loss: 5.1384; Validation loss: 6.9185
# Iteration: 3925; Percent complete: 98.1%; Training loss: 4.9437; Validation loss: 7.5617
# Iteration: 3926; Percent complete: 98.2%; Training loss: 4.9831; Validation loss: 7.5120
# Iteration: 3927; Percent complete: 98.2%; Training loss: 4.9698; Validation loss: 7.9640
# Iteration: 3928; Percent complete: 98.2%; Training loss: 5.3163; Validation loss: 7.3512
# Iteration: 3929; Percent complete: 98.2%; Training loss: 5.0368; Validation loss: 7.1735
# Iteration: 3930; Percent complete: 98.2%; Training loss: 5.0202; Validation loss: 7.3679
# Iteration: 3931; Percent complete: 98.3%; Training loss: 4.9041; Validation loss: 7.4794
# Iteration: 3932; Percent complete: 98.3%; Training loss: 4.8708; Validation loss: 7.6661
# Iteration: 3933; Percent complete: 98.3%; Training loss: 4.8631; Validation loss: 7.2641
# Iteration: 3934; Percent complete: 98.4%; Training loss: 4.9429; Validation loss: 7.4066
# Iteration: 3935; Percent complete: 98.4%; Training loss: 4.9966; Validation loss: 7.7066
# Iteration: 3936; Percent complete: 98.4%; Training loss: 5.0522; Validation loss: 7.5274
# Iteration: 3937; Percent complete: 98.4%; Training loss: 4.9952; Validation loss: 7.2545
# Iteration: 3938; Percent complete: 98.5%; Training loss: 5.1808; Validation loss: 7.6317
# Iteration: 3939; Percent complete: 98.5%; Training loss: 4.9265; Validation loss: 7.2679
# Iteration: 3940; Percent complete: 98.5%; Training loss: 4.9370; Validation loss: 7.6606
# Iteration: 3941; Percent complete: 98.5%; Training loss: 4.9023; Validation loss: 7.6246
# Iteration: 3942; Percent complete: 98.6%; Training loss: 5.1868; Validation loss: 7.6035
# Iteration: 3943; Percent complete: 98.6%; Training loss: 4.9903; Validation loss: 7.3803
# Iteration: 3944; Percent complete: 98.6%; Training loss: 5.0007; Validation loss: 7.5538
# Iteration: 3945; Percent complete: 98.6%; Training loss: 4.9027; Validation loss: 7.6051
# Iteration: 3946; Percent complete: 98.7%; Training loss: 5.3155; Validation loss: 7.2818
# Iteration: 3947; Percent complete: 98.7%; Training loss: 5.3589; Validation loss: 7.3938
# Iteration: 3948; Percent complete: 98.7%; Training loss: 5.0611; Validation loss: 7.5343
# Iteration: 3949; Percent complete: 98.7%; Training loss: 5.1772; Validation loss: 7.4582
# Iteration: 3950; Percent complete: 98.8%; Training loss: 5.0193; Validation loss: 7.5558
# Iteration: 3951; Percent complete: 98.8%; Training loss: 5.1856; Validation loss: 7.6323
# Iteration: 3952; Percent complete: 98.8%; Training loss: 4.9204; Validation loss: 7.5057
# Iteration: 3953; Percent complete: 98.8%; Training loss: 5.1128; Validation loss: 7.4258
# Iteration: 3954; Percent complete: 98.9%; Training loss: 5.1244; Validation loss: 7.9741
# Iteration: 3955; Percent complete: 98.9%; Training loss: 4.9107; Validation loss: 7.3365
# Iteration: 3956; Percent complete: 98.9%; Training loss: 5.1558; Validation loss: 7.1059
# Iteration: 3957; Percent complete: 98.9%; Training loss: 4.8806; Validation loss: 7.7808
# Iteration: 3958; Percent complete: 99.0%; Training loss: 5.1109; Validation loss: 7.1773
# Iteration: 3959; Percent complete: 99.0%; Training loss: 5.1793; Validation loss: 7.5027
# Iteration: 3960; Percent complete: 99.0%; Training loss: 5.2105; Validation loss: 7.6357
# Iteration: 3961; Percent complete: 99.0%; Training loss: 4.6695; Validation loss: 7.5630
# Iteration: 3962; Percent complete: 99.1%; Training loss: 4.9027; Validation loss: 7.7093
# Iteration: 3963; Percent complete: 99.1%; Training loss: 4.9723; Validation loss: 7.2125
# Iteration: 3964; Percent complete: 99.1%; Training loss: 4.9973; Validation loss: 7.3749
# Iteration: 3965; Percent complete: 99.1%; Training loss: 5.1132; Validation loss: 7.4733
# Iteration: 3966; Percent complete: 99.2%; Training loss: 4.9584; Validation loss: 7.5851
# Iteration: 3967; Percent complete: 99.2%; Training loss: 5.5163; Validation loss: 7.4405
# Iteration: 3968; Percent complete: 99.2%; Training loss: 5.1066; Validation loss: 7.2752
# Iteration: 3969; Percent complete: 99.2%; Training loss: 5.0208; Validation loss: 7.5572
# Iteration: 3970; Percent complete: 99.2%; Training loss: 5.2695; Validation loss: 7.5185
# Iteration: 3971; Percent complete: 99.3%; Training loss: 5.0757; Validation loss: 7.2242
# Iteration: 3972; Percent complete: 99.3%; Training loss: 5.0346; Validation loss: 7.4375
# Iteration: 3973; Percent complete: 99.3%; Training loss: 5.2358; Validation loss: 7.5019
# Iteration: 3974; Percent complete: 99.4%; Training loss: 5.2687; Validation loss: 7.4671
# Iteration: 3975; Percent complete: 99.4%; Training loss: 5.1792; Validation loss: 7.1768
# Iteration: 3976; Percent complete: 99.4%; Training loss: 5.3388; Validation loss: 7.3566
# Iteration: 3977; Percent complete: 99.4%; Training loss: 5.0581; Validation loss: 7.7474
# Iteration: 3978; Percent complete: 99.5%; Training loss: 5.2040; Validation loss: 7.5076
# Iteration: 3979; Percent complete: 99.5%; Training loss: 5.0228; Validation loss: 7.2737
# Iteration: 3980; Percent complete: 99.5%; Training loss: 5.3975; Validation loss: 7.6851
# Iteration: 3981; Percent complete: 99.5%; Training loss: 4.8159; Validation loss: 7.8626
# Iteration: 3982; Percent complete: 99.6%; Training loss: 4.8760; Validation loss: 7.8534
# Iteration: 3983; Percent complete: 99.6%; Training loss: 5.0514; Validation loss: 7.5047
# Iteration: 3984; Percent complete: 99.6%; Training loss: 5.1597; Validation loss: 7.5628
# Iteration: 3985; Percent complete: 99.6%; Training loss: 4.8591; Validation loss: 7.2352
# Iteration: 3986; Percent complete: 99.7%; Training loss: 5.2544; Validation loss: 7.1298
# Iteration: 3987; Percent complete: 99.7%; Training loss: 5.0097; Validation loss: 7.2921
# Iteration: 3988; Percent complete: 99.7%; Training loss: 5.1761; Validation loss: 7.7700
# Iteration: 3989; Percent complete: 99.7%; Training loss: 5.2414; Validation loss: 7.5546
# Iteration: 3990; Percent complete: 99.8%; Training loss: 5.2407; Validation loss: 7.1427
# Iteration: 3991; Percent complete: 99.8%; Training loss: 5.1843; Validation loss: 7.4710
# Iteration: 3992; Percent complete: 99.8%; Training loss: 5.2022; Validation loss: 7.1684
# Iteration: 3993; Percent complete: 99.8%; Training loss: 4.9753; Validation loss: 7.6832
# Iteration: 3994; Percent complete: 99.9%; Training loss: 5.0227; Validation loss: 7.5320
# Iteration: 3995; Percent complete: 99.9%; Training loss: 4.9777; Validation loss: 7.5096
# Iteration: 3996; Percent complete: 99.9%; Training loss: 4.9419; Validation loss: 7.3336
# Iteration: 3997; Percent complete: 99.9%; Training loss: 5.3307; Validation loss: 7.6825
# Iteration: 3998; Percent complete: 100.0%; Training loss: 5.2035; Validation loss: 7.6703
# Iteration: 3999; Percent complete: 100.0%; Training loss: 5.0576; Validation loss: 7.2778
# Iteration: 4000; Percent complete: 100.0%; Training loss: 4.9566; Validation loss: 7.3970

# %%
PATH=r"C:\\Users\\indra\\OneDrive\\Documents\\Indrani\\UCB\\w266\\chatbot"
print(PATH)
torch.save(model_name, PATH)
# Out:
# C:\\Users\\indra\\OneDrive\\Documents\\Indrani\\UCB\\w266\\chatbot
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-112-c25635f26d64> in <module>
#       1 PATH=r"C:\\Users\\indra\\OneDrive\\Documents\\Indrani\\UCB\\w266\\chatbot"
#       2 print(PATH)
# ----> 3 torch.save(model_name, PATH)
#
# ~\anaconda3\lib\site-packages\torch\serialization.py in save(obj, f, pickle_module, pickle_protocol, _use_new_zipfile_serialization)
#     367             return
#     368
# --> 369     with _open_file_like(f, 'wb') as opened_file:
#     370         _legacy_save(obj, opened_file, pickle_module, pickle_protocol)
#     371
#
# ~\anaconda3\lib\site-packages\torch\serialization.py in _open_file_like(name_or_buffer, mode)
#     232 def _open_file_like(name_or_buffer, mode):
#     233     if _is_path(name_or_buffer):
# --> 234         return _open_file(name_or_buffer, mode)
#     235     else:
#     236         if 'w' in mode:
#
# ~\anaconda3\lib\site-packages\torch\serialization.py in __init__(self, name, mode)
#     213 class _open_file(_opener):
#     214     def __init__(self, name, mode):
# --> 215         super(_open_file, self).__init__(open(name, mode))
#     216
#     217     def __exit__(self, *args):
#
# PermissionError: [Errno 13] Permission denied: 'C:\\\\Users\\\\indra\\\\OneDrive\\\\Documents\\\\Indrani\\\\UCB\\\\w266\\\\chatbot'

# %%
import json
def save_current_config(save_model_file_name):
  config_dict = {'start_token':1, 'end_token':2, 'save_model_file_name':save_model_file_name}
  config_filename = PATH + save_model_file_name + '\config.txt'
  with open(config_filename, 'w') as f:
    json.dump(config_dict, f)

# %%
save_current_config("")

# %%
import time

# %%
encoder.eval()
decoder.eval()
searcher = SearchDecoder(encoder, decoder)
# evaluateInput(encoder, decoder, searcher, voc)
