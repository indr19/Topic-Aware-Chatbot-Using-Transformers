# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function
from __future__ import unicode_literals

import torch
from torch.jit import script, trace
import torch.nn as nn
from torch import optim
import torch.nn.functional as F
import csv
import random
import re
import os
import unicodedata
import codecs
from io import open
import itertools
import math

# %%
corpus_name = "cornell movie-dialogs corpus"
corpus = os.path.join(r"C:\Users\indra\OneDrive\Documents\Indrani\UCB\w266\chatbot\data", corpus_name)

def printLines(file, n=10):
    with open(file, 'rb') as datafile:
        lines = datafile.readlines()
    for line in lines[:n]:
        print(line)

printLines(os.path.join(corpus, "movie_lines.txt"))

# Define path to new file
datafile = os.path.join(corpus, "formatted_movie_lines.txt")
# Out:
# b'L1045 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ They do not!\n'
# b'L1044 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ They do to!\n'
# b'L985 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ I hope so.\n'
# b'L984 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ She okay?\n'
# b"L925 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Let's go.\n"
# b'L924 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ Wow\n'
# b"L872 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Okay -- you're gonna need to learn how to lie.\n"
# b'L871 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ No\n'
# b'L870 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ I\'m kidding.  You know how sometimes you just become this "persona"?  And you don\'t know how to quit?\n'
# b'L869 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Like my fear of wearing pastels?\n'

# %%
# Default word tokens
PAD_token = 0  # Used for padding short sentences
SOS_token = 1  # Start-of-sentence token
EOS_token = 2  # End-of-sentence token

# %%
class Voc:
    def __init__(self, name):
        self.name = name
        self.trimmed = False
        self.word2index = {}
        self.word2count = {}
        self.index2word = {PAD_token: "PAD", SOS_token: "SOS", EOS_token: "EOS"}
        self.num_words = 3  # Count SOS, EOS, PAD

    def addSentence(self, sentence):
        for word in sentence.split(' '):
            self.addWord(word)

    def addWord(self, word):
        if word not in self.word2index:
            self.word2index[word] = self.num_words
            self.word2count[word] = 1
            self.index2word[self.num_words] = word
            self.num_words += 1
        else:
            self.word2count[word] += 1

    # Remove words below a certain count threshold
    def trim(self, min_count):
        if self.trimmed:
            return
        self.trimmed = True

        keep_words = []

        for k, v in self.word2count.items():
            if v >= min_count:
                keep_words.append(k)

        print('keep_words {} / {} = {:.4f}'.format(
            len(keep_words), len(self.word2index), len(keep_words) / len(self.word2index)
        ))

        # Reinitialize dictionaries
        self.word2index = {}
        self.word2count = {}
        self.index2word = {PAD_token: "PAD", SOS_token: "SOS", EOS_token: "EOS"}
        self.num_words = 3 # Count default tokens

        for word in keep_words:
            self.addWord(word)

# %%
MAX_LENGTH = 10  # Maximum sentence length to consider

# Turn a Unicode string to plain ASCII, thanks to
# https://stackoverflow.com/a/518232/2809427
def unicodeToAscii(s):
    return ''.join(
        c for c in unicodedata.normalize('NFD', s)
        if unicodedata.category(c) != 'Mn'
    )

# Lowercase, trim, and remove non-letter characters
def normalizeString(s):
    s = unicodeToAscii(s.lower().strip())
    s = re.sub(r"([.!?])", r" \1", s)
    s = re.sub(r"[^a-zA-Z.!?]+", r" ", s)
    s = re.sub(r"\s+", r" ", s).strip()
    return s

# Read query/response pairs and return a voc object
def readVocs(datafile, corpus_name):
    print("Reading lines...")
    # Read the file and split into lines
    lines = open(datafile, encoding='utf-8').\
        read().strip().split('\n')
    # Split every line into pairs and normalize
    pairs = [[normalizeString(s) for s in l.split('\t')] for l in lines]
    voc = Voc(corpus_name)
    return voc, pairs

# Returns True iff both sentences in a pair 'p' are under the MAX_LENGTH threshold
def filterPair(p):
    # Input sequences need to preserve the last word for EOS token
    return len(p[0].split(' ')) < MAX_LENGTH and len(p[1].split(' ')) < MAX_LENGTH

# Filter pairs using filterPair condition
def filterPairs(pairs):
    return [pair for pair in pairs if filterPair(pair)]

# Using the functions defined above, return a populated voc object and pairs list
def loadPrepareData(corpus, corpus_name, datafile, save_dir):
    print("Start preparing training data ...")
    voc, pairs = readVocs(datafile, corpus_name)
    print("Read {!s} sentence pairs".format(len(pairs)))
    pairs = filterPairs(pairs)
    print("Trimmed to {!s} sentence pairs".format(len(pairs)))
    print("Counting words...")
    for pair in pairs:
        voc.addSentence(pair[0])
        voc.addSentence(pair[1])
    print("Counted words:", voc.num_words)
    return voc, pairs

# %%
datafile_validation = os.path.join(corpus, "formatted_movie_lines_valid.txt")

# %%
# Load/Assemble voc and pairs
save_dir = os.path.join("data", "save")
voc, pairs = loadPrepareData(corpus, corpus_name, datafile, save_dir)
# Out:
# Start preparing training data ...
# Reading lines...
# Read 171282 sentence pairs
# Trimmed to 49566 sentence pairs
# Counting words...
# Counted words: 15583

# %%
voc_validation, pairs_validation = loadPrepareData(corpus, corpus_name, datafile_validation, save_dir)
# Out:
# Start preparing training data ...
# Reading lines...
# Read 53424 sentence pairs
# Trimmed to 15653 sentence pairs
# Counting words...
# Counted words: 7808

# %%
def indexesFromSentence(voc, sentence):
    return [voc.word2index[word] for word in sentence.split(' ')] + [EOS_token]


def zeroPadding(l, fillvalue=PAD_token):
    return list(itertools.zip_longest(*l, fillvalue=fillvalue))

def binaryMatrix(l, value=PAD_token):
    m = []
    for i, seq in enumerate(l):
        m.append([])
        for token in seq:
            if token == PAD_token:
                m[i].append(0)
            else:
                m[i].append(1)
    return m

# Returns padded input sequence tensor and lengths
def inputVar(l, voc):
    indexes_batch = [indexesFromSentence(voc, sentence) for sentence in l]
    lengths = torch.tensor([len(indexes) for indexes in indexes_batch])
    padList = zeroPadding(indexes_batch)
    padVar = torch.LongTensor(padList)
    return padVar, lengths

# Returns padded target sequence tensor, padding mask, and max target length
def outputVar(l, voc):
    indexes_batch = [indexesFromSentence(voc, sentence) for sentence in l]
    max_target_len = max([len(indexes) for indexes in indexes_batch])
    padList = zeroPadding(indexes_batch)
    mask = binaryMatrix(padList)
    mask = torch.BoolTensor(mask)
    padVar = torch.LongTensor(padList)
    return padVar, mask, max_target_len

# Returns all items for a given batch of pairs
def batch2TrainData(voc, pair_batch):
    pair_batch.sort(key=lambda x: len(x[0].split(" ")), reverse=True)
    input_batch, output_batch = [], []
    for pair in pair_batch:
        input_batch.append(pair[0])
        output_batch.append(pair[1])
    inp, lengths = inputVar(input_batch, voc)
    output, mask, max_target_len = outputVar(output_batch, voc)
    return inp, lengths, output, mask, max_target_len

# %%
def printLines(file, n=10):
    with open(file, 'rb') as datafile:
        lines = datafile.readlines()
    for line in lines[:n]:
        print(line)

# %%
# Splits each line of the file into a dictionary of fields
def loadLines(fileName, fields):
    lines = {}
    with open(fileName, 'r', encoding='iso-8859-1') as f:
        for line in f:
            values = line.split(" +++$+++ ")
            # Extract fields
            lineObj = {}
            for i, field in enumerate(fields):
                lineObj[field] = values[i]
            lines[lineObj['lineID']] = lineObj
    return lines

# %%
# Groups fields of lines from `loadLines` into conversations based on *movie_conversations.txt*
def loadConversations(fileName, lines, fields):
    conversations = []
    with open(fileName, 'r', encoding='iso-8859-1') as f:
        for line in f:
            values = line.split(" +++$+++ ")
            # Extract fields
            convObj = {}
            for i, field in enumerate(fields):
                convObj[field] = values[i]
            # Convert string to list (convObj["utteranceIDs"] == "['L598485', 'L598486', ...]")
            utterance_id_pattern = re.compile('L[0-9]+')
            lineIds = utterance_id_pattern.findall(convObj["utteranceIDs"])
            # Reassemble lines
            convObj["lines"] = []
            for lineId in lineIds:
                convObj["lines"].append(lines[lineId])
            conversations.append(convObj)
    return conversations

# %%
# Extracts pairs of sentences from conversations
def extractSentencePairs(conversations):
    qa_pairs = []
    for conversation in conversations:
        # Iterate over all the lines of the conversation
        for i in range(len(conversation["lines"]) - 1):  # We ignore the last line (no answer for it)
            inputLine = conversation["lines"][i]["text"].strip()
            targetLine = conversation["lines"][i+1]["text"].strip()
            # Filter wrong samples (if one of the lists is empty)
            if inputLine and targetLine:
                qa_pairs.append([inputLine, targetLine])
    return qa_pairs

# %%
# Define path to new file
datafile = r"C:\Users\indra\OneDrive\Documents\Indrani\UCB\w266\chatbot\data\cornell movie-dialogs corpus\formatted_movie_lines.txt"
datafile_validation = r"C:\Users\indra\OneDrive\Documents\Indrani\UCB\w266\chatbot\data\cornell movie-dialogs corpus\formatted_movie_lines_validation.txt"

# %%
delimiter = '\t'
# Unescape the delimiter
delimiter = str(codecs.decode(delimiter, "unicode_escape"))

# Initialize lines dict, conversations list, and field ids
lines = {}
conversations = []
MOVIE_LINES_FIELDS = ["lineID", "characterID", "movieID", "character", "text"]
MOVIE_CONVERSATIONS_FIELDS = ["character1ID", "character2ID", "movieID", "utteranceIDs"]

# %%
 # Load lines and process conversations
print("\nProcessing corpus...")
lines = loadLines(r"C:\Users\indra\OneDrive\Documents\Indrani\UCB\w266\chatbot\data\cornell movie-dialogs corpus\movie_lines.txt", MOVIE_LINES_FIELDS)
print("\nLoading conversations...")
conversations = loadConversations(r"C:\Users\indra\OneDrive\Documents\Indrani\UCB\w266\chatbot\data\cornell movie-dialogs corpus\movie_conversations.txt",
                              lines, MOVIE_CONVERSATIONS_FIELDS)

# Write new csv file
number = 1
print("\nWriting Validation formatted file...")
with open(datafile_validation, 'w', encoding='utf-8') as outputfile:
    writer = csv.writer(outputfile, delimiter=delimiter, lineterminator='\n')

    for pair in extractSentencePairs(conversations):
        if number <= 50000:
            writer.writerow(pair)
        number += 1

number = 1
print("\nWriting Training  formatted file...")
with open(datafile, 'w', encoding='utf-8') as outputfile:
    writer = csv.writer(outputfile, delimiter=delimiter, lineterminator='\n')
    for pair in extractSentencePairs(conversations):
        if number > 50000:
            writer.writerow(pair)
        number += 1
# Out:
# Processing corpus...
#
# Loading conversations...
#
# Writing Validation formatted file...
#
# Writing Training  formatted file...

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import NMF ,LatentDirichletAllocation
from sklearn.pipeline import Pipeline
from sklearn.datasets import fetch_20newsgroups
import numpy as np

# %%
def save_model(dictionary, feature_names, filename):
    with open(filename, "wb") as f:
        np.savez(f, dictionary=dictionary, feature_names=feature_names)
        
def load_model(filename):
    """load model saved with save_model. Returns a tupe of dictionary, feature_names"""
    with open(filename, "rb") as f:
        arrs = np.load(f)
        return arrs["dictionary"], arrs["feature_names"]
    

def print_top_words(dictionary, feature_names, n_top_words):
    """print the top n_top_words from each topic in the dictionary matrix
    of dictionary. Feature names is a list of words with indices corresponding
    to the columns of the dictionary"""
    for topic_idx, topic in enumerate(dictionary):
        message = "Topic #%d: " % topic_idx
        message += " ".join([feature_names[i]
                             for i in topic.argsort()[:-n_top_words - 1:-1]])
        print(message)
    print()

# %%
def train_model(data, n_features, n_components):
    model = Pipeline(steps=[("tfidf", TfidfVectorizer(max_df=0.95, min_df=2,
                                                      max_features=n_features, stop_words='english')),
                            ("lda", LatentDirichletAllocation(n_components=n_components, random_state=1))])
    model.fit(data)
    features = model["tfidf"].get_feature_names()
    dictionary = model["lda"].components_
    return dictionary, features

def train_save_model(data, n_features, n_components, filename):
    dictionary, features = train_model(data, n_features, n_components)
    save_model(dictionary, features, filename)
    return dictionary, features        

def load_news():
    dataset = fetch_20newsgroups(shuffle=True, random_state=1,
                                 remove=('headers', 'footers', 'quotes'))
    data_samples = dataset.data
    return data_samples

# %%
# number of top words to use in tfidf representation of data
n_features = 1000
# number of topics in LDA
n_components = 10

# train model and save it
print("Loading, training, and saving 20 news groups model")
news_data = load_news()
news_dict, news_feats = train_save_model(news_data, n_features, n_components, "data/topic/news-lda.npz")
print_top_words(news_dict, news_feats, 10)
# Out:
# Loading, training, and saving 20 news groups model
# Topic #0: 00 10 11 1993 15 12 23 13 apr 17
# Topic #1: god people think jesus don say believe just does know
# Topic #2: windows window file program use files using edu server motif
# Topic #3: government people key israel gun law don state encryption public
# Topic #4: drive card mac software video monitor use windows pc scsi
# Topic #5: space nasa new orbit earth air years launch research water
# Topic #6: game team year games season players play hockey league win
# Topic #7: mail phone address thanks sale edu email interested 00 price
# Topic #8: just like car don bike good know think ve time
# Topic #9: thanks know mail looking post hi info faq help appreciated

# %%
USE_CUDA = torch.cuda.is_available()
print("USE_CUDA", USE_CUDA)
if USE_CUDA:
    device = torch.device("cuda")
# Out:
# USE_CUDA True

# %%
def calculate_codes(topic_for_code, input_seq_for_code, voc, feature_path, batch_size):
    # batch_size = 64 for training, 1 for chatting
    ldadict = np.load(feature_path)["feature_names"]
    new_input_seq = torch.zeros(batch_size, len(ldadict))

    for i in range(batch_size):
        for j in range(len(input_seq_for_code[i])):
            input_seq_words = voc.index2word[input_seq_for_code[i][j].item()]
            for check_index in range(len(ldadict)):
                if ldadict[check_index] == input_seq_words:
                    new_input_seq[i][check_index] = 1

    three_d_topic = topic_for_code.repeat(batch_size, 1, 1).to(device)
    three_d_q = new_input_seq.repeat(1, 1, 1).permute(1, 2, 0).to(device)

    return torch.bmm(three_d_topic, three_d_q)

# %%
class EncoderRNN(nn.Module):
    def __init__(self,
                 hidden_size,
                 embedding,
                 topics,
                 n_layers=1,
                 dropout=0,
                 batch_size=64):
        super(EncoderRNN, self).__init__()
        self.n_layers = n_layers
        self.hidden_size = hidden_size
        self.embedding = embedding
        self.topics = topics
        self.batch_size = batch_size
        # self.voc = voc
        # Initialize GRU; the input_size and hidden_size params are both set to 'hidden_size'
        self.gru = nn.GRU(hidden_size,
                          hidden_size,
                          n_layers,
                          dropout=(0 if n_layers == 1 else dropout), bidirectional=True)

    def forward(self, input_seq, input_lengths, hidden=None):
        #print(input_seq)
        batch_size = 1
        #get the codes first
        input_seq_for_code = input_seq.transpose(0,1)
        topic_for_code = self.topics
        feature_path = r"data/topic/news-lda.npz"
        codes = calculate_codes(topic_for_code, input_seq_for_code, voc, feature_path, self.batch_size)
        #print(codes.size())
        # Convert word indexes to embeddings
        embedded = self.embedding(input_seq)
        # Pack padded batch of sequences for RNN module
        packed = nn.utils.rnn.pack_padded_sequence(embedded, input_lengths)
        # Forward pass through GRU
        outputs, hidden = self.gru(packed, hidden)
        # Unpack padding
        outputs, _ = nn.utils.rnn.pad_packed_sequence(outputs)
        # Sum bidirectional GRU outputs
        outputs = outputs[:, :, :self.hidden_size] + outputs[:, : ,self.hidden_size:]
        # Return output and final hidden state
        return outputs, hidden, codes

# %%
class Attn(nn.Module):
    def __init__(self, method, hidden_size):
        super(Attn, self).__init__()
        self.method = method
        if self.method not in ['dot', 'general', 'concat']:
            raise ValueError(self.method, "is not an appropriate attention method.")
        self.hidden_size = hidden_size
        if self.method == 'general':
            self.attn = nn.Linear(self.hidden_size, hidden_size)
        elif self.method == 'concat':
            self.attn = nn.Linear(self.hidden_size * 2, hidden_size)
            self.v = nn.Parameter(torch.FloatTensor(hidden_size))

    def dot_score(self, hidden, encoder_output):
        return torch.sum(hidden * encoder_output, dim=2)

    def general_score(self, hidden, encoder_output):
        energy = self.attn(encoder_output)
        return torch.sum(hidden * energy, dim=2)

    def concat_score(self, hidden, encoder_output):
        energy = self.attn(torch.cat((hidden.expand(encoder_output.size(0), -1, -1), encoder_output), 2)).tanh()
        return torch.sum(self.v * energy, dim=2)

    def forward(self, hidden, encoder_outputs):
        # Calculate the attention weights (energies) based on the given method
        if self.method == 'general':
            attn_energies = self.general_score(hidden, encoder_outputs)
        elif self.method == 'concat':
            attn_energies = self.concat_score(hidden, encoder_outputs)
        elif self.method == 'dot':
            attn_energies = self.dot_score(hidden, encoder_outputs)

        # Transpose max_length and batch_size dimensions
        attn_energies = attn_energies.t()

        # Return the softmax normalized probability scores (with added dimension)
        return F.softmax(attn_energies, dim=1).unsqueeze(1)

# %%
def maskNLLLoss(inp, target, mask):
    nTotal = mask.sum()
    crossEntropy = -torch.log(torch.gather(inp, 1, target.view(-1, 1)).squeeze(1))
    loss = crossEntropy.masked_select(mask).mean()
    loss = loss.to(device)
    return loss, nTotal.item()

# %%
def validation(input_variable, lengths, target_variable, mask, max_target_len, encoder, decoder, embedding,
          encoder_optimizer, decoder_optimizer, batch_size, clip, max_length=MAX_LENGTH):
    # Set device options
    input_variable = input_variable.to(device)
    lengths = lengths.to(device)
    target_variable = target_variable.to(device)
    mask = mask.to(device)

    # Initialize variables
    loss = 0
    print_losses = []
    n_totals = 0

    # Forward pass through encoder
    encoder_outputs, encoder_hidden, codes = encoder(input_variable, lengths)

    # Create initial decoder input (start with SOS tokens for each sentence)
    decoder_input = torch.LongTensor([[SOS_token for _ in range(batch_size)]])
    decoder_input = decoder_input.to(device)

    # Set initial decoder hidden state to the encoder's final hidden state
    decoder_hidden = encoder_hidden[:decoder.n_layers]

    # Determine if we are using teacher forcing this iteration
    teacher_forcing_ratio = 1.0
    use_teacher_forcing = True if random.random() < teacher_forcing_ratio else False

    # Forward batch of sequences through decoder one time step at a time
    if use_teacher_forcing:
        for t in range(max_target_len):
            decoder_output, decoder_hidden = decoder(
                decoder_input, decoder_hidden, encoder_outputs, codes, batch_size
            )
            # Teacher forcing: next input is current target
            decoder_input = target_variable[t].view(1, -1)
            # Calculate and accumulate loss
            mask_loss, nTotal = maskNLLLoss(decoder_output, target_variable[t], mask[t])
            loss += mask_loss
            print_losses.append(mask_loss.item() * nTotal)
            n_totals += nTotal
    else:
        for t in range(max_target_len):
            decoder_output, decoder_hidden = decoder(
                decoder_input, decoder_hidden, encoder_outputs, codes, batch_size
            )
            # No teacher forcing: next input is decoder's own current output
            _, topi = decoder_output.topk(1)
            decoder_input = torch.LongTensor([[topi[i][0] for i in range(batch_size)]])
            decoder_input = decoder_input.to(device)
            # Calculate and accumulate loss
            mask_loss, nTotal = maskNLLLoss(decoder_output, target_variable[t], mask[t])
            loss += mask_loss
            print_losses.append(mask_loss.item() * nTotal)
            n_totals += nTotal

    return sum(print_losses) / n_totals

# %%
def train(input_variable,
          lengths,
          target_variable,
          mask,
          max_target_len,
          encoder,
          decoder,
          embedding,
          encoder_optimizer,
          decoder_optimizer,
          batch_size,
          clip,
          max_length=MAX_LENGTH):

    # Zero gradients
    encoder_optimizer.zero_grad()
    decoder_optimizer.zero_grad()

    # Set device options
    input_variable = input_variable.to(device)
    lengths = lengths.to(device)
    target_variable = target_variable.to(device)
    mask = mask.to(device)

    # Initialize variables
    loss = 0
    print_losses = []
    n_totals = 0

    # Forward pass through encoder
    encoder_outputs, encoder_hidden, codes = encoder(input_variable, lengths)

    # Create initial decoder input (start with SOS tokens for each sentence)
    decoder_input = torch.LongTensor([[SOS_token for _ in range(batch_size)]])
    decoder_input = decoder_input.to(device)

    # Set initial decoder hidden state to the encoder's final hidden state
    #decoder_hidden = encoder_hidden[:decoder.n_layers]
    decoder_hidden = encoder_hidden[:decoder.n_layers]

    # Determine if we are using teacher forcing this iteration
    teacher_forcing_ratio = 1.0
    use_teacher_forcing = True if random.random() < teacher_forcing_ratio else False

    # Forward batch of sequences through decoder one time step at a time
    if use_teacher_forcing:
        for t in range(max_target_len):

            decoder_output, decoder_hidden = decoder(
                decoder_input, decoder_hidden, encoder_outputs, codes, batch_size
            )
            # Teacher forcing: next input is current target
            decoder_input = target_variable[t].view(1, -1)
            # Calculate and accumulate loss
            mask_loss, nTotal = maskNLLLoss(decoder_output, target_variable[t], mask[t])
            loss += mask_loss
            print_losses.append(mask_loss.item() * nTotal)
            n_totals += nTotal
    else:
        for t in range(max_target_len):
            decoder_output, decoder_hidden = decoder(
                decoder_input, decoder_hidden, encoder_outputs, codes, batch_size
            )
            # No teacher forcing: next input is decoder's own current output
            _, topi = decoder_output.topk(1)
            decoder_input = torch.LongTensor([[topi[i][0] for i in range(batch_size)]])
            decoder_input = decoder_input.to(device)
            # Calculate and accumulate loss
            mask_loss, nTotal = maskNLLLoss(decoder_output, target_variable[t], mask[t])
            loss += mask_loss
            print_losses.append(mask_loss.item() * nTotal)
            n_totals += nTotal

    # Perform backpropatation
    loss.backward()

    # Clip gradients: gradients are modified in place
    _ = nn.utils.clip_grad_norm_(encoder.parameters(), clip)
    _ = nn.utils.clip_grad_norm_(decoder.parameters(), clip)

    # Adjust model weights
    encoder_optimizer.step()
    decoder_optimizer.step()

    return sum(print_losses) / n_totals

# %%
def trainIters(model_name,
               voc,
               voc_validation,
               pairs,
               pairs_validation,
               encoder,
               decoder,
               encoder_optimizer,
               decoder_optimizer,
               embedding,
               encoder_n_layers,
               decoder_n_layers,
               save_dir,
               n_iteration,
               batch_size,
               print_every,
               save_every,
               clip,
               corpus_name,
               loadFilename,
               DICT_NAME,
               checkpoint):

    #history record file
    history_file = open(r'history_delta.txt', 'w')

    # Load batches for each iteration
    training_batches = [batch2TrainData(voc, [random.choice(pairs) for _ in range(batch_size)])
                      for _ in range(n_iteration)]
    training_batches_validation = [batch2TrainData(voc_validation, [random.choice(pairs_validation) for _ in range(batch_size)])
                        for _ in range(n_iteration)]

    # Initializations
    print('Initializing ...')
    start_iteration = 1
    print_loss = 0
    print_loss_validation = 0
    if loadFilename:
        start_iteration = checkpoint['iteration'] + 1

    # Training loop
    print("Training...")
    for iteration in range(start_iteration, n_iteration + 1):
        training_batch = training_batches[iteration - 1]
        training_batch_validation = training_batches_validation[iteration - 1]

        # Extract fields from batch
        input_variable, lengths, target_variable, mask, max_target_len = training_batch
        input_variable_validation, lengths_validation, target_variable_validation, mask_validation, max_target_len_validation = training_batch_validation

        # Run a training iteration with batch
        loss = train(input_variable, lengths, target_variable, mask, max_target_len, encoder,
                     decoder, embedding, encoder_optimizer, decoder_optimizer, batch_size, clip)
        print_loss += loss
        loss_validation = validation(input_variable_validation, lengths_validation, target_variable_validation, mask_validation, max_target_len_validation, encoder,
                     decoder, embedding, encoder_optimizer, decoder_optimizer, batch_size, clip)
        print_loss_validation += loss_validation

        # Print progress
        if iteration % print_every == 0:
            print_loss_avg = print_loss / print_every
            print_loss_avg_validation = print_loss_validation / print_every
            print("Iteration: {}; Percent complete: {:.1f}%; Training loss: {:.4f}; Validation loss: {:.4f}".format(iteration, iteration / n_iteration * 100, print_loss_avg, print_loss_avg_validation))
            history_file.write('{}'.format(print_loss_avg))
            history_file.write(' ')
            history_file.write('{}'.format(print_loss_avg_validation))
            history_file.write("\n")

            print_loss = 0
            print_loss_validation = 0

# %%
def evaluate(encoder, decoder, searcher, voc, sentence, max_length=MAX_LENGTH):
    ### Format input sentence as a batch
    # words -> indexes
    indexes_batch = [indexesFromSentence(voc, sentence)]
    # Create lengths tensor
    lengths = torch.tensor([len(indexes) for indexes in indexes_batch])
    # Transpose dimensions of batch to match models' expectations
    input_batch = torch.LongTensor(indexes_batch).transpose(0, 1)
    # Use appropriate device
    input_batch = input_batch.to(device)
    lengths = lengths.to(device)
    # Decode sentence with searcher
    tokens, scores = searcher(input_batch, lengths, max_length)
    # indexes -> words
    decoded_words = [voc.index2word[token.item()] for token in tokens]
    return decoded_words


def evaluateInput(encoder, decoder, searcher, voc):
    input_sentence = ''
    while(1):
        try:
            # Get input sentence
            input_sentence = input('> ')
            # Check if it is quit case
            if input_sentence == 'q' or input_sentence == 'quit': break
            # Normalize sentence
            input_sentence = normalizeString(input_sentence)
            # Evaluate sentence
            start_time = time.time()
            output_words = evaluate(encoder, decoder, searcher, voc, input_sentence)
            # Format and print response sentence
            output_words[:] = [x for x in output_words if not (x == 'EOS' or x == 'PAD')]
            print('Bot:', ' '.join(output_words))
            end_time = time.time()
            print('Responding time:', end_time - start_time)
        except KeyError:
            print("Error: Encountered unknown word.")

# %%
def rand_pick(probabilities):
    x=random.uniform(0,1)
    #print(probabilities[0][20])
    cumulative_probability = 0.0
    #list = [n for n in range(len(probabilities))]
    for item in range(len(probabilities[0])):
        cumulative_probability += probabilities[0][item]
        if x < cumulative_probability:
            break
    item_list = torch.zeros([1], device=device, dtype=torch.long)
    item_list[0] = item
    score = torch.zeros([1],device=device)
    score[0]=probabilities[0][item]
    
    return item_list, score

class SearchDecoder(nn.Module):
    def __init__(self, encoder, decoder, batch_size=1):
        super(SearchDecoder, self).__init__()
        self.encoder = encoder
        self.decoder = decoder
        self.batch_size = batch_size

    def forward(self, input_seq, input_length, max_length):
        # Forward input through encoder model
        encoder_outputs, encoder_hidden, codes = self.encoder(input_seq, input_length)
        # Prepare encoder's final hidden layer to be first hidden input to the decoder
        decoder_hidden = encoder_hidden[:self.decoder.n_layers]
        # Initialize decoder input with SOS_token
        decoder_input = torch.ones(1, 1, device=device, dtype=torch.long) * SOS_token
        # Initialize tensors to append decoded words to
        all_tokens = torch.zeros([0], device=device, dtype=torch.long)
        all_scores = torch.zeros([0], device=device)
        # Iteratively decode one word token at a time
        for _ in range(max_length):
            # Forward pass through decoder
            decoder_output, decoder_hidden = self.decoder(decoder_input,
                                                          decoder_hidden,
                                                          encoder_outputs,
                                                          codes,
                                                          self.batch_size)
            # Obtain word based on probability distribution token and its softmax score
            decoder_input, decoder_scores = my_random_pick(decoder_output)
            # Record token and score
            all_tokens = torch.cat((all_tokens, decoder_input), dim=0)
            all_scores = torch.cat((all_scores, decoder_scores), dim=0)
            # Prepare current token to be next decoder input (add a dimension)
            decoder_input = torch.unsqueeze(decoder_input, 0)
        # Return collections of word tokens and scores
        return all_tokens, all_scores

# %%
class TopicAttention(nn.Module):
    def __init__(self, topic_vocab_size, enc_hid_dim, dec_hid_dim):
        super(TopicAttention, self).__init__()
        self.enc_hid_dim = enc_hid_dim
        self.dec_hid_dim = dec_hid_dim

        self.attn = nn.Linear(topic_vocab_size + dec_hid_dim + enc_hid_dim, dec_hid_dim)
        self.v = nn.Parameter(torch.rand(dec_hid_dim))

    def forward(self, hidden, topic_dict, enc_hidden):
        batch_size = enc_hidden.shape[0]
        num_topics = topic_dict.shape[0]

        hidden = hidden.repeat(num_topics, 1, 1).permute(1, 0, 2)
        enc_hidden = enc_hidden.repeat(num_topics, 1, 1).permute(1, 0, 2)
        topic_dict = topic_dict.repeat(batch_size, 1, 1)

        
        energy = torch.tanh(self.attn(torch.cat((hidden, topic_dict, enc_hidden), dim=2)))

        # energy = [batch_size, dec_hid_dim]
        energy = energy.permute(0, 2, 1)

        v = self.v.repeat(batch_size, 1).unsqueeze(1)

        # v = [batch_size, 1, dec_hid_dim]
        attention = torch.bmm(v, energy).squeeze(1)

        return F.softmax(attention, dim=1).unsqueeze(1)

# %%
class TopicDecoder(nn.Module):
    def __init__(self,
                 attn_model,
                 embedding,
                 hidden_size,
                 output_size,
                 enc_hid_dim,
                 dec_hid_dim,
                 topics,
                 topic_vocab_size,
                 n_layers=1,
                 dropout=0.1,
                 batch_size=1):
        super(TopicDecoder, self).__init__()

        # Keep for reference
        self.attn_model = attn_model
        self.hidden_size = hidden_size
        self.output_size = output_size
        self.n_layers = n_layers
        self.dropout = dropout
        self.enc_hid_dim = enc_hid_dim
        self.dec_hid_dim = dec_hid_dim
        self.topics = topics
        self.topic_vocab_size = topic_vocab_size
        self.batch_size = batch_size

        # Define layers
        self.embedding = embedding
        self.embedding_dropout = nn.Dropout(dropout)
        self.gru = nn.GRU(hidden_size, hidden_size, n_layers, dropout=(0 if n_layers == 1 else dropout))
        self.concat = nn.Linear(hidden_size * 2 + topic_vocab_size + 1000, hidden_size) #1000 is len of topic dictionary
        self.out = nn.Linear(hidden_size, output_size)

        self.attn = Attn(attn_model, hidden_size)
        self.topic_attn = TopicAttention(topic_vocab_size, enc_hid_dim, dec_hid_dim)

    def forward(self,
                input_step,
                last_hidden,
                encoder_outputs,
                codes,
                batch_size=1):
        # Note: we run this one step (word) at a time
        # Get embedding of current input word
        embedded = self.embedding(input_step)
        embedded = self.embedding_dropout(embedded)
        # Forward through unidirectional GRU
        rnn_output, hidden = self.gru(embedded, last_hidden)

        # Calculate attention weights from the current GRU output
        attn_weights = self.attn(rnn_output, encoder_outputs)
        topic_attn_weights = self.topic_attn(last_hidden, self.topics, encoder_outputs[-1])

        # Multiply attention weights to encoder outputs to get new "weighted sum" context vector
        encoder_outputs = encoder_outputs.permute(1,0,2)
      
        context = torch.bmm(attn_weights, encoder_outputs)
     
        topic_context = torch.bmm(topic_attn_weights, self.topics.repeat(batch_size, 1, 1))
       
        topic_for_Pk = self.topics.repeat(batch_size,1,1).permute(0,2,1)
        # print('topic_for_Pk',topic_for_Pk.size())
        Pk_context = torch.bmm(topic_for_Pk, codes)
        # print('Pk_context',Pk_context.size())

        # Concatenate weighted context vector and GRU output using Luong eq. 5
       
        rnn_output = rnn_output.squeeze(0)
        context = context.squeeze(1)
        topic_context = topic_context.squeeze(1)
      
        Pk_context = Pk_context.squeeze(2)
        concat_input = torch.cat((rnn_output, context, topic_context, Pk_context), 1)
        # print('concat_input', concat_input.size())
        concat_output = torch.tanh(self.concat(concat_input))

        # Predict next word using Luong eq. 6
        output = self.out(concat_output)
        output = F.softmax(output, dim=1)
        # Return output and final hidden state
        return output, hidden

# %%
# Configure models
model_name = 'topic_model'
attn_model = 'dot'
hidden_size = 500
encoder_n_layers = 1
decoder_n_layers = 1
dropout = 0.1
batch_size = 1 # 64 for training, 1 for chatting

# %%
DICT_NAME = 'data/topic/news'
DICT_PATH = DICT_NAME + '-lda.npz'
print("DICT_PATH",DICT_PATH)
topic_dict = torch.tensor(np.load(DICT_PATH)["dictionary"], dtype=torch.float).to(device)
# Out:
# DICT_PATH data/topic/news-lda.npz

# %%
# Set checkpoint to load from
loadFilename = None
checkpoint_iter = 64000

# %%
print('Building encoder and decoder ...')
# Initialize word embeddings
embedding = nn.Embedding(voc.num_words, hidden_size)
if loadFilename:
    embedding.load_state_dict(embedding_sd)

# Initialize encoder & decoder models
encoder = EncoderRNN(hidden_size=hidden_size,
                             embedding=embedding,
                             topics=topic_dict,
                             n_layers=encoder_n_layers,
                             dropout=dropout,
                             batch_size=batch_size)

enc_hid_dim, dec_hid_dim, emb_dim = hidden_size, hidden_size, hidden_size

decoder = TopicDecoder(attn_model,
                                  embedding,
                                  hidden_size,
                                  voc.num_words,
                                  enc_hid_dim,
                                  dec_hid_dim,
                                  topic_dict,
                                  topic_dict.shape[1],
                                  decoder_n_layers,
                                  dropout)
if loadFilename:
    encoder.load_state_dict(encoder_sd)
    decoder.load_state_dict(decoder_sd)

# Use appropriate device
encoder = encoder.to(device)
decoder = decoder.to(device)
print('Models built and ready to go!')
# Out:
# Building encoder and decoder ...
# Models built and ready to go!

# %%
#start training
# Configure training/optimization
clip = 50.0
teacher_forcing_ratio = 1.0
learning_rate = 0.0001
decoder_learning_ratio = 5.0
n_iteration = 10000
print_every = 1
save_every = 100

# Ensure dropout layers are in train mode
encoder.train()
decoder.train()

# Initialize optimizers
print('Building optimizers ...')
encoder_optimizer = optim.Adam(encoder.parameters(), lr=learning_rate)
decoder_optimizer = optim.Adam(decoder.parameters(), lr=learning_rate * decoder_learning_ratio)
if loadFilename:
    encoder_optimizer.load_state_dict(encoder_optimizer_sd)
    decoder_optimizer.load_state_dict(decoder_optimizer_sd)

# If you have cuda, configure cuda to call
for state in encoder_optimizer.state.values():
    for k, v in state.items():
        if isinstance(v, torch.Tensor):
            state[k] = v.cuda()

for state in decoder_optimizer.state.values():
    for k, v in state.items():
        if isinstance(v, torch.Tensor):
            state[k] = v.cuda()

# Run training iterations
print("Starting Training!")
trainIters(model_name=model_name,
                   voc=voc,
                   voc_validation=voc_validation,
                   pairs=pairs,
                   pairs_validation=pairs_validation,
                   encoder=encoder,
                   decoder=decoder,
                   encoder_optimizer=encoder_optimizer,
                   decoder_optimizer=decoder_optimizer,
                   embedding=embedding,
                   encoder_n_layers=encoder_n_layers,
                   decoder_n_layers=decoder_n_layers,
                   save_dir=save_dir,
                   n_iteration=n_iteration,
                   batch_size=batch_size,
                   print_every=print_every,
                   save_every=save_every,
                   clip=clip,
                   corpus_name=corpus_name,
                   loadFilename=loadFilename,
                   DICT_NAME=DICT_NAME,
                   checkpoint=None)
# Out:
# Building optimizers ...
# Starting Training!
# Initializing ...
# Training...
# Iteration: 1; Percent complete: 0.0%; Training loss: 9.6455; Validation loss: 9.4591
# Iteration: 2; Percent complete: 0.0%; Training loss: 9.3333; Validation loss: 9.2758
# Iteration: 3; Percent complete: 0.0%; Training loss: 8.8919; Validation loss: 8.8792
# Iteration: 4; Percent complete: 0.0%; Training loss: 8.4588; Validation loss: 8.8420
# Iteration: 5; Percent complete: 0.1%; Training loss: 8.0139; Validation loss: 8.3881
# Iteration: 6; Percent complete: 0.1%; Training loss: 7.5489; Validation loss: 8.2012
# Iteration: 7; Percent complete: 0.1%; Training loss: 7.2515; Validation loss: 8.0170
# Iteration: 8; Percent complete: 0.1%; Training loss: 7.3038; Validation loss: 8.0796
# Iteration: 9; Percent complete: 0.1%; Training loss: 7.2709; Validation loss: 7.9820
# Iteration: 10; Percent complete: 0.1%; Training loss: 7.1980; Validation loss: 7.9168
# Iteration: 11; Percent complete: 0.1%; Training loss: 6.6402; Validation loss: 7.7141
# Iteration: 12; Percent complete: 0.1%; Training loss: 6.4170; Validation loss: 7.4403
# Iteration: 13; Percent complete: 0.1%; Training loss: 6.1985; Validation loss: 7.4828
# Iteration: 14; Percent complete: 0.1%; Training loss: 5.7328; Validation loss: 7.4374
# Iteration: 15; Percent complete: 0.1%; Training loss: 6.0955; Validation loss: 7.5879
# Iteration: 16; Percent complete: 0.2%; Training loss: 5.7960; Validation loss: 7.5022
# Iteration: 17; Percent complete: 0.2%; Training loss: 5.6885; Validation loss: 7.3763
# Iteration: 18; Percent complete: 0.2%; Training loss: 5.8375; Validation loss: 7.3413
# Iteration: 19; Percent complete: 0.2%; Training loss: 5.5980; Validation loss: 7.3036
# Iteration: 20; Percent complete: 0.2%; Training loss: 5.4619; Validation loss: 7.1562
# Iteration: 21; Percent complete: 0.2%; Training loss: 5.1355; Validation loss: 7.0765
# Iteration: 22; Percent complete: 0.2%; Training loss: 5.0579; Validation loss: 7.2747
# Iteration: 23; Percent complete: 0.2%; Training loss: 5.2371; Validation loss: 7.0451
# Iteration: 24; Percent complete: 0.2%; Training loss: 5.1457; Validation loss: 7.0106
# Iteration: 25; Percent complete: 0.2%; Training loss: 5.0088; Validation loss: 7.2398
# Iteration: 26; Percent complete: 0.3%; Training loss: 5.2790; Validation loss: 6.9493
# Iteration: 27; Percent complete: 0.3%; Training loss: 5.0674; Validation loss: 7.1819
# Iteration: 28; Percent complete: 0.3%; Training loss: 5.1529; Validation loss: 6.8880
# Iteration: 29; Percent complete: 0.3%; Training loss: 5.1261; Validation loss: 7.0100
# Iteration: 30; Percent complete: 0.3%; Training loss: 5.1996; Validation loss: 7.4462
# Iteration: 31; Percent complete: 0.3%; Training loss: 5.2447; Validation loss: 7.3631
# Iteration: 32; Percent complete: 0.3%; Training loss: 4.6835; Validation loss: 7.2447
# Iteration: 33; Percent complete: 0.3%; Training loss: 5.0029; Validation loss: 7.0244
# Iteration: 34; Percent complete: 0.3%; Training loss: 5.1332; Validation loss: 7.1850
# Iteration: 35; Percent complete: 0.4%; Training loss: 5.2762; Validation loss: 6.6385
# Iteration: 36; Percent complete: 0.4%; Training loss: 4.8031; Validation loss: 7.1590
# Iteration: 37; Percent complete: 0.4%; Training loss: 4.9858; Validation loss: 7.1435
# Iteration: 38; Percent complete: 0.4%; Training loss: 4.9698; Validation loss: 7.0982
# Iteration: 39; Percent complete: 0.4%; Training loss: 4.8911; Validation loss: 7.1571
# Iteration: 40; Percent complete: 0.4%; Training loss: 5.0660; Validation loss: 7.1699
# Iteration: 41; Percent complete: 0.4%; Training loss: 4.8760; Validation loss: 7.4285
# Iteration: 42; Percent complete: 0.4%; Training loss: 4.8452; Validation loss: 7.3177
# Iteration: 43; Percent complete: 0.4%; Training loss: 5.1028; Validation loss: 7.3501
# Iteration: 44; Percent complete: 0.4%; Training loss: 4.6080; Validation loss: 7.4526
# Iteration: 45; Percent complete: 0.4%; Training loss: 4.9919; Validation loss: 7.4311
# Iteration: 46; Percent complete: 0.5%; Training loss: 4.6402; Validation loss: 7.6484
# Iteration: 47; Percent complete: 0.5%; Training loss: 4.6292; Validation loss: 7.5629
# Iteration: 48; Percent complete: 0.5%; Training loss: 4.9809; Validation loss: 7.5689
# Iteration: 49; Percent complete: 0.5%; Training loss: 4.7583; Validation loss: 7.7259
# Iteration: 50; Percent complete: 0.5%; Training loss: 5.0109; Validation loss: 7.3508
# Iteration: 51; Percent complete: 0.5%; Training loss: 4.8651; Validation loss: 7.1463
# Iteration: 52; Percent complete: 0.5%; Training loss: 4.6777; Validation loss: 7.7047
# Iteration: 53; Percent complete: 0.5%; Training loss: 4.7915; Validation loss: 7.1983
# Iteration: 54; Percent complete: 0.5%; Training loss: 4.6787; Validation loss: 7.6112
# Iteration: 55; Percent complete: 0.5%; Training loss: 4.9027; Validation loss: 7.4722
# Iteration: 56; Percent complete: 0.6%; Training loss: 4.9386; Validation loss: 7.2789
# Iteration: 57; Percent complete: 0.6%; Training loss: 4.7688; Validation loss: 7.4201
# Iteration: 58; Percent complete: 0.6%; Training loss: 4.9510; Validation loss: 7.5106
# Iteration: 59; Percent complete: 0.6%; Training loss: 4.6759; Validation loss: 7.4512
# Iteration: 60; Percent complete: 0.6%; Training loss: 4.6511; Validation loss: 7.4091
# Iteration: 61; Percent complete: 0.6%; Training loss: 4.6322; Validation loss: 7.7193
# Iteration: 62; Percent complete: 0.6%; Training loss: 4.5956; Validation loss: 7.6223
# Iteration: 63; Percent complete: 0.6%; Training loss: 4.8840; Validation loss: 7.3704
# Iteration: 64; Percent complete: 0.6%; Training loss: 4.8246; Validation loss: 7.2284
# Iteration: 65; Percent complete: 0.7%; Training loss: 4.7043; Validation loss: 7.6823
# Iteration: 66; Percent complete: 0.7%; Training loss: 4.9013; Validation loss: 7.5397
# Iteration: 67; Percent complete: 0.7%; Training loss: 4.8287; Validation loss: 7.3977
# Iteration: 68; Percent complete: 0.7%; Training loss: 4.6771; Validation loss: 7.6369
# Iteration: 69; Percent complete: 0.7%; Training loss: 4.8526; Validation loss: 7.4405
# Iteration: 70; Percent complete: 0.7%; Training loss: 4.7023; Validation loss: 7.5416
# Iteration: 71; Percent complete: 0.7%; Training loss: 4.7377; Validation loss: 7.5156
# Iteration: 72; Percent complete: 0.7%; Training loss: 4.7650; Validation loss: 7.7300
# Iteration: 73; Percent complete: 0.7%; Training loss: 4.8593; Validation loss: 7.4837
# Iteration: 74; Percent complete: 0.7%; Training loss: 4.5615; Validation loss: 7.4650
# Iteration: 75; Percent complete: 0.8%; Training loss: 4.6040; Validation loss: 7.4091
# Iteration: 76; Percent complete: 0.8%; Training loss: 4.7848; Validation loss: 7.4234
# Iteration: 77; Percent complete: 0.8%; Training loss: 4.7588; Validation loss: 7.6924
# Iteration: 78; Percent complete: 0.8%; Training loss: 4.5243; Validation loss: 7.6148
# Iteration: 79; Percent complete: 0.8%; Training loss: 4.3938; Validation loss: 7.4280
# Iteration: 80; Percent complete: 0.8%; Training loss: 4.4780; Validation loss: 7.4590
# Iteration: 81; Percent complete: 0.8%; Training loss: 4.8096; Validation loss: 7.5754
# Iteration: 82; Percent complete: 0.8%; Training loss: 4.5103; Validation loss: 7.4737
# Iteration: 83; Percent complete: 0.8%; Training loss: 4.3539; Validation loss: 7.5321
# Iteration: 84; Percent complete: 0.8%; Training loss: 4.4753; Validation loss: 7.5611
# Iteration: 85; Percent complete: 0.9%; Training loss: 4.6663; Validation loss: 7.7290
# Iteration: 86; Percent complete: 0.9%; Training loss: 4.4045; Validation loss: 7.5090
# Iteration: 87; Percent complete: 0.9%; Training loss: 4.3721; Validation loss: 7.8438
# Iteration: 88; Percent complete: 0.9%; Training loss: 4.6220; Validation loss: 7.7148
# Iteration: 89; Percent complete: 0.9%; Training loss: 4.7049; Validation loss: 7.6624
# Iteration: 90; Percent complete: 0.9%; Training loss: 4.8900; Validation loss: 7.2715
# Iteration: 91; Percent complete: 0.9%; Training loss: 4.5319; Validation loss: 7.3461
# Iteration: 92; Percent complete: 0.9%; Training loss: 4.5553; Validation loss: 7.4859
# Iteration: 93; Percent complete: 0.9%; Training loss: 4.3601; Validation loss: 7.4914
# Iteration: 94; Percent complete: 0.9%; Training loss: 4.7603; Validation loss: 7.5313
# Iteration: 95; Percent complete: 0.9%; Training loss: 4.3819; Validation loss: 7.4898
# Iteration: 96; Percent complete: 1.0%; Training loss: 4.4387; Validation loss: 7.4025
# Iteration: 97; Percent complete: 1.0%; Training loss: 4.7317; Validation loss: 7.3248
# Iteration: 98; Percent complete: 1.0%; Training loss: 4.9077; Validation loss: 7.4756
# Iteration: 99; Percent complete: 1.0%; Training loss: 4.3607; Validation loss: 7.7515
# Iteration: 100; Percent complete: 1.0%; Training loss: 4.7195; Validation loss: 7.3063
# Iteration: 101; Percent complete: 1.0%; Training loss: 4.5413; Validation loss: 7.3426
# Iteration: 102; Percent complete: 1.0%; Training loss: 4.6390; Validation loss: 7.4348
# Iteration: 103; Percent complete: 1.0%; Training loss: 4.7192; Validation loss: 7.3067
# Iteration: 104; Percent complete: 1.0%; Training loss: 4.4623; Validation loss: 7.6797
# Iteration: 105; Percent complete: 1.1%; Training loss: 4.7238; Validation loss: 7.3014
# Iteration: 106; Percent complete: 1.1%; Training loss: 4.4814; Validation loss: 7.3493
# Iteration: 107; Percent complete: 1.1%; Training loss: 4.7293; Validation loss: 7.3324
# Iteration: 108; Percent complete: 1.1%; Training loss: 4.6669; Validation loss: 7.3809
# Iteration: 109; Percent complete: 1.1%; Training loss: 4.4296; Validation loss: 7.8207
# Iteration: 110; Percent complete: 1.1%; Training loss: 4.7624; Validation loss: 7.2274
# Iteration: 111; Percent complete: 1.1%; Training loss: 4.5124; Validation loss: 7.6546
# Iteration: 112; Percent complete: 1.1%; Training loss: 4.5230; Validation loss: 7.3972
# Iteration: 113; Percent complete: 1.1%; Training loss: 4.5917; Validation loss: 7.6187
# Iteration: 114; Percent complete: 1.1%; Training loss: 4.3127; Validation loss: 7.8026
# Iteration: 115; Percent complete: 1.1%; Training loss: 4.4747; Validation loss: 7.7619
# Iteration: 116; Percent complete: 1.2%; Training loss: 4.5366; Validation loss: 7.5946
# Iteration: 117; Percent complete: 1.2%; Training loss: 4.5295; Validation loss: 7.6026
# Iteration: 118; Percent complete: 1.2%; Training loss: 4.2611; Validation loss: 7.5798
# Iteration: 119; Percent complete: 1.2%; Training loss: 4.2496; Validation loss: 7.5716
# Iteration: 120; Percent complete: 1.2%; Training loss: 4.6475; Validation loss: 7.4798
# Iteration: 121; Percent complete: 1.2%; Training loss: 4.6350; Validation loss: 7.6819
# Iteration: 122; Percent complete: 1.2%; Training loss: 4.3526; Validation loss: 7.4664
# Iteration: 123; Percent complete: 1.2%; Training loss: 4.3121; Validation loss: 7.7922
# Iteration: 124; Percent complete: 1.2%; Training loss: 4.6039; Validation loss: 7.5073
# Iteration: 125; Percent complete: 1.2%; Training loss: 4.4915; Validation loss: 7.8182
# Iteration: 126; Percent complete: 1.3%; Training loss: 4.2998; Validation loss: 7.6238
# Iteration: 127; Percent complete: 1.3%; Training loss: 4.5411; Validation loss: 7.6892
# Iteration: 128; Percent complete: 1.3%; Training loss: 4.1560; Validation loss: 7.7681
# Iteration: 129; Percent complete: 1.3%; Training loss: 4.3925; Validation loss: 7.6640
# Iteration: 130; Percent complete: 1.3%; Training loss: 4.3059; Validation loss: 7.9445
# Iteration: 131; Percent complete: 1.3%; Training loss: 4.0431; Validation loss: 7.6688
# Iteration: 132; Percent complete: 1.3%; Training loss: 4.1862; Validation loss: 7.8156
# Iteration: 133; Percent complete: 1.3%; Training loss: 4.3207; Validation loss: 7.9582
# Iteration: 134; Percent complete: 1.3%; Training loss: 4.4600; Validation loss: 7.5231
# Iteration: 135; Percent complete: 1.4%; Training loss: 4.2253; Validation loss: 7.6578
# Iteration: 136; Percent complete: 1.4%; Training loss: 4.5574; Validation loss: 7.5445
# Iteration: 137; Percent complete: 1.4%; Training loss: 4.3274; Validation loss: 7.6005
# Iteration: 138; Percent complete: 1.4%; Training loss: 4.7423; Validation loss: 7.9336
# Iteration: 139; Percent complete: 1.4%; Training loss: 4.4958; Validation loss: 7.6498
# Iteration: 140; Percent complete: 1.4%; Training loss: 4.5151; Validation loss: 7.6846
# Iteration: 141; Percent complete: 1.4%; Training loss: 4.3669; Validation loss: 7.9741
# Iteration: 142; Percent complete: 1.4%; Training loss: 4.3649; Validation loss: 7.4605
# Iteration: 143; Percent complete: 1.4%; Training loss: 4.3677; Validation loss: 7.4021
# Iteration: 144; Percent complete: 1.4%; Training loss: 4.5548; Validation loss: 7.7918
# Iteration: 145; Percent complete: 1.5%; Training loss: 4.2317; Validation loss: 7.3193
# Iteration: 146; Percent complete: 1.5%; Training loss: 4.4636; Validation loss: 7.6228
# Iteration: 147; Percent complete: 1.5%; Training loss: 4.4138; Validation loss: 7.5663
# Iteration: 148; Percent complete: 1.5%; Training loss: 4.2262; Validation loss: 7.4461
# Iteration: 149; Percent complete: 1.5%; Training loss: 4.1990; Validation loss: 7.5784
# Iteration: 150; Percent complete: 1.5%; Training loss: 4.3171; Validation loss: 7.5112
# Iteration: 151; Percent complete: 1.5%; Training loss: 4.3260; Validation loss: 7.3523
# Iteration: 152; Percent complete: 1.5%; Training loss: 4.4224; Validation loss: 7.1469
# Iteration: 153; Percent complete: 1.5%; Training loss: 4.3943; Validation loss: 7.6094
# Iteration: 154; Percent complete: 1.5%; Training loss: 4.4886; Validation loss: 7.8490
# Iteration: 155; Percent complete: 1.6%; Training loss: 4.2743; Validation loss: 7.6501
# Iteration: 156; Percent complete: 1.6%; Training loss: 4.5386; Validation loss: 7.6707
# Iteration: 157; Percent complete: 1.6%; Training loss: 4.2669; Validation loss: 7.5110
# Iteration: 158; Percent complete: 1.6%; Training loss: 4.4268; Validation loss: 7.7147
# Iteration: 159; Percent complete: 1.6%; Training loss: 4.2137; Validation loss: 7.5832
# Iteration: 160; Percent complete: 1.6%; Training loss: 4.7291; Validation loss: 7.6297
# Iteration: 161; Percent complete: 1.6%; Training loss: 4.1478; Validation loss: 7.5275
# Iteration: 162; Percent complete: 1.6%; Training loss: 4.2953; Validation loss: 7.7920
# Iteration: 163; Percent complete: 1.6%; Training loss: 4.5698; Validation loss: 8.0372
# Iteration: 164; Percent complete: 1.6%; Training loss: 4.2297; Validation loss: 7.4666
# Iteration: 165; Percent complete: 1.7%; Training loss: 4.2928; Validation loss: 8.0721
# Iteration: 166; Percent complete: 1.7%; Training loss: 4.5046; Validation loss: 7.5288
# Iteration: 167; Percent complete: 1.7%; Training loss: 4.1993; Validation loss: 8.1581
# Iteration: 168; Percent complete: 1.7%; Training loss: 4.1138; Validation loss: 7.6420
# Iteration: 169; Percent complete: 1.7%; Training loss: 4.3221; Validation loss: 7.7024
# Iteration: 170; Percent complete: 1.7%; Training loss: 4.2811; Validation loss: 7.6255
# Iteration: 171; Percent complete: 1.7%; Training loss: 3.9759; Validation loss: 8.0778
# Iteration: 172; Percent complete: 1.7%; Training loss: 4.3587; Validation loss: 7.6314
# Iteration: 173; Percent complete: 1.7%; Training loss: 4.1792; Validation loss: 7.8809
# Iteration: 174; Percent complete: 1.7%; Training loss: 4.4233; Validation loss: 7.6308
# Iteration: 175; Percent complete: 1.8%; Training loss: 4.3851; Validation loss: 7.9021
# Iteration: 176; Percent complete: 1.8%; Training loss: 4.2756; Validation loss: 7.6856
# Iteration: 177; Percent complete: 1.8%; Training loss: 4.2297; Validation loss: 7.6312
# Iteration: 178; Percent complete: 1.8%; Training loss: 4.1696; Validation loss: 7.7283
# Iteration: 179; Percent complete: 1.8%; Training loss: 4.1694; Validation loss: 7.7559
# Iteration: 180; Percent complete: 1.8%; Training loss: 4.2578; Validation loss: 7.5768
# Iteration: 181; Percent complete: 1.8%; Training loss: 4.2610; Validation loss: 7.8682
# Iteration: 182; Percent complete: 1.8%; Training loss: 4.4229; Validation loss: 7.7518
# Iteration: 183; Percent complete: 1.8%; Training loss: 4.3525; Validation loss: 7.7875
# Iteration: 184; Percent complete: 1.8%; Training loss: 4.3384; Validation loss: 7.9883
# Iteration: 185; Percent complete: 1.8%; Training loss: 4.0980; Validation loss: 8.0076
# Iteration: 186; Percent complete: 1.9%; Training loss: 4.0410; Validation loss: 7.5572
# Iteration: 187; Percent complete: 1.9%; Training loss: 4.0761; Validation loss: 7.9112
# Iteration: 188; Percent complete: 1.9%; Training loss: 4.1560; Validation loss: 7.9178
# Iteration: 189; Percent complete: 1.9%; Training loss: 4.3427; Validation loss: 7.4773
# Iteration: 190; Percent complete: 1.9%; Training loss: 4.3468; Validation loss: 7.8893
# Iteration: 191; Percent complete: 1.9%; Training loss: 4.3964; Validation loss: 7.9794
# Iteration: 192; Percent complete: 1.9%; Training loss: 4.2471; Validation loss: 7.7313
# Iteration: 193; Percent complete: 1.9%; Training loss: 4.2205; Validation loss: 7.8005
# Iteration: 194; Percent complete: 1.9%; Training loss: 4.5411; Validation loss: 7.6419
# Iteration: 195; Percent complete: 1.9%; Training loss: 4.2252; Validation loss: 7.4914
# Iteration: 196; Percent complete: 2.0%; Training loss: 4.3122; Validation loss: 7.9124
# Iteration: 197; Percent complete: 2.0%; Training loss: 4.2970; Validation loss: 7.6416
# Iteration: 198; Percent complete: 2.0%; Training loss: 4.3420; Validation loss: 7.7646
# Iteration: 199; Percent complete: 2.0%; Training loss: 4.3072; Validation loss: 7.6221
# Iteration: 200; Percent complete: 2.0%; Training loss: 4.3304; Validation loss: 7.6534
# Iteration: 201; Percent complete: 2.0%; Training loss: 4.1609; Validation loss: 8.0615
# Iteration: 202; Percent complete: 2.0%; Training loss: 4.0969; Validation loss: 7.9427
# Iteration: 203; Percent complete: 2.0%; Training loss: 4.2654; Validation loss: 7.7062
# Iteration: 204; Percent complete: 2.0%; Training loss: 4.2715; Validation loss: 7.5523
# Iteration: 205; Percent complete: 2.1%; Training loss: 4.5559; Validation loss: 7.6628
# Iteration: 206; Percent complete: 2.1%; Training loss: 4.3515; Validation loss: 7.1886
# Iteration: 207; Percent complete: 2.1%; Training loss: 3.9970; Validation loss: 7.6987
# Iteration: 208; Percent complete: 2.1%; Training loss: 3.9979; Validation loss: 7.3996
# Iteration: 209; Percent complete: 2.1%; Training loss: 4.0921; Validation loss: 7.6313
# Iteration: 210; Percent complete: 2.1%; Training loss: 4.5754; Validation loss: 7.4998
# Iteration: 211; Percent complete: 2.1%; Training loss: 4.3088; Validation loss: 7.7079
# Iteration: 212; Percent complete: 2.1%; Training loss: 4.1275; Validation loss: 7.4350
# Iteration: 213; Percent complete: 2.1%; Training loss: 4.1313; Validation loss: 7.4497
# Iteration: 214; Percent complete: 2.1%; Training loss: 4.0857; Validation loss: 7.6055
# Iteration: 215; Percent complete: 2.1%; Training loss: 4.1087; Validation loss: 7.8709
# Iteration: 216; Percent complete: 2.2%; Training loss: 4.3364; Validation loss: 7.7106
# Iteration: 217; Percent complete: 2.2%; Training loss: 4.2643; Validation loss: 7.5915
# Iteration: 218; Percent complete: 2.2%; Training loss: 4.2904; Validation loss: 7.8261
# Iteration: 219; Percent complete: 2.2%; Training loss: 4.1183; Validation loss: 7.8138
# Iteration: 220; Percent complete: 2.2%; Training loss: 4.0659; Validation loss: 7.7744
# Iteration: 221; Percent complete: 2.2%; Training loss: 4.0691; Validation loss: 7.5289
# Iteration: 222; Percent complete: 2.2%; Training loss: 4.2168; Validation loss: 8.0390
# Iteration: 223; Percent complete: 2.2%; Training loss: 4.2267; Validation loss: 7.8171
# Iteration: 224; Percent complete: 2.2%; Training loss: 4.0655; Validation loss: 7.7614
# Iteration: 225; Percent complete: 2.2%; Training loss: 4.1047; Validation loss: 7.4614
# Iteration: 226; Percent complete: 2.3%; Training loss: 4.2893; Validation loss: 7.9794
# Iteration: 227; Percent complete: 2.3%; Training loss: 4.2335; Validation loss: 7.7378
# Iteration: 228; Percent complete: 2.3%; Training loss: 4.3773; Validation loss: 7.8135
# Iteration: 229; Percent complete: 2.3%; Training loss: 4.0718; Validation loss: 7.7021
# Iteration: 230; Percent complete: 2.3%; Training loss: 4.0577; Validation loss: 8.1084
# Iteration: 231; Percent complete: 2.3%; Training loss: 4.1643; Validation loss: 7.6945
# Iteration: 232; Percent complete: 2.3%; Training loss: 4.1256; Validation loss: 7.9967
# Iteration: 233; Percent complete: 2.3%; Training loss: 3.8140; Validation loss: 7.6917
# Iteration: 234; Percent complete: 2.3%; Training loss: 4.2651; Validation loss: 7.8830
# Iteration: 235; Percent complete: 2.4%; Training loss: 4.2788; Validation loss: 7.4963
# Iteration: 236; Percent complete: 2.4%; Training loss: 4.1441; Validation loss: 7.9426
# Iteration: 237; Percent complete: 2.4%; Training loss: 4.0709; Validation loss: 7.8360
# Iteration: 238; Percent complete: 2.4%; Training loss: 4.1135; Validation loss: 8.0289
# Iteration: 239; Percent complete: 2.4%; Training loss: 4.0804; Validation loss: 7.8040
# Iteration: 240; Percent complete: 2.4%; Training loss: 4.1545; Validation loss: 7.7993
# Iteration: 241; Percent complete: 2.4%; Training loss: 4.1200; Validation loss: 7.9344
# Iteration: 242; Percent complete: 2.4%; Training loss: 4.2173; Validation loss: 7.5835
# Iteration: 243; Percent complete: 2.4%; Training loss: 4.1663; Validation loss: 7.8113
# Iteration: 244; Percent complete: 2.4%; Training loss: 4.1741; Validation loss: 7.7134
# Iteration: 245; Percent complete: 2.5%; Training loss: 4.1575; Validation loss: 7.7059
# Iteration: 246; Percent complete: 2.5%; Training loss: 4.3202; Validation loss: 7.4606
# Iteration: 247; Percent complete: 2.5%; Training loss: 3.9918; Validation loss: 7.8425
# Iteration: 248; Percent complete: 2.5%; Training loss: 4.0124; Validation loss: 7.6211
# Iteration: 249; Percent complete: 2.5%; Training loss: 4.0278; Validation loss: 8.0067
# Iteration: 250; Percent complete: 2.5%; Training loss: 4.3793; Validation loss: 7.7090
# Iteration: 251; Percent complete: 2.5%; Training loss: 4.1310; Validation loss: 7.4681
# Iteration: 252; Percent complete: 2.5%; Training loss: 4.2832; Validation loss: 7.6226
# Iteration: 253; Percent complete: 2.5%; Training loss: 3.8227; Validation loss: 7.6415
# Iteration: 254; Percent complete: 2.5%; Training loss: 4.3151; Validation loss: 7.8814
# Iteration: 255; Percent complete: 2.5%; Training loss: 4.1402; Validation loss: 8.0471
# Iteration: 256; Percent complete: 2.6%; Training loss: 4.2629; Validation loss: 7.9968
# Iteration: 257; Percent complete: 2.6%; Training loss: 4.1630; Validation loss: 7.8224
# Iteration: 258; Percent complete: 2.6%; Training loss: 3.9452; Validation loss: 8.1914
# Iteration: 259; Percent complete: 2.6%; Training loss: 4.0621; Validation loss: 8.2298
# Iteration: 260; Percent complete: 2.6%; Training loss: 4.1847; Validation loss: 8.2420
# Iteration: 261; Percent complete: 2.6%; Training loss: 4.5332; Validation loss: 7.8631
# Iteration: 262; Percent complete: 2.6%; Training loss: 4.2616; Validation loss: 8.1748
# Iteration: 263; Percent complete: 2.6%; Training loss: 3.9954; Validation loss: 8.2062
# Iteration: 264; Percent complete: 2.6%; Training loss: 4.2425; Validation loss: 8.3535
# Iteration: 265; Percent complete: 2.6%; Training loss: 4.2151; Validation loss: 7.9268
# Iteration: 266; Percent complete: 2.7%; Training loss: 4.4796; Validation loss: 7.7930
# Iteration: 267; Percent complete: 2.7%; Training loss: 4.2323; Validation loss: 7.9337
# Iteration: 268; Percent complete: 2.7%; Training loss: 4.1513; Validation loss: 7.8381
# Iteration: 269; Percent complete: 2.7%; Training loss: 4.0775; Validation loss: 7.7522
# Iteration: 270; Percent complete: 2.7%; Training loss: 4.2617; Validation loss: 8.2297
# Iteration: 271; Percent complete: 2.7%; Training loss: 4.2184; Validation loss: 7.7298
# Iteration: 272; Percent complete: 2.7%; Training loss: 4.1047; Validation loss: 7.7359
# Iteration: 273; Percent complete: 2.7%; Training loss: 4.0052; Validation loss: 7.7656
# Iteration: 274; Percent complete: 2.7%; Training loss: 3.9955; Validation loss: 7.8633
# Iteration: 275; Percent complete: 2.8%; Training loss: 4.1116; Validation loss: 7.7461
# Iteration: 276; Percent complete: 2.8%; Training loss: 4.2192; Validation loss: 7.7129
# Iteration: 277; Percent complete: 2.8%; Training loss: 4.2383; Validation loss: 7.9083
# Iteration: 278; Percent complete: 2.8%; Training loss: 4.1130; Validation loss: 7.8532
# Iteration: 279; Percent complete: 2.8%; Training loss: 4.3682; Validation loss: 7.6576
# Iteration: 280; Percent complete: 2.8%; Training loss: 4.1877; Validation loss: 7.6839
# Iteration: 281; Percent complete: 2.8%; Training loss: 3.9717; Validation loss: 7.8374
# Iteration: 282; Percent complete: 2.8%; Training loss: 4.1738; Validation loss: 8.0615
# Iteration: 283; Percent complete: 2.8%; Training loss: 4.1019; Validation loss: 7.6852
# Iteration: 284; Percent complete: 2.8%; Training loss: 4.1656; Validation loss: 8.2928
# Iteration: 285; Percent complete: 2.9%; Training loss: 4.1439; Validation loss: 7.7873
# Iteration: 286; Percent complete: 2.9%; Training loss: 4.4024; Validation loss: 8.1242
# Iteration: 287; Percent complete: 2.9%; Training loss: 4.1641; Validation loss: 7.6705
# Iteration: 288; Percent complete: 2.9%; Training loss: 4.2176; Validation loss: 7.9662
# Iteration: 289; Percent complete: 2.9%; Training loss: 4.2568; Validation loss: 7.8198
# Iteration: 290; Percent complete: 2.9%; Training loss: 3.8219; Validation loss: 8.0065
# Iteration: 291; Percent complete: 2.9%; Training loss: 4.5140; Validation loss: 7.6661
# Iteration: 292; Percent complete: 2.9%; Training loss: 3.9985; Validation loss: 8.0263
# Iteration: 293; Percent complete: 2.9%; Training loss: 4.0507; Validation loss: 8.2324
# Iteration: 294; Percent complete: 2.9%; Training loss: 4.2387; Validation loss: 7.8806
# Iteration: 295; Percent complete: 2.9%; Training loss: 4.1276; Validation loss: 7.7369
# Iteration: 296; Percent complete: 3.0%; Training loss: 4.5105; Validation loss: 7.9131
# Iteration: 297; Percent complete: 3.0%; Training loss: 3.9801; Validation loss: 7.9713
# Iteration: 298; Percent complete: 3.0%; Training loss: 4.1992; Validation loss: 7.6589
# Iteration: 299; Percent complete: 3.0%; Training loss: 3.9802; Validation loss: 7.9898
# Iteration: 300; Percent complete: 3.0%; Training loss: 3.9974; Validation loss: 7.8028
# Iteration: 301; Percent complete: 3.0%; Training loss: 4.2176; Validation loss: 8.2193
# Iteration: 302; Percent complete: 3.0%; Training loss: 3.9335; Validation loss: 7.8462
# Iteration: 303; Percent complete: 3.0%; Training loss: 4.2574; Validation loss: 8.0646
# Iteration: 304; Percent complete: 3.0%; Training loss: 4.3153; Validation loss: 7.7732
# Iteration: 305; Percent complete: 3.0%; Training loss: 4.0958; Validation loss: 8.2901
# Iteration: 306; Percent complete: 3.1%; Training loss: 4.2906; Validation loss: 7.8722
# Iteration: 307; Percent complete: 3.1%; Training loss: 3.9852; Validation loss: 7.8404
# Iteration: 308; Percent complete: 3.1%; Training loss: 3.9757; Validation loss: 8.3189
# Iteration: 309; Percent complete: 3.1%; Training loss: 3.8639; Validation loss: 8.0818
# Iteration: 310; Percent complete: 3.1%; Training loss: 4.4107; Validation loss: 7.6575
# Iteration: 311; Percent complete: 3.1%; Training loss: 4.3051; Validation loss: 7.7562
# Iteration: 312; Percent complete: 3.1%; Training loss: 3.9337; Validation loss: 7.7819
# Iteration: 313; Percent complete: 3.1%; Training loss: 4.0073; Validation loss: 7.7993
# Iteration: 314; Percent complete: 3.1%; Training loss: 4.2074; Validation loss: 7.7667
# Iteration: 315; Percent complete: 3.1%; Training loss: 4.2578; Validation loss: 7.6354
# Iteration: 316; Percent complete: 3.2%; Training loss: 4.2937; Validation loss: 7.4148
# Iteration: 317; Percent complete: 3.2%; Training loss: 4.0182; Validation loss: 7.8305
# Iteration: 318; Percent complete: 3.2%; Training loss: 4.0906; Validation loss: 7.5365
# Iteration: 319; Percent complete: 3.2%; Training loss: 4.0732; Validation loss: 8.1281
# Iteration: 320; Percent complete: 3.2%; Training loss: 4.0127; Validation loss: 7.7191
# Iteration: 321; Percent complete: 3.2%; Training loss: 3.8952; Validation loss: 8.1830
# Iteration: 322; Percent complete: 3.2%; Training loss: 3.9672; Validation loss: 7.8772
# Iteration: 323; Percent complete: 3.2%; Training loss: 4.0775; Validation loss: 8.3262
# Iteration: 324; Percent complete: 3.2%; Training loss: 4.1759; Validation loss: 8.3926
# Iteration: 325; Percent complete: 3.2%; Training loss: 4.0670; Validation loss: 8.0624
# Iteration: 326; Percent complete: 3.3%; Training loss: 4.0202; Validation loss: 7.6939
# Iteration: 327; Percent complete: 3.3%; Training loss: 4.2630; Validation loss: 8.0443
# Iteration: 328; Percent complete: 3.3%; Training loss: 3.8365; Validation loss: 7.9684
# Iteration: 329; Percent complete: 3.3%; Training loss: 4.0679; Validation loss: 8.2435
# Iteration: 330; Percent complete: 3.3%; Training loss: 4.0502; Validation loss: 7.9307
# Iteration: 331; Percent complete: 3.3%; Training loss: 3.8309; Validation loss: 8.0672
# Iteration: 332; Percent complete: 3.3%; Training loss: 3.8636; Validation loss: 8.0125
# Iteration: 333; Percent complete: 3.3%; Training loss: 4.0268; Validation loss: 8.0759
# Iteration: 334; Percent complete: 3.3%; Training loss: 4.2840; Validation loss: 8.0082
# Iteration: 335; Percent complete: 3.4%; Training loss: 3.6560; Validation loss: 7.8472
# Iteration: 336; Percent complete: 3.4%; Training loss: 4.3222; Validation loss: 8.0339
# Iteration: 337; Percent complete: 3.4%; Training loss: 4.1550; Validation loss: 8.0253
# Iteration: 338; Percent complete: 3.4%; Training loss: 3.9899; Validation loss: 7.8319
# Iteration: 339; Percent complete: 3.4%; Training loss: 4.3610; Validation loss: 8.0800
# Iteration: 340; Percent complete: 3.4%; Training loss: 3.9313; Validation loss: 8.2757
# Iteration: 341; Percent complete: 3.4%; Training loss: 3.8975; Validation loss: 7.9527
# Iteration: 342; Percent complete: 3.4%; Training loss: 3.9951; Validation loss: 7.9155
# Iteration: 343; Percent complete: 3.4%; Training loss: 3.9279; Validation loss: 7.9093
# Iteration: 344; Percent complete: 3.4%; Training loss: 3.7363; Validation loss: 7.7987
# Iteration: 345; Percent complete: 3.5%; Training loss: 3.8883; Validation loss: 7.5005
# Iteration: 346; Percent complete: 3.5%; Training loss: 4.2197; Validation loss: 8.1470
# Iteration: 347; Percent complete: 3.5%; Training loss: 4.0940; Validation loss: 8.2081
# Iteration: 348; Percent complete: 3.5%; Training loss: 4.3246; Validation loss: 7.9420
# Iteration: 349; Percent complete: 3.5%; Training loss: 3.9173; Validation loss: 7.8331
# Iteration: 350; Percent complete: 3.5%; Training loss: 4.0619; Validation loss: 8.0122
# Iteration: 351; Percent complete: 3.5%; Training loss: 4.0396; Validation loss: 7.8132
# Iteration: 352; Percent complete: 3.5%; Training loss: 3.9992; Validation loss: 8.2205
# Iteration: 353; Percent complete: 3.5%; Training loss: 3.9847; Validation loss: 7.9800
# Iteration: 354; Percent complete: 3.5%; Training loss: 3.9863; Validation loss: 7.5967
# Iteration: 355; Percent complete: 3.5%; Training loss: 4.0283; Validation loss: 8.2064
# Iteration: 356; Percent complete: 3.6%; Training loss: 3.9838; Validation loss: 8.2930
# Iteration: 357; Percent complete: 3.6%; Training loss: 4.1604; Validation loss: 7.9423
# Iteration: 358; Percent complete: 3.6%; Training loss: 4.0400; Validation loss: 8.0262
# Iteration: 359; Percent complete: 3.6%; Training loss: 3.8113; Validation loss: 8.2171
# Iteration: 360; Percent complete: 3.6%; Training loss: 3.8958; Validation loss: 8.4583
# Iteration: 361; Percent complete: 3.6%; Training loss: 4.0604; Validation loss: 7.8979
# Iteration: 362; Percent complete: 3.6%; Training loss: 3.5894; Validation loss: 8.0410
# Iteration: 363; Percent complete: 3.6%; Training loss: 4.0750; Validation loss: 8.0299
# Iteration: 364; Percent complete: 3.6%; Training loss: 4.0581; Validation loss: 7.8492
# Iteration: 365; Percent complete: 3.6%; Training loss: 3.9646; Validation loss: 8.3000
# Iteration: 366; Percent complete: 3.7%; Training loss: 4.0361; Validation loss: 8.1322
# Iteration: 367; Percent complete: 3.7%; Training loss: 3.8524; Validation loss: 8.2799
# Iteration: 368; Percent complete: 3.7%; Training loss: 4.0332; Validation loss: 8.0472
# Iteration: 369; Percent complete: 3.7%; Training loss: 3.9405; Validation loss: 8.0409
# Iteration: 370; Percent complete: 3.7%; Training loss: 4.0400; Validation loss: 8.2486
# Iteration: 371; Percent complete: 3.7%; Training loss: 3.8168; Validation loss: 8.3279
# Iteration: 372; Percent complete: 3.7%; Training loss: 3.9444; Validation loss: 8.1700
# Iteration: 373; Percent complete: 3.7%; Training loss: 4.2210; Validation loss: 7.8407
# Iteration: 374; Percent complete: 3.7%; Training loss: 3.9688; Validation loss: 8.2977
# Iteration: 375; Percent complete: 3.8%; Training loss: 3.9582; Validation loss: 7.9548
# Iteration: 376; Percent complete: 3.8%; Training loss: 4.2149; Validation loss: 8.0599
# Iteration: 377; Percent complete: 3.8%; Training loss: 4.3592; Validation loss: 7.7190
# Iteration: 378; Percent complete: 3.8%; Training loss: 4.0271; Validation loss: 8.0075
# Iteration: 379; Percent complete: 3.8%; Training loss: 3.7377; Validation loss: 7.8690
# Iteration: 380; Percent complete: 3.8%; Training loss: 3.7814; Validation loss: 8.0267
# Iteration: 381; Percent complete: 3.8%; Training loss: 4.0023; Validation loss: 8.1190
# Iteration: 382; Percent complete: 3.8%; Training loss: 3.8159; Validation loss: 8.0653
# Iteration: 383; Percent complete: 3.8%; Training loss: 3.9617; Validation loss: 7.8170
# Iteration: 384; Percent complete: 3.8%; Training loss: 4.0154; Validation loss: 7.9074
# Iteration: 385; Percent complete: 3.9%; Training loss: 4.2363; Validation loss: 8.0455
# Iteration: 386; Percent complete: 3.9%; Training loss: 3.9401; Validation loss: 7.7656
# Iteration: 387; Percent complete: 3.9%; Training loss: 4.1137; Validation loss: 8.0834
# Iteration: 388; Percent complete: 3.9%; Training loss: 4.2651; Validation loss: 7.9125
# Iteration: 389; Percent complete: 3.9%; Training loss: 4.1861; Validation loss: 7.6268
# Iteration: 390; Percent complete: 3.9%; Training loss: 3.8006; Validation loss: 7.7826
# Iteration: 391; Percent complete: 3.9%; Training loss: 3.9662; Validation loss: 7.7376
# Iteration: 392; Percent complete: 3.9%; Training loss: 4.0381; Validation loss: 7.8416
# Iteration: 393; Percent complete: 3.9%; Training loss: 3.8887; Validation loss: 8.0716
# Iteration: 394; Percent complete: 3.9%; Training loss: 4.1498; Validation loss: 7.8746
# Iteration: 395; Percent complete: 4.0%; Training loss: 3.8633; Validation loss: 7.8291
# Iteration: 396; Percent complete: 4.0%; Training loss: 3.8610; Validation loss: 7.8469
# Iteration: 397; Percent complete: 4.0%; Training loss: 3.9608; Validation loss: 7.7268
# Iteration: 398; Percent complete: 4.0%; Training loss: 4.1497; Validation loss: 7.9366
# Iteration: 399; Percent complete: 4.0%; Training loss: 3.9366; Validation loss: 7.9786
# Iteration: 400; Percent complete: 4.0%; Training loss: 4.2722; Validation loss: 7.8365
# Iteration: 401; Percent complete: 4.0%; Training loss: 3.9125; Validation loss: 7.9092
# Iteration: 402; Percent complete: 4.0%; Training loss: 4.0944; Validation loss: 7.8737
# Iteration: 403; Percent complete: 4.0%; Training loss: 3.9157; Validation loss: 7.9794
# Iteration: 404; Percent complete: 4.0%; Training loss: 4.1141; Validation loss: 7.9016
# Iteration: 405; Percent complete: 4.0%; Training loss: 3.7953; Validation loss: 7.8796
# Iteration: 406; Percent complete: 4.1%; Training loss: 3.9411; Validation loss: 8.0165
# Iteration: 407; Percent complete: 4.1%; Training loss: 3.6808; Validation loss: 8.2822
# Iteration: 408; Percent complete: 4.1%; Training loss: 4.0714; Validation loss: 7.9852
# Iteration: 409; Percent complete: 4.1%; Training loss: 3.8465; Validation loss: 7.5597
# Iteration: 410; Percent complete: 4.1%; Training loss: 4.1782; Validation loss: 8.1213
# Iteration: 411; Percent complete: 4.1%; Training loss: 4.0746; Validation loss: 7.9601
# Iteration: 412; Percent complete: 4.1%; Training loss: 4.0246; Validation loss: 7.9733
# Iteration: 413; Percent complete: 4.1%; Training loss: 3.9016; Validation loss: 7.7577
# Iteration: 414; Percent complete: 4.1%; Training loss: 4.1201; Validation loss: 7.9290
# Iteration: 415; Percent complete: 4.2%; Training loss: 3.7243; Validation loss: 7.6938
# Iteration: 416; Percent complete: 4.2%; Training loss: 4.2943; Validation loss: 7.9373
# Iteration: 417; Percent complete: 4.2%; Training loss: 3.7735; Validation loss: 8.1750
# Iteration: 418; Percent complete: 4.2%; Training loss: 3.8714; Validation loss: 8.1321
# Iteration: 419; Percent complete: 4.2%; Training loss: 4.0659; Validation loss: 8.1167
# Iteration: 420; Percent complete: 4.2%; Training loss: 3.7754; Validation loss: 8.0415
# Iteration: 421; Percent complete: 4.2%; Training loss: 4.0974; Validation loss: 8.0167
# Iteration: 422; Percent complete: 4.2%; Training loss: 3.9778; Validation loss: 8.1891
# Iteration: 423; Percent complete: 4.2%; Training loss: 4.0016; Validation loss: 7.7200
# Iteration: 424; Percent complete: 4.2%; Training loss: 4.1164; Validation loss: 8.1928
# Iteration: 425; Percent complete: 4.2%; Training loss: 4.1131; Validation loss: 8.1607
# Iteration: 426; Percent complete: 4.3%; Training loss: 3.9967; Validation loss: 7.9914
# Iteration: 427; Percent complete: 4.3%; Training loss: 3.9959; Validation loss: 8.1287
# Iteration: 428; Percent complete: 4.3%; Training loss: 4.1394; Validation loss: 7.9893
# Iteration: 429; Percent complete: 4.3%; Training loss: 4.1780; Validation loss: 8.0148
# Iteration: 430; Percent complete: 4.3%; Training loss: 3.8617; Validation loss: 8.0437
# Iteration: 431; Percent complete: 4.3%; Training loss: 3.7455; Validation loss: 7.6470
# Iteration: 432; Percent complete: 4.3%; Training loss: 3.9707; Validation loss: 8.0019
# Iteration: 433; Percent complete: 4.3%; Training loss: 4.1047; Validation loss: 8.4863
# Iteration: 434; Percent complete: 4.3%; Training loss: 3.8186; Validation loss: 8.2609
# Iteration: 435; Percent complete: 4.3%; Training loss: 3.8679; Validation loss: 8.2539
# Iteration: 436; Percent complete: 4.4%; Training loss: 3.8993; Validation loss: 8.1155
# Iteration: 437; Percent complete: 4.4%; Training loss: 4.2986; Validation loss: 8.0355
# Iteration: 438; Percent complete: 4.4%; Training loss: 3.8466; Validation loss: 8.0441
# Iteration: 439; Percent complete: 4.4%; Training loss: 3.7339; Validation loss: 8.1159
# Iteration: 440; Percent complete: 4.4%; Training loss: 4.0055; Validation loss: 8.2191
# Iteration: 441; Percent complete: 4.4%; Training loss: 3.7211; Validation loss: 8.0182
# Iteration: 442; Percent complete: 4.4%; Training loss: 3.8094; Validation loss: 8.1965
# Iteration: 443; Percent complete: 4.4%; Training loss: 4.1691; Validation loss: 7.9925
# Iteration: 444; Percent complete: 4.4%; Training loss: 4.0610; Validation loss: 8.2942
# Iteration: 445; Percent complete: 4.5%; Training loss: 3.5062; Validation loss: 7.9849
# Iteration: 446; Percent complete: 4.5%; Training loss: 3.7725; Validation loss: 8.0270
# Iteration: 447; Percent complete: 4.5%; Training loss: 4.0855; Validation loss: 8.2816
# Iteration: 448; Percent complete: 4.5%; Training loss: 4.0959; Validation loss: 7.9825
# Iteration: 449; Percent complete: 4.5%; Training loss: 4.2601; Validation loss: 8.0599
# Iteration: 450; Percent complete: 4.5%; Training loss: 3.9077; Validation loss: 7.8652
# Iteration: 451; Percent complete: 4.5%; Training loss: 3.9354; Validation loss: 8.1177
# Iteration: 452; Percent complete: 4.5%; Training loss: 4.0529; Validation loss: 8.0585
# Iteration: 453; Percent complete: 4.5%; Training loss: 4.0469; Validation loss: 7.9717
# Iteration: 454; Percent complete: 4.5%; Training loss: 3.8362; Validation loss: 8.1537
# Iteration: 455; Percent complete: 4.5%; Training loss: 3.9220; Validation loss: 8.0405
# Iteration: 456; Percent complete: 4.6%; Training loss: 3.9724; Validation loss: 8.2016
# Iteration: 457; Percent complete: 4.6%; Training loss: 3.9765; Validation loss: 8.5695
# Iteration: 458; Percent complete: 4.6%; Training loss: 3.8483; Validation loss: 8.3277
# Iteration: 459; Percent complete: 4.6%; Training loss: 4.0095; Validation loss: 8.2150
# Iteration: 460; Percent complete: 4.6%; Training loss: 3.9586; Validation loss: 7.7910
# Iteration: 461; Percent complete: 4.6%; Training loss: 3.9539; Validation loss: 7.9707
# Iteration: 462; Percent complete: 4.6%; Training loss: 3.8333; Validation loss: 8.2028
# Iteration: 463; Percent complete: 4.6%; Training loss: 3.8532; Validation loss: 8.3797
# Iteration: 464; Percent complete: 4.6%; Training loss: 3.7788; Validation loss: 8.0936
# Iteration: 465; Percent complete: 4.7%; Training loss: 3.8846; Validation loss: 8.3097
# Iteration: 466; Percent complete: 4.7%; Training loss: 3.8265; Validation loss: 7.9962
# Iteration: 467; Percent complete: 4.7%; Training loss: 3.8767; Validation loss: 7.9974
# Iteration: 468; Percent complete: 4.7%; Training loss: 4.0043; Validation loss: 8.2746
# Iteration: 469; Percent complete: 4.7%; Training loss: 3.6874; Validation loss: 8.2020
# Iteration: 470; Percent complete: 4.7%; Training loss: 3.8845; Validation loss: 8.0197
# Iteration: 471; Percent complete: 4.7%; Training loss: 3.8169; Validation loss: 8.2563
# Iteration: 472; Percent complete: 4.7%; Training loss: 3.9174; Validation loss: 7.9751
# Iteration: 473; Percent complete: 4.7%; Training loss: 3.9357; Validation loss: 8.0329
# Iteration: 474; Percent complete: 4.7%; Training loss: 3.8481; Validation loss: 7.9440
# Iteration: 475; Percent complete: 4.8%; Training loss: 4.0823; Validation loss: 8.0323
# Iteration: 476; Percent complete: 4.8%; Training loss: 4.2459; Validation loss: 7.9791
# Iteration: 477; Percent complete: 4.8%; Training loss: 4.0802; Validation loss: 8.0817
# Iteration: 478; Percent complete: 4.8%; Training loss: 3.8020; Validation loss: 8.2114
# Iteration: 479; Percent complete: 4.8%; Training loss: 3.7107; Validation loss: 8.0432
# Iteration: 480; Percent complete: 4.8%; Training loss: 3.7066; Validation loss: 8.0205
# Iteration: 481; Percent complete: 4.8%; Training loss: 4.0872; Validation loss: 7.4877
# Iteration: 482; Percent complete: 4.8%; Training loss: 4.2383; Validation loss: 7.9062
# Iteration: 483; Percent complete: 4.8%; Training loss: 3.5953; Validation loss: 7.6310
# Iteration: 484; Percent complete: 4.8%; Training loss: 3.8968; Validation loss: 8.0068
# Iteration: 485; Percent complete: 4.9%; Training loss: 3.7303; Validation loss: 8.0869
# Iteration: 486; Percent complete: 4.9%; Training loss: 4.2225; Validation loss: 8.1007
# Iteration: 487; Percent complete: 4.9%; Training loss: 4.1438; Validation loss: 7.9562
# Iteration: 488; Percent complete: 4.9%; Training loss: 4.3048; Validation loss: 7.9876
# Iteration: 489; Percent complete: 4.9%; Training loss: 3.8015; Validation loss: 7.9444
# Iteration: 490; Percent complete: 4.9%; Training loss: 4.1329; Validation loss: 7.8383
# Iteration: 491; Percent complete: 4.9%; Training loss: 4.0662; Validation loss: 7.9460
# Iteration: 492; Percent complete: 4.9%; Training loss: 3.9143; Validation loss: 7.7635
# Iteration: 493; Percent complete: 4.9%; Training loss: 3.8823; Validation loss: 7.9855
# Iteration: 494; Percent complete: 4.9%; Training loss: 4.0184; Validation loss: 7.9281
# Iteration: 495; Percent complete: 5.0%; Training loss: 4.1357; Validation loss: 7.6776
# Iteration: 496; Percent complete: 5.0%; Training loss: 3.7680; Validation loss: 7.9235
# Iteration: 497; Percent complete: 5.0%; Training loss: 3.7272; Validation loss: 7.4139
# Iteration: 498; Percent complete: 5.0%; Training loss: 3.9582; Validation loss: 7.8166
# Iteration: 499; Percent complete: 5.0%; Training loss: 4.1426; Validation loss: 8.1516
# Iteration: 500; Percent complete: 5.0%; Training loss: 4.0218; Validation loss: 7.6987
# Iteration: 501; Percent complete: 5.0%; Training loss: 3.5571; Validation loss: 7.9724
# Iteration: 502; Percent complete: 5.0%; Training loss: 3.7094; Validation loss: 8.1531
# Iteration: 503; Percent complete: 5.0%; Training loss: 3.7132; Validation loss: 7.9818
# Iteration: 504; Percent complete: 5.0%; Training loss: 3.8661; Validation loss: 8.4636
# Iteration: 505; Percent complete: 5.1%; Training loss: 4.1928; Validation loss: 7.9397
# Iteration: 506; Percent complete: 5.1%; Training loss: 3.7571; Validation loss: 7.9496
# Iteration: 507; Percent complete: 5.1%; Training loss: 3.9991; Validation loss: 8.0789
# Iteration: 508; Percent complete: 5.1%; Training loss: 3.8473; Validation loss: 7.7011
# Iteration: 509; Percent complete: 5.1%; Training loss: 4.0081; Validation loss: 8.0779
# Iteration: 510; Percent complete: 5.1%; Training loss: 3.9457; Validation loss: 8.0409
# Iteration: 511; Percent complete: 5.1%; Training loss: 4.0699; Validation loss: 7.8545
# Iteration: 512; Percent complete: 5.1%; Training loss: 3.9498; Validation loss: 8.0917
# Iteration: 513; Percent complete: 5.1%; Training loss: 3.9657; Validation loss: 7.9098
# Iteration: 514; Percent complete: 5.1%; Training loss: 3.7190; Validation loss: 8.0786
# Iteration: 515; Percent complete: 5.1%; Training loss: 3.7894; Validation loss: 7.9432
# Iteration: 516; Percent complete: 5.2%; Training loss: 4.1903; Validation loss: 8.1138
# Iteration: 517; Percent complete: 5.2%; Training loss: 3.6761; Validation loss: 8.0096
# Iteration: 518; Percent complete: 5.2%; Training loss: 4.2281; Validation loss: 8.2030
# Iteration: 519; Percent complete: 5.2%; Training loss: 3.6255; Validation loss: 7.9245
# Iteration: 520; Percent complete: 5.2%; Training loss: 4.1044; Validation loss: 7.9741
# Iteration: 521; Percent complete: 5.2%; Training loss: 3.7632; Validation loss: 8.0023
# Iteration: 522; Percent complete: 5.2%; Training loss: 3.7877; Validation loss: 8.1682
# Iteration: 523; Percent complete: 5.2%; Training loss: 3.7259; Validation loss: 7.5055
# Iteration: 524; Percent complete: 5.2%; Training loss: 3.7256; Validation loss: 7.9873
# Iteration: 525; Percent complete: 5.2%; Training loss: 3.6071; Validation loss: 8.2288
# Iteration: 526; Percent complete: 5.3%; Training loss: 4.0106; Validation loss: 8.2060
# Iteration: 527; Percent complete: 5.3%; Training loss: 3.9520; Validation loss: 7.8487
# Iteration: 528; Percent complete: 5.3%; Training loss: 3.9143; Validation loss: 8.0219
# Iteration: 529; Percent complete: 5.3%; Training loss: 3.7889; Validation loss: 7.9741
# Iteration: 530; Percent complete: 5.3%; Training loss: 3.6327; Validation loss: 7.8966
# Iteration: 531; Percent complete: 5.3%; Training loss: 4.1460; Validation loss: 7.7188
# Iteration: 532; Percent complete: 5.3%; Training loss: 3.9890; Validation loss: 7.6675
# Iteration: 533; Percent complete: 5.3%; Training loss: 3.9222; Validation loss: 7.9791
# Iteration: 534; Percent complete: 5.3%; Training loss: 3.9506; Validation loss: 7.8405
# Iteration: 535; Percent complete: 5.3%; Training loss: 3.7059; Validation loss: 7.6429
# Iteration: 536; Percent complete: 5.4%; Training loss: 3.6644; Validation loss: 7.8913
# Iteration: 537; Percent complete: 5.4%; Training loss: 3.8193; Validation loss: 7.8439
# Iteration: 538; Percent complete: 5.4%; Training loss: 3.8140; Validation loss: 8.1704
# Iteration: 539; Percent complete: 5.4%; Training loss: 3.8937; Validation loss: 8.2383
# Iteration: 540; Percent complete: 5.4%; Training loss: 3.9747; Validation loss: 8.1531
# Iteration: 541; Percent complete: 5.4%; Training loss: 3.9702; Validation loss: 7.8457
# Iteration: 542; Percent complete: 5.4%; Training loss: 3.9747; Validation loss: 8.1296
# Iteration: 543; Percent complete: 5.4%; Training loss: 4.1788; Validation loss: 7.7039
# Iteration: 544; Percent complete: 5.4%; Training loss: 4.0175; Validation loss: 8.0294
# Iteration: 545; Percent complete: 5.5%; Training loss: 4.2228; Validation loss: 8.2110
# Iteration: 546; Percent complete: 5.5%; Training loss: 4.3099; Validation loss: 8.0745
# Iteration: 547; Percent complete: 5.5%; Training loss: 3.6994; Validation loss: 7.9113
# Iteration: 548; Percent complete: 5.5%; Training loss: 3.8114; Validation loss: 7.9679
# Iteration: 549; Percent complete: 5.5%; Training loss: 4.2387; Validation loss: 7.6422
# Iteration: 550; Percent complete: 5.5%; Training loss: 3.7703; Validation loss: 7.8332
# Iteration: 551; Percent complete: 5.5%; Training loss: 3.7011; Validation loss: 8.2736
# Iteration: 552; Percent complete: 5.5%; Training loss: 3.8292; Validation loss: 8.2862
# ...
# Iteration: 9824; Percent complete: 98.2%; Training loss: 1.4315; Validation loss: 10.6000
# Iteration: 9825; Percent complete: 98.2%; Training loss: 1.4853; Validation loss: 10.2978
# Iteration: 9826; Percent complete: 98.3%; Training loss: 1.7365; Validation loss: 10.7570
# Iteration: 9827; Percent complete: 98.3%; Training loss: 1.3190; Validation loss: 10.5069
# Iteration: 9828; Percent complete: 98.3%; Training loss: 1.4086; Validation loss: 10.6463
# Iteration: 9829; Percent complete: 98.3%; Training loss: 1.2501; Validation loss: 10.2739
# Iteration: 9830; Percent complete: 98.3%; Training loss: 1.4669; Validation loss: 10.9683
# Iteration: 9831; Percent complete: 98.3%; Training loss: 1.4193; Validation loss: 10.9172
# Iteration: 9832; Percent complete: 98.3%; Training loss: 1.4385; Validation loss: 10.5403
# Iteration: 9833; Percent complete: 98.3%; Training loss: 1.2388; Validation loss: 10.7485
# Iteration: 9834; Percent complete: 98.3%; Training loss: 1.5252; Validation loss: 11.0496
# Iteration: 9835; Percent complete: 98.4%; Training loss: 1.3672; Validation loss: 10.7615
# Iteration: 9836; Percent complete: 98.4%; Training loss: 1.3200; Validation loss: 10.6096
# Iteration: 9837; Percent complete: 98.4%; Training loss: 1.3311; Validation loss: 10.4301
# Iteration: 9838; Percent complete: 98.4%; Training loss: 1.4231; Validation loss: 10.4264
# Iteration: 9839; Percent complete: 98.4%; Training loss: 1.1835; Validation loss: 11.6386
# Iteration: 9840; Percent complete: 98.4%; Training loss: 1.4138; Validation loss: 11.1554
# Iteration: 9841; Percent complete: 98.4%; Training loss: 1.5533; Validation loss: 10.0270
# Iteration: 9842; Percent complete: 98.4%; Training loss: 1.3230; Validation loss: 11.2516
# Iteration: 9843; Percent complete: 98.4%; Training loss: 1.3976; Validation loss: 11.0273
# Iteration: 9844; Percent complete: 98.4%; Training loss: 1.4467; Validation loss: 11.3869
# Iteration: 9845; Percent complete: 98.5%; Training loss: 1.3118; Validation loss: 10.9242
# Iteration: 9846; Percent complete: 98.5%; Training loss: 1.4637; Validation loss: 11.1982
# Iteration: 9847; Percent complete: 98.5%; Training loss: 1.4756; Validation loss: 10.7964
# Iteration: 9848; Percent complete: 98.5%; Training loss: 1.3013; Validation loss: 10.9037
# Iteration: 9849; Percent complete: 98.5%; Training loss: 1.4707; Validation loss: 10.7371
# Iteration: 9850; Percent complete: 98.5%; Training loss: 1.3247; Validation loss: 10.6022
# Iteration: 9851; Percent complete: 98.5%; Training loss: 1.1031; Validation loss: 10.8219
# Iteration: 9852; Percent complete: 98.5%; Training loss: 1.3557; Validation loss: 10.6096
# Iteration: 9853; Percent complete: 98.5%; Training loss: 1.5308; Validation loss: 10.9603
# Iteration: 9854; Percent complete: 98.5%; Training loss: 1.4008; Validation loss: 10.6124
# Iteration: 9855; Percent complete: 98.6%; Training loss: 1.4249; Validation loss: 9.9064
# Iteration: 9856; Percent complete: 98.6%; Training loss: 1.2971; Validation loss: 11.2814
# Iteration: 9857; Percent complete: 98.6%; Training loss: 1.3757; Validation loss: 10.4785
# Iteration: 9858; Percent complete: 98.6%; Training loss: 1.4140; Validation loss: 10.7155
# Iteration: 9859; Percent complete: 98.6%; Training loss: 1.3873; Validation loss: 10.6142
# Iteration: 9860; Percent complete: 98.6%; Training loss: 1.3606; Validation loss: 10.6651
# Iteration: 9861; Percent complete: 98.6%; Training loss: 1.4306; Validation loss: 10.5921
# Iteration: 9862; Percent complete: 98.6%; Training loss: 1.4912; Validation loss: 10.1677
# Iteration: 9863; Percent complete: 98.6%; Training loss: 1.5697; Validation loss: 10.7651
# Iteration: 9864; Percent complete: 98.6%; Training loss: 1.2602; Validation loss: 10.7305
# Iteration: 9865; Percent complete: 98.7%; Training loss: 1.2678; Validation loss: 11.0505
# Iteration: 9866; Percent complete: 98.7%; Training loss: 1.4435; Validation loss: 10.8790
# Iteration: 9867; Percent complete: 98.7%; Training loss: 1.3388; Validation loss: 10.5961
# Iteration: 9868; Percent complete: 98.7%; Training loss: 1.2440; Validation loss: 10.4919
# Iteration: 9869; Percent complete: 98.7%; Training loss: 1.2823; Validation loss: 10.8854
# Iteration: 9870; Percent complete: 98.7%; Training loss: 1.3905; Validation loss: 10.2141
# Iteration: 9871; Percent complete: 98.7%; Training loss: 1.4128; Validation loss: 9.9846
# Iteration: 9872; Percent complete: 98.7%; Training loss: 1.4091; Validation loss: 10.6124
# Iteration: 9873; Percent complete: 98.7%; Training loss: 1.2977; Validation loss: 10.5871
# Iteration: 9874; Percent complete: 98.7%; Training loss: 1.5884; Validation loss: 10.8469
# Iteration: 9875; Percent complete: 98.8%; Training loss: 1.5230; Validation loss: 10.4723
# Iteration: 9876; Percent complete: 98.8%; Training loss: 1.4631; Validation loss: 10.7116
# Iteration: 9877; Percent complete: 98.8%; Training loss: 1.3114; Validation loss: 10.6460
# Iteration: 9878; Percent complete: 98.8%; Training loss: 1.3971; Validation loss: 10.9185
# Iteration: 9879; Percent complete: 98.8%; Training loss: 1.4283; Validation loss: 11.2409
# Iteration: 9880; Percent complete: 98.8%; Training loss: 1.3486; Validation loss: 10.7346
# Iteration: 9881; Percent complete: 98.8%; Training loss: 1.3340; Validation loss: 10.8025
# Iteration: 9882; Percent complete: 98.8%; Training loss: 1.4578; Validation loss: 11.0187
# Iteration: 9883; Percent complete: 98.8%; Training loss: 1.5878; Validation loss: 10.8414
# Iteration: 9884; Percent complete: 98.8%; Training loss: 1.3837; Validation loss: 10.6041
# Iteration: 9885; Percent complete: 98.9%; Training loss: 1.2514; Validation loss: 11.1085
# Iteration: 9886; Percent complete: 98.9%; Training loss: 1.3657; Validation loss: 10.8596
# Iteration: 9887; Percent complete: 98.9%; Training loss: 1.5087; Validation loss: 10.5863
# Iteration: 9888; Percent complete: 98.9%; Training loss: 1.2808; Validation loss: 10.6243
# Iteration: 9889; Percent complete: 98.9%; Training loss: 1.3705; Validation loss: 10.5896
# Iteration: 9890; Percent complete: 98.9%; Training loss: 1.5177; Validation loss: 10.8231
# Iteration: 9891; Percent complete: 98.9%; Training loss: 1.3646; Validation loss: 10.5081
# Iteration: 9892; Percent complete: 98.9%; Training loss: 1.4579; Validation loss: 10.3975
# Iteration: 9893; Percent complete: 98.9%; Training loss: 1.6223; Validation loss: 10.3681
# Iteration: 9894; Percent complete: 98.9%; Training loss: 1.2950; Validation loss: 10.5066
# Iteration: 9895; Percent complete: 99.0%; Training loss: 1.2117; Validation loss: 11.4992
# Iteration: 9896; Percent complete: 99.0%; Training loss: 1.4418; Validation loss: 11.0582
# Iteration: 9897; Percent complete: 99.0%; Training loss: 1.4452; Validation loss: 10.2092
# Iteration: 9898; Percent complete: 99.0%; Training loss: 1.4768; Validation loss: 10.5029
# Iteration: 9899; Percent complete: 99.0%; Training loss: 1.3047; Validation loss: 11.1851
# Iteration: 9900; Percent complete: 99.0%; Training loss: 1.3552; Validation loss: 10.9189
# Iteration: 9901; Percent complete: 99.0%; Training loss: 1.4464; Validation loss: 10.3683
# Iteration: 9902; Percent complete: 99.0%; Training loss: 1.4036; Validation loss: 10.3317
# Iteration: 9903; Percent complete: 99.0%; Training loss: 1.4807; Validation loss: 10.5011
# Iteration: 9904; Percent complete: 99.0%; Training loss: 1.3308; Validation loss: 10.6234
# Iteration: 9905; Percent complete: 99.1%; Training loss: 1.2429; Validation loss: 10.6766
# Iteration: 9906; Percent complete: 99.1%; Training loss: 1.3337; Validation loss: 10.6064
# Iteration: 9907; Percent complete: 99.1%; Training loss: 1.5509; Validation loss: 10.8427
# Iteration: 9908; Percent complete: 99.1%; Training loss: 1.4239; Validation loss: 10.3282
# Iteration: 9909; Percent complete: 99.1%; Training loss: 1.5991; Validation loss: 9.8806
# Iteration: 9910; Percent complete: 99.1%; Training loss: 1.5216; Validation loss: 10.2353
# Iteration: 9911; Percent complete: 99.1%; Training loss: 1.4658; Validation loss: 10.4911
# Iteration: 9912; Percent complete: 99.1%; Training loss: 1.3374; Validation loss: 11.1284
# Iteration: 9913; Percent complete: 99.1%; Training loss: 1.4882; Validation loss: 10.7516
# Iteration: 9914; Percent complete: 99.1%; Training loss: 1.4272; Validation loss: 11.2753
# Iteration: 9915; Percent complete: 99.2%; Training loss: 1.4089; Validation loss: 10.7320
# Iteration: 9916; Percent complete: 99.2%; Training loss: 1.4070; Validation loss: 10.3774
# Iteration: 9917; Percent complete: 99.2%; Training loss: 1.4319; Validation loss: 10.9133
# Iteration: 9918; Percent complete: 99.2%; Training loss: 1.6020; Validation loss: 10.3607
# Iteration: 9919; Percent complete: 99.2%; Training loss: 1.4440; Validation loss: 11.1036
# Iteration: 9920; Percent complete: 99.2%; Training loss: 1.3725; Validation loss: 10.8568
# Iteration: 9921; Percent complete: 99.2%; Training loss: 1.4225; Validation loss: 10.7198
# Iteration: 9922; Percent complete: 99.2%; Training loss: 1.2100; Validation loss: 10.9028
# Iteration: 9923; Percent complete: 99.2%; Training loss: 1.4675; Validation loss: 10.7297
# Iteration: 9924; Percent complete: 99.2%; Training loss: 1.3940; Validation loss: 10.7916
# Iteration: 9925; Percent complete: 99.2%; Training loss: 1.1850; Validation loss: 10.6114
# Iteration: 9926; Percent complete: 99.3%; Training loss: 1.4791; Validation loss: 10.6357
# Iteration: 9927; Percent complete: 99.3%; Training loss: 1.2729; Validation loss: 10.3933
# Iteration: 9928; Percent complete: 99.3%; Training loss: 1.5439; Validation loss: 10.4716
# Iteration: 9929; Percent complete: 99.3%; Training loss: 1.3379; Validation loss: 10.6597
# Iteration: 9930; Percent complete: 99.3%; Training loss: 1.4419; Validation loss: 10.4104
# Iteration: 9931; Percent complete: 99.3%; Training loss: 1.2232; Validation loss: 10.5458
# Iteration: 9932; Percent complete: 99.3%; Training loss: 1.3556; Validation loss: 10.8049
# Iteration: 9933; Percent complete: 99.3%; Training loss: 1.3162; Validation loss: 11.4279
# Iteration: 9934; Percent complete: 99.3%; Training loss: 1.3942; Validation loss: 10.9532
# Iteration: 9935; Percent complete: 99.4%; Training loss: 1.4450; Validation loss: 10.4461
# Iteration: 9936; Percent complete: 99.4%; Training loss: 1.4961; Validation loss: 11.1608
# Iteration: 9937; Percent complete: 99.4%; Training loss: 1.4471; Validation loss: 10.5607
# Iteration: 9938; Percent complete: 99.4%; Training loss: 1.4789; Validation loss: 11.1067
# Iteration: 9939; Percent complete: 99.4%; Training loss: 1.4875; Validation loss: 10.3468
# Iteration: 9940; Percent complete: 99.4%; Training loss: 1.2393; Validation loss: 10.7868
# Iteration: 9941; Percent complete: 99.4%; Training loss: 1.3513; Validation loss: 10.4879
# Iteration: 9942; Percent complete: 99.4%; Training loss: 1.3046; Validation loss: 10.5080
# Iteration: 9943; Percent complete: 99.4%; Training loss: 1.3658; Validation loss: 10.7546
# Iteration: 9944; Percent complete: 99.4%; Training loss: 1.4022; Validation loss: 10.6381
# Iteration: 9945; Percent complete: 99.5%; Training loss: 1.1788; Validation loss: 10.6225
# Iteration: 9946; Percent complete: 99.5%; Training loss: 1.4928; Validation loss: 10.5326
# Iteration: 9947; Percent complete: 99.5%; Training loss: 1.4110; Validation loss: 10.8555
# Iteration: 9948; Percent complete: 99.5%; Training loss: 1.4064; Validation loss: 10.4543
# Iteration: 9949; Percent complete: 99.5%; Training loss: 1.3836; Validation loss: 11.0833
# Iteration: 9950; Percent complete: 99.5%; Training loss: 1.3638; Validation loss: 10.7243
# Iteration: 9951; Percent complete: 99.5%; Training loss: 1.3500; Validation loss: 10.4239
# Iteration: 9952; Percent complete: 99.5%; Training loss: 1.4124; Validation loss: 10.8640
# Iteration: 9953; Percent complete: 99.5%; Training loss: 1.2618; Validation loss: 10.4188
# Iteration: 9954; Percent complete: 99.5%; Training loss: 1.4341; Validation loss: 10.6825
# Iteration: 9955; Percent complete: 99.6%; Training loss: 1.3953; Validation loss: 10.5653
# Iteration: 9956; Percent complete: 99.6%; Training loss: 1.5966; Validation loss: 10.7080
# Iteration: 9957; Percent complete: 99.6%; Training loss: 1.3776; Validation loss: 10.4256
# Iteration: 9958; Percent complete: 99.6%; Training loss: 1.3051; Validation loss: 10.7804
# Iteration: 9959; Percent complete: 99.6%; Training loss: 1.3739; Validation loss: 10.7569
# Iteration: 9960; Percent complete: 99.6%; Training loss: 1.3272; Validation loss: 10.5914
# Iteration: 9961; Percent complete: 99.6%; Training loss: 1.3009; Validation loss: 11.3975
# Iteration: 9962; Percent complete: 99.6%; Training loss: 1.4520; Validation loss: 10.8964
# Iteration: 9963; Percent complete: 99.6%; Training loss: 1.2653; Validation loss: 10.1977
# Iteration: 9964; Percent complete: 99.6%; Training loss: 1.4328; Validation loss: 10.4823
# Iteration: 9965; Percent complete: 99.7%; Training loss: 1.3707; Validation loss: 10.9010
# Iteration: 9966; Percent complete: 99.7%; Training loss: 1.4243; Validation loss: 10.4749
# Iteration: 9967; Percent complete: 99.7%; Training loss: 1.2818; Validation loss: 10.8086
# Iteration: 9968; Percent complete: 99.7%; Training loss: 1.4530; Validation loss: 10.7729
# Iteration: 9969; Percent complete: 99.7%; Training loss: 1.3456; Validation loss: 10.6654
# Iteration: 9970; Percent complete: 99.7%; Training loss: 1.3208; Validation loss: 10.8728
# Iteration: 9971; Percent complete: 99.7%; Training loss: 1.2679; Validation loss: 10.5521
# Iteration: 9972; Percent complete: 99.7%; Training loss: 1.2763; Validation loss: 11.3123
# Iteration: 9973; Percent complete: 99.7%; Training loss: 1.4179; Validation loss: 10.9326
# Iteration: 9974; Percent complete: 99.7%; Training loss: 1.4710; Validation loss: 10.8155
# Iteration: 9975; Percent complete: 99.8%; Training loss: 1.2412; Validation loss: 10.5062
# Iteration: 9976; Percent complete: 99.8%; Training loss: 1.2959; Validation loss: 10.5893
# Iteration: 9977; Percent complete: 99.8%; Training loss: 1.2422; Validation loss: 10.7284
# Iteration: 9978; Percent complete: 99.8%; Training loss: 1.3435; Validation loss: 11.0468
# Iteration: 9979; Percent complete: 99.8%; Training loss: 1.2612; Validation loss: 10.7815
# Iteration: 9980; Percent complete: 99.8%; Training loss: 1.2546; Validation loss: 10.8700
# Iteration: 9981; Percent complete: 99.8%; Training loss: 1.3650; Validation loss: 10.5163
# Iteration: 9982; Percent complete: 99.8%; Training loss: 1.3996; Validation loss: 10.2508
# Iteration: 9983; Percent complete: 99.8%; Training loss: 1.1785; Validation loss: 10.8731
# Iteration: 9984; Percent complete: 99.8%; Training loss: 1.2830; Validation loss: 10.9435
# Iteration: 9985; Percent complete: 99.9%; Training loss: 1.3436; Validation loss: 10.7461
# Iteration: 9986; Percent complete: 99.9%; Training loss: 1.2803; Validation loss: 10.1638
# Iteration: 9987; Percent complete: 99.9%; Training loss: 1.5689; Validation loss: 11.3210
# Iteration: 9988; Percent complete: 99.9%; Training loss: 1.3034; Validation loss: 10.7099
# Iteration: 9989; Percent complete: 99.9%; Training loss: 1.4204; Validation loss: 10.8425
# Iteration: 9990; Percent complete: 99.9%; Training loss: 1.3247; Validation loss: 11.0101
# Iteration: 9991; Percent complete: 99.9%; Training loss: 1.3612; Validation loss: 10.6919
# Iteration: 9992; Percent complete: 99.9%; Training loss: 1.4841; Validation loss: 10.5573
# Iteration: 9993; Percent complete: 99.9%; Training loss: 1.3609; Validation loss: 10.7577
# Iteration: 9994; Percent complete: 99.9%; Training loss: 1.3844; Validation loss: 10.8553
# Iteration: 9995; Percent complete: 100.0%; Training loss: 1.3469; Validation loss: 10.8987
# Iteration: 9996; Percent complete: 100.0%; Training loss: 1.2909; Validation loss: 10.4876
# Iteration: 9997; Percent complete: 100.0%; Training loss: 1.3462; Validation loss: 10.8336
# Iteration: 9998; Percent complete: 100.0%; Training loss: 1.2900; Validation loss: 10.6088
# Iteration: 9999; Percent complete: 100.0%; Training loss: 1.3692; Validation loss: 10.6366
# Iteration: 10000; Percent complete: 100.0%; Training loss: 1.4761; Validation loss: 10.6373

# %%
encoder.eval()
decoder.eval()
searcher = SearchDecoder(encoder, decoder)
evaluateInput(encoder, decoder, searcher, voc)
